# %% [markdown]
# # Hindi Song Mood Classifier — Experiment Grid
# ### Comparing models × sampling strategies
# **Models:** XGBoost, SVM, Logistic Regression, KNN, Random Forest
# **Strategies:** Baseline · Remove 'other' · Oversample (SMOTE) · Undersample · Remove+Oversample · Remove+Undersample
# **Total experiments:** 30 combinations

# %%
# Run once to install dependencies
# !pip install xgboost imbalanced-learn scikit-learn pandas matplotlib seaborn openpyxl

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from itertools import product

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import (classification_report, confusion_matrix,
                              accuracy_score, f1_score)
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as ImbPipeline

from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier

from sklearn.linear_model import RidgeClassifier, LogisticRegression
from sklearn.ensemble import ExtraTreesClassifier, AdaBoostClassifier, StackingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier

RANDOM_STATE = 42
pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:.4f}".format)
print("All imports OK")
# Out:
# All imports OK

# %%
# ── Load dataset ──────────────────────────────────────────────────────────
EXCEL_PATH = "scaled_features.xlsx"
TARGET_COL = "FINAL MOOD"

META_COLS = ["ID", "Song Title", "Film / Album", "Year",
             "ChatGPT Mood", "Claude Mood", "deepseek/copilot Mood",
             "FINAL MOOD", "Test", "File name"]

df = pd.read_excel(EXCEL_PATH)
FEATURE_COLS = [c for c in df.columns if c not in META_COLS]

print(f"Dataset shape   : {df.shape}")
print(f"Feature columns : {len(FEATURE_COLS)}")
print()
print("Class distribution:")
print(df[TARGET_COL].value_counts().to_string())
# Out:
# Dataset shape   : (1538, 66)
# Feature columns : 56
#
# Class distribution:
# FINAL MOOD
# romantic    395
# sad         344
# excited     321
# other       247
# happy       231

# %%
# ── Class distribution visualisation ─────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

counts = df[TARGET_COL].value_counts()
colors = ["#e74c3c", "#e67e22", "#3498db", "#2ecc71", "#9b59b6"]

axes[0].bar(counts.index, counts.values, color=colors)
axes[0].set_title("Full Dataset — Class Distribution", fontsize=13)
axes[0].set_xlabel("Mood"); axes[0].set_ylabel("Count")
for i, (cls, v) in enumerate(counts.items()):
    axes[0].text(i, v + 3, str(v), ha="center", fontsize=10, fontweight="bold")

counts_no_other = df.loc[df[TARGET_COL] != "other", TARGET_COL].value_counts()
axes[1].bar(counts_no_other.index, counts_no_other.values, color=colors[:4])
axes[1].set_title("Without 'other' Class", fontsize=13)
axes[1].set_xlabel("Mood"); axes[1].set_ylabel("Count")
for i, (cls, v) in enumerate(counts_no_other.items()):
    axes[1].text(i, v + 3, str(v), ha="center", fontsize=10, fontweight="bold")

plt.suptitle("Class Imbalance Overview", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Feature selection: drop low-variance + highly correlated ──────────────
from sklearn.preprocessing import MinMaxScaler

def drop_low_variance(X_df, threshold=0.01):
    scaled = pd.DataFrame(MinMaxScaler().fit_transform(X_df), columns=X_df.columns)
    return [c for c in scaled.columns if scaled[c].var() > threshold]

def drop_correlated(X_df, threshold=0.90):
    corr  = X_df.corr().abs()
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
    drop  = {c for c in upper.columns if any(upper[c] > threshold)}
    return [c for c in X_df.columns if c not in drop]

X_full = df[FEATURE_COLS].copy()
keep   = drop_low_variance(X_full)
X_full = X_full[keep]
keep   = drop_correlated(X_full)
X_full = X_full[keep]

print(f"Features after selection: {X_full.shape[1]}  (was {len(FEATURE_COLS)})")

y_full = df[TARGET_COL].values
# Out:
# Features after selection: 35  (was 56)

# %%
# ── Define models and sampling strategies ─────────────────────────────────

MODELS = {
    "LightGBM": LGBMClassifier(
        n_estimators=300, learning_rate=0.1,
        random_state=RANDOM_STATE, n_jobs=-1),

    "Gradient Boosting": GradientBoostingClassifier(
        n_estimators=200, learning_rate=0.1,
        random_state=RANDOM_STATE),
    "Decision Tree": DecisionTreeClassifier(
        max_depth=6, class_weight="balanced",
        random_state=RANDOM_STATE),
    "SGD": SGDClassifier(
        loss="log_loss", max_iter=1000, tol=1e-3,
        class_weight="balanced", random_state=RANDOM_STATE),
    "Naive Bayes": GaussianNB(),
    "Ridge": RidgeClassifier(random_state=RANDOM_STATE),
}

STRATEGIES = [
    "baseline",
    "remove_other",
    "oversample",
    "undersample",
    "remove_other+oversample",
    "remove_other+undersample",
]

print(f"Models     : {list(MODELS.keys())}")
print(f"Strategies : {STRATEGIES}")
print(f"\nTotal experiments : {len(MODELS) * len(STRATEGIES)}")
# Out:
# Models     : ['LightGBM', 'Gradient Boosting', 'Decision Tree', 'SGD', 'Naive Bayes', 'Ridge']
# Strategies : ['baseline', 'remove_other', 'oversample', 'undersample', 'remove_other+oversample', 'remove_other+undersample']
#
# Total experiments : 36

# %%
# ── Run all 30 experiments ────────────────────────────────────────────────

def prepare_data(strategy, X, y):
    """Apply sampling strategy and return (X_train, X_test, y_train, y_test, classes)."""
    remove_other = "remove_other" in strategy

    if remove_other:
        mask = y != "other"
        X_use, y_use = X[mask], y[mask]
    else:
        X_use, y_use = X.copy(), y.copy()

    le = LabelEncoder()
    y_enc = le.fit_transform(y_use)

    X_tr, X_te, y_tr, y_te = train_test_split(
        X_use.values, y_enc, test_size=0.2,
        stratify=y_enc, random_state=RANDOM_STATE)

    if "oversample" in strategy:
        sm = SMOTE(random_state=RANDOM_STATE)
        X_tr, y_tr = sm.fit_resample(X_tr, y_tr)
    elif "undersample" in strategy:
        rus = RandomUnderSampler(random_state=RANDOM_STATE)
        X_tr, y_tr = rus.fit_resample(X_tr, y_tr)

    return X_tr, X_te, y_tr, y_te, le


results = []  # list of dicts, one per experiment

for strategy in STRATEGIES:
    X_tr, X_te, y_tr, y_te, le = prepare_data(strategy, X_full, y_full)
    n_classes = len(le.classes_)

    print(f"\n{'='*60}")
    print(f"Strategy: {strategy.upper()}")
    print(f"  Train size: {len(X_tr)}  |  Test size: {len(X_te)}")
    print(f"  Classes: {list(le.classes_)}")
    tr_dist = pd.Series(y_tr).value_counts().to_dict()
    print(f"  Train dist: { {le.classes_[k]: v for k, v in tr_dist.items()} }")

    for model_name, clf in MODELS.items():
        # Wrap in scaling pipeline
        pipe = Pipeline([("sc", StandardScaler()), ("clf", clf)])

        pipe.fit(X_tr, y_tr)
        y_pred = pipe.predict(X_te)

        acc = accuracy_score(y_te, y_pred)
        f1  = f1_score(y_te, y_pred, average="macro")
        f1w = f1_score(y_te, y_pred, average="weighted")

        report = classification_report(
            y_te, y_pred, target_names=le.classes_, output_dict=True)

        results.append({
            "strategy"  : strategy,
            "model"     : model_name,
            "accuracy"  : acc,
            "f1_macro"  : f1,
            "f1_weighted": f1w,
            "report"    : report,
            "y_te"      : y_te,
            "y_pred"    : y_pred,
            "classes"   : list(le.classes_),
            "pipe"      : pipe,
        })

        print(f"  {model_name:<22}: Acc={acc:.4f}  F1-macro={f1:.4f}  F1-weighted={f1w:.4f}")

print("\n✅ All experiments complete.")
# Out:
# ============================================================
# Strategy: BASELINE
#   Train size: 1230  |  Test size: 308
#   Classes: ['excited', 'happy', 'other', 'romantic', 'sad']
#   Train dist: {'romantic': 316, 'sad': 275, 'excited': 257, 'other': 197, 'happy': 185}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000830 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8696
# [LightGBM] [Info] Number of data points in the train set: 1230, number of used features: 35
# [LightGBM] [Info] Start training from score -1.565693
# [LightGBM] [Info] Start training from score -1.894414
# [LightGBM] [Info] Start training from score -1.831566
# [LightGBM] [Info] Start training from score -1.359027
# [LightGBM] [Info] Start training from score -1.497998
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#   LightGBM              : Acc=0.4903  F1-macro=0.4620  F1-weighted=0.4783
#   Gradient Boosting     : Acc=0.4805  F1-macro=0.4516  F1-weighted=0.4700
#   Decision Tree         : Acc=0.4383  F1-macro=0.4233  F1-weighted=0.4378
#   SGD                   : Acc=0.3279  F1-macro=0.3027  F1-weighted=0.3100
#   Naive Bayes           : Acc=0.4545  F1-macro=0.3975  F1-weighted=0.4234
#   Ridge                 : Acc=0.4708  F1-macro=0.3976  F1-weighted=0.4265
#
# ============================================================
# Strategy: REMOVE_OTHER
#   Train size: 1032  |  Test size: 259
#   Classes: ['excited', 'happy', 'romantic', 'sad']
#   Train dist: {'romantic': 316, 'sad': 275, 'excited': 256, 'happy': 185}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001102 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8697
# [LightGBM] [Info] Number of data points in the train set: 1032, number of used features: 35
# [LightGBM] [Info] Start training from score -1.394077
# [LightGBM] [Info] Start training from score -1.718898
# [LightGBM] [Info] Start training from score -1.183512
# [LightGBM] [Info] Start training from score -1.322483
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#   LightGBM              : Acc=0.5405  F1-macro=0.5263  F1-weighted=0.5359
#   Gradient Boosting     : Acc=0.4942  F1-macro=0.4740  F1-weighted=0.4889
#   Decision Tree         : Acc=0.4826  F1-macro=0.4781  F1-weighted=0.4866
#   SGD                   : Acc=0.4517  F1-macro=0.4426  F1-weighted=0.4466
#   Naive Bayes           : Acc=0.5097  F1-macro=0.4745  F1-weighted=0.4949
#   Ridge                 : Acc=0.5135  F1-macro=0.4851  F1-weighted=0.5006
#
# ✅ All experiments complete.

# %%
# ── Summary table: all 30 experiments ────────────────────────────────────
summary = pd.DataFrame([{
    "Strategy"   : r["strategy"],
    "Model"      : r["model"],
    "Accuracy"   : round(r["accuracy"],  4),
    "F1-macro"   : round(r["f1_macro"],  4),
    "F1-weighted": round(r["f1_weighted"],4),
} for r in results])

# Highlight best F1-macro per strategy
def highlight_best(s):
    is_max = s == s.max()
    return ["background-color: #d4edda; font-weight: bold" if v else "" for v in is_max]

display(
    summary.style
    .apply(highlight_best, subset=["F1-macro"], axis=0)
    .format({"Accuracy": "{:.4f}", "F1-macro": "{:.4f}", "F1-weighted": "{:.4f}"})
    .set_caption("All Experiments — Green = best F1-macro per strategy")
)
# Out:
# <style type="text/css">
# #T_d6530_row6_col3 {
#   background-color: #d4edda;
#   font-weight: bold;
# }
# </style>
# <table id="T_d6530">
#   <caption>All Experiments — Green = best F1-macro per strategy</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6530_level0_col0" class="col_heading level0 col0" >Strategy</th>
#       <th id="T_d6530_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_d6530_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#       <th id="T_d6530_level0_col3" class="col_heading level0 col3" >F1-macro</th>
#       <th id="T_d6530_level0_col4" class="col_heading level0 col4" >F1-weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6530_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6530_row0_col0" class="data row0 col0" >baseline</td>
#       <td id="T_d6530_row0_col1" class="data row0 col1" >LightGBM</td>
#       <td id="T_d6530_row0_col2" class="data row0 col2" >0.4903</td>
#       <td id="T_d6530_row0_col3" class="data row0 col3" >0.4620</td>
#       <td id="T_d6530_row0_col4" class="data row0 col4" >0.4783</td>
#     </tr>
#     <tr>
#       <th id="T_d6530_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d6530_row1_col0" class="data row1 col0" >baseline</td>
#       <td id="T_d6530_row1_col1" class="data row1 col1" >Gradient Boosting</td>
#       <td id="T_d6530_row1_col2" class="data row1 col2" >0.4805</td>
#       <td id="T_d6530_row1_col3" class="data row1 col3" >0.4516</td>
#       <td id="T_d6530_row1_col4" class="data row1 col4" >0.4700</td>
#     </tr>
#     <tr>
#       <th id="T_d6530_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d6530_row2_col0" class="data row2 col0" >baseline</td>
#       <td id="T_d6530_row2_col1" class="data row2 col1" >Decision Tree</td>
#       <td id="T_d6530_row2_col2" class="data row2 col2" >0.4383</td>
#       <td id="T_d6530_row2_col3" class="data row2 col3" >0.4233</td>
#       <td id="T_d6530_row2_col4" class="data row2 col4" >0.4378</td>
#     </tr>
#     <tr>
#       <th id="T_d6530_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d6530_row3_col0" class="data row3 col0" >baseline</td>
#       <td id="T_d6530_row3_col1" class="data row3 col1" >SGD</td>
#       <td id="T_d6530_row3_col2" class="data row3 col2" >0.3279</td>
#       <td id="T_d6530_row3_col3" class="data row3 col3" >0.3027</td>
#       <td id="T_d6530_row3_col4" class="data row3 col4" >0.3100</td>
#     </tr>
#     <tr>
#       <th id="T_d6530_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d6530_row4_col0" class="data row4 col0" >baseline</td>
#       <td id="T_d6530_row4_col1" class="data row4 col1" >Naive Bayes</td>
#       <td id="T_d6530_row4_col2" class="data row4 col2" >0.4545</td>
#       <td id="T_d6530_row4_col3" class="data row4 col3" >0.3975</td>
#       <td id="T_d6530_row4_col4" class="data row4 col4" >0.4234</td>
#     </tr>
#     <tr>
#       <th id="T_d6530_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d6530_row5_col0" class="data row5 col0" >baseline</td>
#       <td id="T_d6530_row5_col1" class="data row5 col1" >Ridge</td>
#       <td id="T_d6530_row5_col2" class="data row5 col2" >0.4708</td>
#       <td id="T_d6530_row5_col3" class="data row5 col3" >0.3976</td>
#       <td id="T_d6530_row5_col4" class="data row5 col4" >0.4265</td>
#     </tr>
#     <tr>
#       <th id="T_d6530_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d6530_row6_col0" class="data row6 col0" >remove_other</td>
#       <td id="T_d6530_row6_col1" class="data row6 col1" >LightGBM</td>
#       <td id="T_d6530_row6_col2" class="data row6 col2" >0.5521</td>
#       <td id="T_d6530_row6_col3" class="data row6 col3" >0.5296</td>
#       <td id="T_d6530_row6_col4" class="data row6 col4" >0.5417</td>
#     </tr>
#     <tr>
#       <th id="T_d6530_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d6530_row7_col0" class="data row7 col0" >remove_other</td>
#       <td id="T_d6530_row7_col1" class="data row7 col1" >Gradient Boosting</td>
#       <td id="T_d6530_row7_col2" class="data row7 col2" >0.5174</td>
#       <td id="T_d6530_row7_col3" class="data row7 col3" >0.4992</td>
#       <td id="T_d6530_row7_col4" class="data row7 col4" >0.5100</td>
#     </tr>
#     <tr>
#       <th id="T_d6530_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d6530_row8_col0" class="data row8 col0" >remove_other</td>
#       <td id="T_d6530_row8_col1" class="data row8 col1" >Decision Tree</td>
#       <td id="T_d6530_row8_col2" class="data row8 col2" >0.4749</td>
#       <td id="T_d6530_row8_col3" class="data row8 col3" >0.4791</td>
#       <td id="T_d6530_row8_col4" class="data row8 col4" >0.4841</td>
#     </tr>
#     <tr>
#       <th id="T_d6530_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d6530_row9_col0" class="data row9 col0" >remove_other</td>
#       <td id="T_d6530_row9_col1" class="data row9 col1" >SGD</td>
#       <td id="T_d6530_row9_col2" class="data row9 col2" >0.4633</td>
#       <td id="T_d6530_row9_col3" class="data row9 col3" >0.4484</td>
#       <td id="T_d6530_row9_col4" class="data row9 col4" >0.4546</td>
#     </tr>
#     <tr>
#       <th id="T_d6530_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d6530_row10_col0" class="data row10 col0" >remove_other</td>
#       <td id="T_d6530_row10_col1" class="data row10 col1" >Naive Bayes</td>
#       <td id="T_d6530_row10_col2" class="data row10 col2" >0.5290</td>
#       <td id="T_d6530_row10_col3" class="data row10 col3" >0.4764</td>
#       <td id="T_d6530_row10_col4" class="data row10 col4" >0.5035</td>
#     </tr>
#     <tr>
#       <th id="T_d6530_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d6530_row11_col0" class="data row11 col0" >remove_other</td>
#       <td id="T_d6530_row11_col1" class="data row11 col1" >Ridge</td>
#       <td id="T_d6530_row11_col2" class="data row11 col2" >0.5290</td>
#       <td id="T_d6530_row11_col3" class="data row11 col3" >0.4631</td>
#       <td id="T_d6530_row11_col4" class="data row11 col4" >0.4920</td>
#     </tr>
#     <tr>
#       <th id="T_d6530_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d6530_row12_col0" class="data row12 col0" >oversample</td>
#       <td id="T_d6530_row12_col1" class="data row12 col1" >LightGBM</td>
#       <td id="T_d6530_row12_col2" class="data row12 col2" >0.4805</td>
#       <td id="T_d6530_row12_col3" class="data row12 col3" >0.4653</td>
#       <td id="T_d6530_row12_col4" class="data row12 col4" >0.4760</td>
#     </tr>
#     <tr>
#       <th id="T_d6530_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d6530_row13_col0" class="data row13 col0" >oversample</td>
#       <td id="T_d6530_row13_col1" class="data row13 col1" >Gradient Boosting</td>
#       <td id="T_d6530_row13_col2" class="data row13 col2" >0.4416</td>
#       <td id="T_d6530_row13_col3" class="data row13 col3" >0.4243</td>
#       <td id="T_d6530_row13_col4" class="data row13 col4" >0.4365</td>
#     </tr>
#     <tr>
#       <th id="T_d6530_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d6530_row14_col0" class="data row14 col0" >oversample</td>
#       <td id="T_d6530_row14_col1" class="data row14 col1" >Decision Tree</td>
#       <td id="T_d6530_row14_col2" class="data row14 col2" >0.3701</td>
#       <td id="T_d6530_row14_col3" class="data row14 col3" >0.3654</td>
#       <td id="T_d6530_row14_col4" class="data row14 col4" >0.3759</td>
#     </tr>
#     <tr>
#       <th id="T_d6530_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d6530_row15_col0" class="data row15 col0" >oversample</td>
#       <td id="T_d6530_row15_col1" class="data row15 col1" >SGD</td>
#       <td id="T_d6530_row15_col2" class="data row15 col2" >0.4416</td>
#       <td id="T_d6530_row15_col3" class="data row15 col3" >0.4260</td>
#       <td id="T_d6530_row15_col4" class="data row15 col4" >0.4345</td>
#     </tr>
#     <tr>
#       <th id="T_d6530_level0_row16" class="row_heading level0

# %%
# ── Best model per strategy ───────────────────────────────────────────────
best_per_strategy = (
    summary.sort_values("F1-macro", ascending=False)
           .groupby("Strategy").first()
           .reset_index()
           [["Strategy", "Model", "Accuracy", "F1-macro", "F1-weighted"]]
           .sort_values("F1-macro", ascending=False)
)

print("Best model per strategy (sorted by F1-macro):")
display(best_per_strategy.style.format({
    "Accuracy": "{:.4f}", "F1-macro": "{:.4f}", "F1-weighted": "{:.4f}"}))
# Out:
# Best model per strategy (sorted by F1-macro):
# <style type="text/css">
# </style>
# <table id="T_142bd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_142bd_level0_col0" class="col_heading level0 col0" >Strategy</th>
#       <th id="T_142bd_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_142bd_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#       <th id="T_142bd_level0_col3" class="col_heading level0 col3" >F1-macro</th>
#       <th id="T_142bd_level0_col4" class="col_heading level0 col4" >F1-weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_142bd_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_142bd_row0_col0" class="data row0 col0" >remove_other</td>
#       <td id="T_142bd_row0_col1" class="data row0 col1" >LightGBM</td>
#       <td id="T_142bd_row0_col2" class="data row0 col2" >0.5521</td>
#       <td id="T_142bd_row0_col3" class="data row0 col3" >0.5296</td>
#       <td id="T_142bd_row0_col4" class="data row0 col4" >0.5417</td>
#     </tr>
#     <tr>
#       <th id="T_142bd_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_142bd_row1_col0" class="data row1 col0" >remove_other+undersample</td>
#       <td id="T_142bd_row1_col1" class="data row1 col1" >LightGBM</td>
#       <td id="T_142bd_row1_col2" class="data row1 col2" >0.5405</td>
#       <td id="T_142bd_row1_col3" class="data row1 col3" >0.5263</td>
#       <td id="T_142bd_row1_col4" class="data row1 col4" >0.5359</td>
#     </tr>
#     <tr>
#       <th id="T_142bd_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_142bd_row2_col0" class="data row2 col0" >remove_other+oversample</td>
#       <td id="T_142bd_row2_col1" class="data row2 col1" >Gradient Boosting</td>
#       <td id="T_142bd_row2_col2" class="data row2 col2" >0.5405</td>
#       <td id="T_142bd_row2_col3" class="data row2 col3" >0.5213</td>
#       <td id="T_142bd_row2_col4" class="data row2 col4" >0.5330</td>
#     </tr>
#     <tr>
#       <th id="T_142bd_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_142bd_row3_col0" class="data row3 col0" >oversample</td>
#       <td id="T_142bd_row3_col1" class="data row3 col1" >LightGBM</td>
#       <td id="T_142bd_row3_col2" class="data row3 col2" >0.4805</td>
#       <td id="T_142bd_row3_col3" class="data row3 col3" >0.4653</td>
#       <td id="T_142bd_row3_col4" class="data row3 col4" >0.4760</td>
#     </tr>
#     <tr>
#       <th id="T_142bd_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_142bd_row4_col0" class="data row4 col0" >baseline</td>
#       <td id="T_142bd_row4_col1" class="data row4 col1" >LightGBM</td>
#       <td id="T_142bd_row4_col2" class="data row4 col2" >0.4903</td>
#       <td id="T_142bd_row4_col3" class="data row4 col3" >0.4620</td>
#       <td id="T_142bd_row4_col4" class="data row4 col4" >0.4783</td>
#     </tr>
#     <tr>
#       <th id="T_142bd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_142bd_row5_col0" class="data row5 col0" >undersample</td>
#       <td id="T_142bd_row5_col1" class="data row5 col1" >LightGBM</td>
#       <td id="T_142bd_row5_col2" class="data row5 col2" >0.4416</td>
#       <td id="T_142bd_row5_col3" class="data row5 col3" >0.4325</td>
#       <td id="T_142bd_row5_col4" class="data row5 col4" >0.4406</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ── Heatmap: F1-macro for all model × strategy combinations ───────────────
pivot = summary.pivot(index="Model", columns="Strategy", values="F1-macro")
# Order strategies sensibly
col_order = [c for c in STRATEGIES if c in pivot.columns]
pivot = pivot[col_order]

fig, ax = plt.subplots(figsize=(14, 5))
sns.heatmap(pivot, annot=True, fmt=".3f", cmap="YlGn",
            linewidths=0.5, linecolor="white",
            annot_kws={"size": 11}, ax=ax,
            vmin=pivot.values.min() - 0.02,
            vmax=pivot.values.max() + 0.01)
ax.set_title("F1-macro Heatmap: Model × Sampling Strategy", fontsize=14, pad=12)
ax.set_xlabel("Strategy", fontsize=11)
ax.set_ylabel("Model", fontsize=11)
plt.xticks(rotation=25, ha="right")
plt.tight_layout()
plt.show()

# %%
# ── Heatmap: Accuracy ─────────────────────────────────────────────────────
pivot_acc = summary.pivot(index="Model", columns="Strategy", values="Accuracy")[col_order]

fig, ax = plt.subplots(figsize=(14, 5))
sns.heatmap(pivot_acc, annot=True, fmt=".3f", cmap="Blues",
            linewidths=0.5, linecolor="white",
            annot_kws={"size": 11}, ax=ax)
ax.set_title("Accuracy Heatmap: Model × Sampling Strategy", fontsize=14, pad=12)
ax.set_xlabel("Strategy", fontsize=11)
ax.set_ylabel("Model", fontsize=11)
plt.xticks(rotation=25, ha="right")
plt.tight_layout()
plt.show()

# %%
# ── Grouped bar: F1-macro per model across strategies ─────────────────────
fig, ax = plt.subplots(figsize=(15, 6))
model_names = list(MODELS.keys())
x = np.arange(len(model_names))
n_strat = len(STRATEGIES)
width = 0.13
colors_strat = plt.cm.Set2(np.linspace(0, 1, n_strat))

for i, strat in enumerate(STRATEGIES):
    vals = [summary.loc[(summary.Model == m) & (summary.Strategy == strat),
                        "F1-macro"].values[0] for m in model_names]
    offset = (i - n_strat / 2) * width + width / 2
    bars = ax.bar(x + offset, vals, width, label=strat, color=colors_strat[i])

ax.set_xlabel("Model", fontsize=12)
ax.set_ylabel("F1-macro", fontsize=12)
ax.set_title("F1-macro by Model and Sampling Strategy", fontsize=14)
ax.set_xticks(x); ax.set_xticklabels(model_names, fontsize=11)
ax.set_ylim(0, 1)
ax.legend(title="Strategy", bbox_to_anchor=(1.01, 1), loc="upper left", fontsize=9)
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# ── Per-class F1 breakdown for best experiment per strategy ───────────────
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

for ax_idx, strat in enumerate(STRATEGIES):
    # Find best model for this strategy
    strat_results = [r for r in results if r["strategy"] == strat]
    best = max(strat_results, key=lambda r: r["f1_macro"])
    classes = best["classes"]
    report  = best["report"]

    class_f1 = {cls: report[cls]["f1-score"] for cls in classes}
    mood_colors = {
        "happy":    "#2ecc71",
        "sad":      "#3498db",
        "romantic": "#e74c3c",
        "excited":  "#e67e22",
        "other":    "#95a5a6",
    }
    bar_colors = [mood_colors.get(c, "#7f8c8d") for c in class_f1]

    bars = axes[ax_idx].bar(class_f1.keys(), class_f1.values(), color=bar_colors)
    axes[ax_idx].set_title(
        f"{strat}\nBest: {best['model']}  (F1-macro={best['f1_macro']:.3f})",
        fontsize=10, fontweight="bold")
    axes[ax_idx].set_ylim(0, 1)
    axes[ax_idx].set_ylabel("F1-score")
    axes[ax_idx].axhline(best["f1_macro"], color="black",
                          linestyle="--", linewidth=1, alpha=0.5, label="macro avg")
    axes[ax_idx].legend(fontsize=8)
    for bar, (cls, val) in zip(bars, class_f1.items()):
        axes[ax_idx].text(bar.get_x() + bar.get_width()/2,
                           val + 0.01, f"{val:.2f}",
                           ha="center", va="bottom", fontsize=9)

plt.suptitle("Per-class F1 for Best Model per Strategy", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Confusion matrices for best model per strategy ────────────────────────
fig, axes = plt.subplots(2, 3, figsize=(18, 11))
axes = axes.flatten()

for ax_idx, strat in enumerate(STRATEGIES):
    strat_results = [r for r in results if r["strategy"] == strat]
    best = max(strat_results, key=lambda r: r["f1_macro"])

    cm   = confusion_matrix(best["y_te"], best["y_pred"])
    cm_n = cm.astype(float) / cm.sum(axis=1, keepdims=True)

    sns.heatmap(cm_n, annot=True, fmt=".2f", cmap="Blues",
                xticklabels=best["classes"], yticklabels=best["classes"],
                ax=axes[ax_idx], linewidths=0.3)
    axes[ax_idx].set_title(
        f"{strat}\n{best['model']}  Acc={best['accuracy']:.3f}",
        fontsize=10, fontweight="bold")
    axes[ax_idx].set_xlabel("Predicted"); axes[ax_idx].set_ylabel("Actual")

plt.suptitle("Confusion Matrices — Best Model per Strategy (normalised)",
             fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Full classification reports for every experiment ─────────────────────
for strat in STRATEGIES:
    print("\n" + "="*70)
    print(f"  STRATEGY: {strat.upper()}")
    print("="*70)
    for r in [x for x in results if x["strategy"] == strat]:
        print(f"\n--- {r['model']} ---")
        print(f"  Accuracy   : {r['accuracy']:.4f}")
        print(f"  F1-macro   : {r['f1_macro']:.4f}")
        print(f"  F1-weighted: {r['f1_weighted']:.4f}")
        rpt = r["report"]
        header = f"{'Class':<14} {'Precision':>10} {'Recall':>10} {'F1':>10} {'Support':>10}"
        print("  " + header)
        print("  " + "-"*len(header))
        for cls in r["classes"]:
            row = rpt[cls]
            print(f"  {cls:<14} {row['precision']:>10.4f} {row['recall']:>10.4f} "
                  f"{row['f1-score']:>10.4f} {int(row['support']):>10}")
        print(f"  {'macro avg':<14} {rpt['macro avg']['precision']:>10.4f} "
              f"{rpt['macro avg']['recall']:>10.4f} "
              f"{rpt['macro avg']['f1-score']:>10.4f} "
              f"{int(rpt['macro avg']['support']):>10}")
# Out:
# ======================================================================
#   STRATEGY: BASELINE
# ======================================================================
#
# --- LightGBM ---
#   Accuracy   : 0.4903
#   F1-macro   : 0.4620
#   F1-weighted: 0.4783
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7206     0.7656     0.7424         64
#   happy              0.3200     0.1739     0.2254         46
#   other              0.4872     0.3800     0.4270         50
#   romantic           0.4259     0.5823     0.4920         79
#   sad                0.4265     0.4203     0.4234         69
#   macro avg          0.4760     0.4644     0.4620        308
#
# --- Gradient Boosting ---
#   Accuracy   : 0.4805
#   F1-macro   : 0.4516
#   F1-weighted: 0.4700
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7538     0.7656     0.7597         64
#   happy              0.2414     0.1522     0.1867         46
#   other              0.4737     0.3600     0.4091         50
#   romantic           0.4107     0.5823     0.4817         79
#   sad                0.4375     0.4058     0.4211         69
#   macro avg          0.4634     0.4532     0.4516        308
#
# --- Decision Tree ---
#   Accuracy   : 0.4383
#   F1-macro   : 0.4233
#   F1-weighted: 0.4378
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6833     0.6406     0.6613         64
#   happy              0.2340     0.2391     0.2366         46
#   other              0.4048     0.3400     0.3696         50
#   romantic           0.4059     0.5190     0.4556         79
#   sad                0.4310     0.3623     0.3937         69
#   macro avg          0.4318     0.4202     0.4233        308
#
# --- SGD ---
#   Accuracy   : 0.3279
#   F1-macro   : 0.3027
#   F1-weighted: 0.3100
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5444     0.7656     0.6364         64
#   happy              0.1132     0.1304     0.1212         46
#   other              0.2209     0.3800     0.2794         50
#   romantic           0.3415     0.1772     0.2333         79
#   sad                0.3421     0.1884     0.2430         69
#   macro avg          0.3124     0.3283     0.3027        308
#
# --- Naive Bayes ---
#   Accuracy   : 0.4545
#   F1-macro   : 0.3975
#   F1-weighted: 0.4234
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5426     0.7969     0.6456         64
#   happy              0.2500     0.0652     0.1034         46
#   other              0.3333     0.3000     0.3158         50
#   romantic           0.4433     0.5443     0.4886         79
#   sad                0.4667     0.4058     0.4341         69
#   macro avg          0.4072     0.4224     0.3975        308
#
# --- Ridge ---
#   Accuracy   : 0.4708
#   F1-macro   : 0.3976
#   F1-weighted: 0.4265
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5806     0.8438     0.6879         64
#   happy              0.2500     0.0652     0.1034         46
#   other              0.5000     0.2000     0.2857         50
#   romantic           0.4530     0.6709     0.5408         79
#   sad                0.3788     0.3623     0.3704         69
#   macro avg          0.4325     0.4284     0.3976        308
#
# ======================================================================
#   STRATEGY: REMOVE_OTHER
# ======================================================================
#
# --- LightGBM ---
#   Accuracy   : 0.5521
#   F1-macro   : 0.5296
#   F1-weighted: 0.5417
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7761     0.8000     0.7879         65
#   happy              0.5000     0.2391     0.3235         46
#   romantic           0.4634     0.4810     0.4720         79
#   sad                0.4773     0.6087     0.5350         69
#   macro avg          0.5542     0.5322     0.5296        259
#
# --- Gradient Boosting ---
#   Accuracy   : 0.5174
#   F1-macro   : 0.4992
#   F1-weighted: 0.5100
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7463     0.7692     0.7576         65
#   happy              0.4583     0.2391     0.3143         46
#   romantic           0.4239     0.4937     0.4561         79
#   sad                0.4474     0.4928     0.4690         69
#   macro avg          0.5190     0.4987     0.4992        259
#
# --- Decision Tree ---
#   Accuracy   : 0.4749
#   F1-macro   : 0.4791
#   F1-weighted: 0.4841
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.8000     0.6154     0.6957         65
#   happy              0.2941     0.4348     0.3509         46
#   romantic           0.4590     0.3544     0.4000         79
#   sad                0.4375     0.5072     0.4698         69
#   macro avg          0.4977     0.4780     0.4791        259
#
# --- SGD ---
#   Accuracy   : 0.4633
#   F1-macro   : 0.4484
#   F1-weighted: 0.4546
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6800     0.7846     0.7286         65
#   happy              0.2593     0.3043     0.2800         46
#   romantic           0.4231     0.2785     0.3359         79
#   sad                0.4231     0.4783     0.4490         69
#   macro avg          0.4464     0.4614     0.4484        259
#
# --- Naive Bayes ---
#   Accuracy   : 0.5290
#   F1-macro   : 0.4764
#   F1-weighted: 0.5035
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6341     0.8000     0.7075         65
#   happy              0.2632     0.1087     0.1538         46
#   romantic           0.4945     0.5696     0.5294         79
#   sad                0.5224     0.5072     0.5147         69
#   macro avg          0.4785     0.4964     0.4764        259
#
# --- Ridge ---
#   Accuracy   : 0.5290
#   F1-macro   : 0.4631
#   F1-weighted: 0.4920
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6707     0.8462     0.7483         65
#   happy              0.3750     0.0652     0.1111         46
#   romantic           0.4688     0.5696     0.5143         79
#   sad                0.4658     0.4928     0.4789         69
#   macro avg          0.4951     0.4934     0.4631        259
#
# ======================================================================
#   STRATEGY: OVERSAMPLE
# ======================================================================
#
# --- LightGBM ---
#   Accuracy   : 0.4805
#   F1-macro   : 0.4653
#   F1-weighted: 0.4760
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7273     0.7500     0.7385         64
#   happy              0.2941     0.2174     0.2500         46
#   other              0.4600     0.4600     0.4600         50
#   romantic           0.4045     0.4557     0.4286         79
#   sad                0.4493     0.4493     0.4493         69
#   macro avg          0.4670     0.4665     0.4653        308
#
# --- Gradient Boosting ---
#   Accuracy   : 0.4416
#   F1-macro   : 0.4243
#   F1-weighted: 0.4365
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6765     0.7188     0.6970         64
#   happy              0.2222     0.1739     0.1951         46
#   other              0.4200     0.4200     0.4200         50
#   romantic           0.3646     0.4430     0.4000         79
#   sad                0.4483     0.3768     0.4094         69
#   macro avg          0.4263     0.4265     0.4243        308
#
# --- Decision Tree ---
#   Accuracy   : 0.3701
#   F1-macro   : 0.3654
#   F1-weighted: 0.3759
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6842     0.6094     0.6446         64
#   happy              0.1525     0.1957     0.1714         46
#   other              0.3077     0.4000     0.3478         50
#   romantic           0.3457     0.3544     0.3500         79
#   sad                0.3913     0.2609     0.3130         69
#   macro avg          0.3763     0.3641     0.3654        308
#
# --- SGD ---
#   Accuracy   : 0.4416
#   F1-macro   : 0.4260
#   F1-weighted: 0.4345
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6622     0.7656     0.7101         64
#   happy              0.2679     0.3261     0.2941         46
#   other              0.4483     0.2600     0.3291         50
#   romantic           0.3611     0.3291     0.3444         79
#   sad                0.4286     0.4783     0.4521         69
#   macro avg          0.4336     0.4318     0.4260        308
#
# --- Naive Bayes ---
#   Accuracy   : 0.4708
#   F1-macro   : 0.4434
#   F1-weighted: 0.4572
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5795     0.7969     0.6711         64
#   happy              0.3704     0.2174     0.2740         46
#   other              0.3519     0.3800     0.3654         50
#   romantic           0.4714     0.4177     0.4430         79
#   sad                0.4638     0.4638     0.4638         69
#   macro avg          0.4474     0.4552     0.4434        308
#
# --- Ridge ---
#   Accuracy   : 0.4481
#   F1-macro   : 0.4345
#   F1-weighted: 0.4409
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6098     0.7812     0.6849         64
#   happy              0.2414     0.3043     0.2692         46
#   other              0.4600     0.4600     0.4600         50
#   romantic           0.4697     0.3924     0.4276         79
#   sad                0.3846     0.2899     0.3306         69
#   macro avg          0.4331     0.4456     0.4345        308
#
# ======================================================================
#   STRATEGY: UNDERSAMPLE
# ======================================================================
#
# --- LightGBM ---
#   Accuracy   : 0.4416
#   F1-macro   : 0.4325
#   F1-weighted: 0.4406
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6957     0.7500     0.7218         64
#   happy              0.2000     0.2391     0.2178         46
#   other              0.4444     0.4800     0.4615         50
#   romantic           0.4143     0.3671     0.3893         79
#   sad                0.4000     0.3478     0.3721         69
#   macro avg          0.4309     0.4368     0.4325        308
#
# --- Gradient Boosting ---
#   Accuracy   : 0.4058
#   F1-macro   : 0.3978
#   F1-weighted: 0.4044
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6667     0.6875     0.6769         64
#   happy              0.1698     0.1957     0.1818         46
#   other              0.3788     0.5000     0.4310         50
#   romantic           0.3385     0.2785     0.3056         79
#   sad                0.4310     0.3623     0.3937         69
#   macro avg          0.3970     0.4048     0.3978        308
#
# --- Decision Tree ---
#   Accuracy   : 0.4221
#   F1-macro   : 0.4238
#   F1-weighted: 0.4311
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7111     0.5000     0.5872         64
#   happy              0.2368     0.3913     0.2951         46
#   other              0.4722     0.3400     0.3953         50
#   romantic           0.4118     0.3544     0.3810         79
#   sad                0.4217     0.5072     0.4605         69
#   macro avg          0.4507     0.4186     0.4238        308
#
# --- SGD ---
#   Accuracy   : 0.3929
#   F1-macro   : 0.3839
#   F1-weighted: 0.3897
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6769     0.6875     0.6822         64
#   happy              0.2500     0.2391     0.2444         46
#   other              0.3099     0.4400     0.3636         50
#   romantic           0.3600     0.3418     0.3506         79
#   sad                0.3208     0.2464     0.2787         69
#   macro avg          0.3835     0.3910     0.3839        308
#
# --- Naive Bayes ---
#   Accuracy   : 0.4740
#   F1-macro   : 0.4312
#   F1-weighted: 0.4548
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5618     0.7812     0.6536         64
#   happy              0.2381     0.1087     0.1493         46
#   other              0.3393     0.3800     0.3585         50
#   romantic           0.5000     0.4684     0.4837         79
#   sad                0.5147     0.5072     0.5109         69
#   macro avg          0.4308     0.4491     0.4312        308
#
# --- Ridge ---
#   Accuracy   : 0.4448
#   F1-macro   : 0.4291
#   F1-weighted: 0.4397
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6220     0.7969     0.6986         64
#   happy              0.2241     0.2826     0.2500         46
#   other              0.4000     0.4000     0.4000         50
#   romantic           0.5185     0.3544     0.4211         79
#   sad                0.3906     0.3623     0.3759         69
#   macro avg          0.4310     0.4392     0.4291        308
#
# ======================================================================
#   STRATEGY: REMOVE_OTHER+OVERSAMPLE
# ======================================================================
#
# --- LightGBM ---
#   Accuracy   : 0.5212
#   F1-macro   : 0.5031
#   F1-weighted: 0.5129
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7761     0.8000     0.7879         65
#   happy              0.3529     0.2609     0.3000         46
#   romantic           0.4348     0.3797     0.4054         79
#   sad                0.4607     0.5942     0.5190         69
#   macro avg          0.5061     0.5087     0.5031        259
#
# --- Gradient Boosting ---
#   Accuracy   : 0.5405
#   F1-macro   : 0.5213
#   F1-weighted: 0.5330
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7576     0.7692     0.7634         65
#   happy              0.3421     0.2826     0.3095         46
#   romantic           0.4706     0.4051     0.4354         79
#   sad                0.5172     0.6522     0.5769         69
#   macro avg          0.5219     0.5273     0.5213        259
#
# --- Decision Tree ---
#   Accuracy   : 0.4556
#   F1-macro   : 0.4509
#   F1-weighted: 0.4547
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7500     0.6462     0.6942         65
#   happy              0.2807     0.3478     0.3107         46
#   romantic           0.4118     0.2658     0.3231         79
#   sad                0.4105     0.5652     0.4756         69
#   macro avg          0.4632     0.4563     0.4509        259
#
# --- SGD ---
#   Accuracy   : 0.4247
#   F1-macro   : 0.4051
#   F1-weighted: 0.4182
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6806     0.7538     0.7153         65
#   happy              0.2041     0.2174     0.2105         46
#   romantic           0.4146     0.4304     0.4224         79
#   sad                0.3036     0.2464     0.2720         69
#   macro avg          0.4007     0.4120     0.4051        259
#
# --- Naive Bayes ---
#   Accuracy   : 0.5174
#   F1-macro   : 0.4978
#   F1-weighted: 0.5098
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6582     0.8000     0.7222         65
#   happy              0.3043     0.3043     0.3043         46
#   romantic           0.5161     0.4051     0.4539         79
#   sad                0.5000     0.5217     0.5106         69
#   macro avg          0.4947     0.5078     0.4978        259
#
# --- Ridge ---
#   Accuracy   : 0.5058
#   F1-macro   : 0.4826
#   F1-weighted: 0.4924
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6835     0.8308     0.7500         65
#   happy              0.2826     0.2826     0.2826         46
#   romantic           0.4902     0.3165     0.3846         79
#   sad                0.4699     0.5652     0.5132         69
#   macro avg          0.4816     0.4988     0.4826        259
#
# ======================================================================
#   STRATEGY: REMOVE_OTHER+UNDERSAMPLE
# ======================================================================
#
# --- LightGBM ---
#   Accuracy   : 0.5405
#   F1-macro   : 0.5263
#   F1-weighted: 0.5359
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7612     0.7846     0.7727         65
#   happy              0.3333     0.3478     0.3404         46
#   romantic           0.5357     0.3797     0.4444         79
#   sad                0.4886     0.6232     0.5478         69
#   macro avg          0.5297     0.5338     0.5263        259
#
# --- Gradient Boosting ---
#   Accuracy   : 0.4942
#   F1-macro   : 0.4740
#   F1-weighted: 0.4889
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7463     0.7692     0.7576         65
#   happy              0.2222     0.2174     0.2198         46
#   romantic           0.4308     0.3544     0.3889         79
#   sad                0.4878     0.5797     0.5298         69
#   macro avg          0.4718     0.4802     0.4740        259
#
# --- Decision Tree ---
#   Accuracy   : 0.4826
#   F1-macro   : 0.4781
#   F1-weighted: 0.4866
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7460     0.7231     0.7344         65
#   happy              0.2857     0.3478     0.3137         46
#   romantic           0.3956     0.4557     0.4235         79
#   sad                0.5306     0.3768     0.4407         69
#   macro avg          0.4895     0.4759     0.4781        259
#
# --- SGD ---
#   Accuracy   : 0.4517
#   F1-macro   : 0.4426
#   F1-weighted: 0.4466
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7097     0.6769     0.6929         65
#   happy              0.2586     0.3261     0.2885         46
#   romantic           0.3725     0.2405     0.2923         79
#   sad                0.4432     0.5652     0.4968         69
#   macro avg          0.4460     0.4522     0.4426        259
#
# --- Naive Bayes ---
#   Accuracy   : 0.5097
#   F1-macro   : 0.4745
#   F1-weighted: 0.4949
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6375     0.7846     0.7034         65
#   happy              0.2667     0.1739     0.2105         46
#   romantic           0.4706     0.5063     0.4878         79
#   sad                0.5156     0.4783     0.4962         69
#   macro avg          0.4726     0.4858     0.4745        259
#
# --- Ridge ---
#   Accuracy   : 0.5135
#   F1-macro   : 0.4851
#   F1-weighted: 0.5006
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6420     0.8000     0.7123         65
#   happy              0.2683     0.2391     0.2529         46
#   romantic           0.5577     0.3671     0.4427         79
#   sad                0.4824     0.5942     0.5325         69
#   macro avg          0.4876     0.5001     0.4851        259

# %%
# ── Overall leaderboard: top 10 experiments ──────────────────────────────
leaderboard = summary.sort_values("F1-macro", ascending=False).head(10).reset_index(drop=True)
leaderboard.index += 1
print("Top 10 experiments overall:")
display(leaderboard.style
    .format({"Accuracy": "{:.4f}", "F1-macro": "{:.4f}", "F1-weighted": "{:.4f}"})
    .bar(subset=["F1-macro"], color="#2ecc71", vmin=0, vmax=1)
    .set_caption("Top 10 — sorted by F1-macro"))
# Out:
# Top 10 experiments overall:
# <style type="text/css">
# #T_60dc6_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 53.0%, transparent 53.0%);
# }
# #T_60dc6_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 52.6%, transparent 52.6%);
# }
# #T_60dc6_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 52.1%, transparent 52.1%);
# }
# #T_60dc6_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 50.3%, transparent 50.3%);
# }
# #T_60dc6_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 49.9%, transparent 49.9%);
# }
# #T_60dc6_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 49.8%, transparent 49.8%);
# }
# #T_60dc6_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 48.5%, transparent 48.5%);
# }
# #T_60dc6_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 48.3%, transparent 48.3%);
# }
# #T_60dc6_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 47.9%, transparent 47.9%);
# }
# #T_60dc6_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 47.8%, transparent 47.8%);
# }
# </style>
# <table id="T_60dc6">
#   <caption>Top 10 — sorted by F1-macro</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60dc6_level0_col0" class="col_heading level0 col0" >Strategy</th>
#       <th id="T_60dc6_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_60dc6_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#       <th id="T_60dc6_level0_col3" class="col_heading level0 col3" >F1-macro</th>
#       <th id="T_60dc6_level0_col4" class="col_heading level0 col4" >F1-weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60dc6_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_60dc6_row0_col0" class="data row0 col0" >remove_other</td>
#       <td id="T_60dc6_row0_col1" class="data row0 col1" >LightGBM</td>
#       <td id="T_60dc6_row0_col2" class="data row0 col2" >0.5521</td>
#       <td id="T_60dc6_row0_col3" class="data row0 col3" >0.5296</td>
#       <td id="T_60dc6_row0_col4" class="data row0 col4" >0.5417</td>
#     </tr>
#     <tr>
#       <th id="T_60dc6_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_60dc6_row1_col0" class="data row1 col0" >remove_other+undersample</td>
#       <td id="T_60dc6_row1_col1" class="data row1 col1" >LightGBM</td>
#       <td id="T_60dc6_row1_col2" class="data row1 col2" >0.5405</td>
#       <td id="T_60dc6_row1_col3" class="data row1 col3" >0.5263</td>
#       <td id="T_60dc6_row1_col4" class="data row1 col4" >0.5359</td>
#     </tr>
#     <tr>
#       <th id="T_60dc6_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_60dc6_row2_col0" class="data row2 col0" >remove_other+oversample</td>
#       <td id="T_60dc6_row2_col1" class="data row2 col1" >Gradient Boosting</td>
#       <td id="T_60dc6_row2_col2" class="data row2 col2" >0.5405</td>
#       <td id="T_60dc6_row2_col3" class="data row2 col3" >0.5213</td>
#       <td id="T_60dc6_row2_col4" class="data row2 col4" >0.5330</td>
#     </tr>
#     <tr>
#       <th id="T_60dc6_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_60dc6_row3_col0" class="data row3 col0" >remove_other+oversample</td>
#       <td id="T_60dc6_row3_col1" class="data row3 col1" >LightGBM</td>
#       <td id="T_60dc6_row3_col2" class="data row3 col2" >0.5212</td>
#       <td id="T_60dc6_row3_col3" class="data row3 col3" >0.5031</td>
#       <td id="T_60dc6_row3_col4" class="data row3 col4" >0.5129</td>
#     </tr>
#     <tr>
#       <th id="T_60dc6_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_60dc6_row4_col0" class="data row4 col0" >remove_other</td>
#       <td id="T_60dc6_row4_col1" class="data row4 col1" >Gradient Boosting</td>
#       <td id="T_60dc6_row4_col2" class="data row4 col2" >0.5174</td>
#       <td id="T_60dc6_row4_col3" class="data row4 col3" >0.4992</td>
#       <td id="T_60dc6_row4_col4" class="data row4 col4" >0.5100</td>
#     </tr>
#     <tr>
#       <th id="T_60dc6_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_60dc6_row5_col0" class="data row5 col0" >remove_other+oversample</td>
#       <td id="T_60dc6_row5_col1" class="data row5 col1" >Naive Bayes</td>
#       <td id="T_60dc6_row5_col2" class="data row5 col2" >0.5174</td>
#       <td id="T_60dc6_row5_col3" class="data row5 col3" >0.4978</td>
#       <td id="T_60dc6_row5_col4" class="data row5 col4" >0.5098</td>
#     </tr>
#     <tr>
#       <th id="T_60dc6_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_60dc6_row6_col0" class="data row6 col0" >remove_other+undersample</td>
#       <td id="T_60dc6_row6_col1" class="data row6 col1" >Ridge</td>
#       <td id="T_60dc6_row6_col2" class="data row6 col2" >0.5135</td>
#       <td id="T_60dc6_row6_col3" class="data row6 col3" >0.4851</td>
#       <td id="T_60dc6_row6_col4" class="data row6 col4" >0.5006</td>
#     </tr>
#     <tr>
#       <th id="T_60dc6_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_60dc6_row7_col0" class="data row7 col0" >remove_other+oversample</td>
#       <td id="T_60dc6_row7_col1" class="data row7 col1" >Ridge</td>
#       <td id="T_60dc6_row7_col2" class="data row7 col2" >0.5058</td>
#       <td id="T_60dc6_row7_col3" class="data row7 col3" >0.4826</td>
#       <td id="T_60dc6_row7_col4" class="data row7 col4" >0.4924</td>
#     </tr>
#     <tr>
#       <th id="T_60dc6_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_60dc6_row8_col0" class="data row8 col0" >remove_other</td>
#       <td id="T_60dc6_row8_col1" class="data row8 col1" >Decision Tree</td>
#       <td id="T_60dc6_row8_col2" class="data row8 col2" >0.4749</td>
#       <td id="T_60dc6_row8_col3" class="data row8 col3" >0.4791</td>
#       <td id="T_60dc6_row8_col4" class="data row8 col4" >0.4841</td>
#     </tr>
#     <tr>
#       <th id="T_60dc6_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_60dc6_row9_col0" class="data row9 col0" >remove_other+undersample</td>
#       <td id="T_60dc6_row9_col1" class="data row9 col1" >Decision Tree</td>
#       <td id="T_60dc6_row9_col2" class="data row9 col2" >0.4826</td>
#       <td id="T_60dc6_row9_col3" class="data row9 col3" >0.4781</td>
#       <td id="T_60dc6_row9_col4" class="data row9 col4" >0.4866</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ── Impact analysis: removing 'other' class ──────────────────────────────
baseline_f1    = summary[summary.Strategy == "baseline"].set_index("Model")["F1-macro"]
no_other_f1    = summary[summary.Strategy == "remove_other"].set_index("Model")["F1-macro"]
delta = (no_other_f1 - baseline_f1).sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(9, 4))
colors = ["#2ecc71" if v >= 0 else "#e74c3c" for v in delta.values]
ax.barh(delta.index, delta.values, color=colors)
ax.axvline(0, color="black", linewidth=1)
ax.set_xlabel("F1-macro change")
ax.set_title("Impact of Removing 'other' Class on F1-macro\n(green = improvement)")
for i, v in enumerate(delta.values):
    ax.text(v + (0.001 if v >= 0 else -0.001), i,
            f"{v:+.4f}", va="center",
            ha="left" if v >= 0 else "right", fontsize=10)
plt.tight_layout()
plt.show()

print("\nDelta F1-macro (remove_other - baseline):")
print(delta.to_string())
# Out:
# Delta F1-macro (remove_other - baseline):
# Model
# SGD                 0.1457
# Naive Bayes         0.0789
# LightGBM            0.0676
# Ridge               0.0655
# Decision Tree       0.0558
# Gradient Boosting   0.0476

# %%
# ── Impact analysis: sampling strategies vs baseline ─────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for ax, ref_strat, compare_strat, title in [
    (axes[0], "baseline",     "oversample",  "Oversample vs Baseline"),
    (axes[1], "baseline",     "undersample", "Undersample vs Baseline"),
]:
    ref  = summary[summary.Strategy == ref_strat].set_index("Model")["F1-macro"]
    comp = summary[summary.Strategy == compare_strat].set_index("Model")["F1-macro"]
    delta = (comp - ref).sort_values(ascending=False)
    colors = ["#2ecc71" if v >= 0 else "#e74c3c" for v in delta.values]
    ax.barh(delta.index, delta.values, color=colors)
    ax.axvline(0, color="black", linewidth=1)
    ax.set_xlabel("F1-macro change")
    ax.set_title(title)
    for i, v in enumerate(delta.values):
        ax.text(v + (0.001 if v >= 0 else -0.001), i,
                f"{v:+.4f}", va="center",
                ha="left" if v >= 0 else "right", fontsize=9)

plt.suptitle("Sampling Strategy Impact on F1-macro", fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Save summary to CSV ───────────────────────────────────────────────────
summary.to_csv("experiment_results.csv", index=False)
print("Saved to experiment_results.csv")
print()
print("Final summary:")
display(summary.sort_values(["Strategy", "F1-macro"], ascending=[True, False]))
# Out:
# Saved to experiment_results.csv
#
# Final summary:
#                     Strategy              Model  Accuracy  F1-macro  \
# 0                   baseline           LightGBM    0.4903    0.4620
# 1                   baseline  Gradient Boosting    0.4805    0.4516
# 2                   baseline      Decision Tree    0.4383    0.4233
# 5                   baseline              Ridge    0.4708    0.3976
# 4                   baseline        Naive Bayes    0.4545    0.3975
# 3                   baseline                SGD    0.3279    0.3027
# 12                oversample           LightGBM    0.4805    0.4653
# 16                oversample        Naive Bayes    0.4708    0.4434
# 17                oversample              Ridge    0.4481    0.4345
# 15                oversample                SGD    0.4416    0.4260
# 13                oversample  Gradient Boosting    0.4416    0.4243
# 14                oversample      Decision Tree    0.3701    0.3654
# 6               remove_other           LightGBM    0.5521    0.5296
# 7               remove_other  Gradient Boosting    0.5174    0.4992
# 8               remove_other      Decision Tree    0.4749    0.4791
# 10              remove_other        Naive Bayes    0.5290    0.4764
# 11              remove_other              Ridge    0.5290    0.4631
# 9               remove_other                SGD    0.4633    0.4484
# 25   remove_other+oversample  Gradient Boosting    0.5405    0.5213
# 24   remove_other+oversample           LightGBM    0.5212    0.5031
# 28   remove_other+oversample        Naive Bayes    0.5174    0.4978
# 29   remove_other+oversample              Ridge    0.5058    0.4826
# 26   remove_other+oversample      Decision Tree    0.4556    0.4509
# 27   remove_other+oversample                SGD    0.4247    0.4051
# 30  remove_other+undersample           LightGBM    0.5405    0.5263
# 35  remove_other+undersample              Ridge    0.5135    0.4851
# 32  remove_other+undersample      Decision Tree    0.4826    0.4781
# 34  remove_other+undersample        Naive Bayes    0.5097    0.4745
# 31  remove_other+undersample  Gradient Boosting    0.4942    0.4740
# 33  remove_other+undersample                SGD    0.4517    0.4426
# 18               undersample           LightGBM    0.4416    0.4325
# 22               undersample        Naive Bayes    0.4740    0.4312
# 23               undersample              Ridge    0.4448    0.4291
# 20               undersample      Decision Tree    0.4221    0.4238
# 19               undersample  Gradient Boosting    0.4058    0.3978
# 21               undersample                SGD    0.3929    0.3839
#
#     F1-weighted
# 0        0.4783
# 1        0.4700
# 2        0.4378
# 5        0.4265
# 4        0.4234
# 3        0.3100
# 12       0.4760
# 16       0.4572
# 17       0.4409
# 15       0.4345
# 13       0.4365
# 14       0.3759
# 6        0.5417
# 7        0.5100
# 8        0.4841
# 10       0.5035
# 11       0.4920
# 9        0.4546
# 25       0.5330
# 24       0.5129
# 28       0.5098
# 29       0.4924
# 26       0.4547
# 27       0.4182
# 30       0.5359
# 35       0.5006
# 32       0.4866
# 34       0.4949
# 31       0.4889
# 33       0.4466
# 18       0.4406
# 22       0.4548
# 23       0.4397
# 20       0.4311
# 19       0.4044
# 21       0.3897

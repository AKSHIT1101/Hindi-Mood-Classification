# %% [markdown]
# # Hindi Song Mood Classifier — Experiment Grid
# ### Comparing models × sampling strategies
# **Models:** XGBoost, SVM, Logistic Regression, KNN, Random Forest
# **Strategies:** Baseline · Remove 'other' · Oversample (SMOTE) · Undersample · Remove+Oversample · Remove+Undersample
# **Total experiments:** 30 combinations

# %%
# Run once to install dependencies
# !pip install xgboost imbalanced-learn scikit-learn pandas matplotlib seaborn openpyxl

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from itertools import product

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import (classification_report, confusion_matrix,
                              accuracy_score, f1_score)
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as ImbPipeline

from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier

from sklearn.linear_model import RidgeClassifier, LogisticRegression
from sklearn.ensemble import ExtraTreesClassifier, AdaBoostClassifier, StackingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier

RANDOM_STATE = 42
pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:.4f}".format)
print("All imports OK")
# Out:
# All imports OK

# %%
# ── Load dataset ──────────────────────────────────────────────────────────
EXCEL_PATH = "scaled_features.xlsx"
TARGET_COL = "FINAL MOOD"

META_COLS = ["ID", "Song Title", "Film / Album", "Year",
             "ChatGPT Mood", "Claude Mood", "deepseek/copilot Mood",
             "FINAL MOOD", "Test", "File name"]

df = pd.read_excel(EXCEL_PATH)
FEATURE_COLS = [c for c in df.columns if c not in META_COLS]

print(f"Dataset shape   : {df.shape}")
print(f"Feature columns : {len(FEATURE_COLS)}")
print()
print("Class distribution:")
print(df[TARGET_COL].value_counts().to_string())
# Out:
# Dataset shape   : (1538, 66)
# Feature columns : 56
#
# Class distribution:
# FINAL MOOD
# romantic    395
# sad         344
# excited     321
# other       247
# happy       231

# %%
# ── Class distribution visualisation ─────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

counts = df[TARGET_COL].value_counts()
colors = ["#e74c3c", "#e67e22", "#3498db", "#2ecc71", "#9b59b6"]

axes[0].bar(counts.index, counts.values, color=colors)
axes[0].set_title("Full Dataset — Class Distribution", fontsize=13)
axes[0].set_xlabel("Mood"); axes[0].set_ylabel("Count")
for i, (cls, v) in enumerate(counts.items()):
    axes[0].text(i, v + 3, str(v), ha="center", fontsize=10, fontweight="bold")

counts_no_other = df.loc[df[TARGET_COL] != "other", TARGET_COL].value_counts()
axes[1].bar(counts_no_other.index, counts_no_other.values, color=colors[:4])
axes[1].set_title("Without 'other' Class", fontsize=13)
axes[1].set_xlabel("Mood"); axes[1].set_ylabel("Count")
for i, (cls, v) in enumerate(counts_no_other.items()):
    axes[1].text(i, v + 3, str(v), ha="center", fontsize=10, fontweight="bold")

plt.suptitle("Class Imbalance Overview", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Feature selection: drop low-variance + highly correlated ──────────────
from sklearn.preprocessing import MinMaxScaler

def drop_low_variance(X_df, threshold=0.01):
    scaled = pd.DataFrame(MinMaxScaler().fit_transform(X_df), columns=X_df.columns)
    return [c for c in scaled.columns if scaled[c].var() > threshold]

def drop_correlated(X_df, threshold=0.90):
    corr  = X_df.corr().abs()
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
    drop  = {c for c in upper.columns if any(upper[c] > threshold)}
    return [c for c in X_df.columns if c not in drop]

X_full = df[FEATURE_COLS].copy()
keep   = drop_low_variance(X_full)
X_full = X_full[keep]
keep   = drop_correlated(X_full)
X_full = X_full[keep]

print(f"Features after selection: {X_full.shape[1]}  (was {len(FEATURE_COLS)})")

y_full = df[TARGET_COL].values
# Out:
# Features after selection: 35  (was 56)

# %%
# ── Define models and sampling strategies ─────────────────────────────────

MODELS = {
    "Logistic (L1)": LogisticRegression(
        penalty="l1", solver="saga",
        max_iter=1000, class_weight="balanced",
        random_state=RANDOM_STATE),
    "Logistic (ElasticNet)": LogisticRegression(
        penalty="elasticnet", solver="saga",
        l1_ratio=0.5,
        max_iter=1000, class_weight="balanced",
        random_state=RANDOM_STATE),
    "Extra Trees": ExtraTreesClassifier(
        n_estimators=300,
        class_weight="balanced",
        random_state=RANDOM_STATE,
        n_jobs=-1),

    "AdaBoost": AdaBoostClassifier(
        n_estimators=200,
        learning_rate=0.05,
        random_state=RANDOM_STATE),
    "LDA": LinearDiscriminantAnalysis(),

    "QDA": QuadraticDiscriminantAnalysis(),
}

STRATEGIES = [
    "baseline",
    "remove_other",
    "oversample",
    "undersample",
    "remove_other+oversample",
    "remove_other+undersample",
]

print(f"Models     : {list(MODELS.keys())}")
print(f"Strategies : {STRATEGIES}")
print(f"\nTotal experiments : {len(MODELS) * len(STRATEGIES)}")
# Out:
# Models     : ['Logistic (L1)', 'Logistic (ElasticNet)', 'Extra Trees', 'AdaBoost', 'LDA', 'QDA']
# Strategies : ['baseline', 'remove_other', 'oversample', 'undersample', 'remove_other+oversample', 'remove_other+undersample']
#
# Total experiments : 36

# %%
# ── Run all 30 experiments ────────────────────────────────────────────────

def prepare_data(strategy, X, y):
    """Apply sampling strategy and return (X_train, X_test, y_train, y_test, classes)."""
    remove_other = "remove_other" in strategy

    if remove_other:
        mask = y != "other"
        X_use, y_use = X[mask], y[mask]
    else:
        X_use, y_use = X.copy(), y.copy()

    le = LabelEncoder()
    y_enc = le.fit_transform(y_use)

    X_tr, X_te, y_tr, y_te = train_test_split(
        X_use.values, y_enc, test_size=0.2,
        stratify=y_enc, random_state=RANDOM_STATE)

    if "oversample" in strategy:
        sm = SMOTE(random_state=RANDOM_STATE)
        X_tr, y_tr = sm.fit_resample(X_tr, y_tr)
    elif "undersample" in strategy:
        rus = RandomUnderSampler(random_state=RANDOM_STATE)
        X_tr, y_tr = rus.fit_resample(X_tr, y_tr)

    return X_tr, X_te, y_tr, y_te, le


results = []  # list of dicts, one per experiment

for strategy in STRATEGIES:
    X_tr, X_te, y_tr, y_te, le = prepare_data(strategy, X_full, y_full)
    n_classes = len(le.classes_)

    print(f"\n{'='*60}")
    print(f"Strategy: {strategy.upper()}")
    print(f"  Train size: {len(X_tr)}  |  Test size: {len(X_te)}")
    print(f"  Classes: {list(le.classes_)}")
    tr_dist = pd.Series(y_tr).value_counts().to_dict()
    print(f"  Train dist: { {le.classes_[k]: v for k, v in tr_dist.items()} }")

    for model_name, clf in MODELS.items():
        # Wrap in scaling pipeline
        pipe = Pipeline([("sc", StandardScaler()), ("clf", clf)])

        pipe.fit(X_tr, y_tr)
        y_pred = pipe.predict(X_te)

        acc = accuracy_score(y_te, y_pred)
        f1  = f1_score(y_te, y_pred, average="macro")
        f1w = f1_score(y_te, y_pred, average="weighted")

        report = classification_report(
            y_te, y_pred, target_names=le.classes_, output_dict=True)

        results.append({
            "strategy"  : strategy,
            "model"     : model_name,
            "accuracy"  : acc,
            "f1_macro"  : f1,
            "f1_weighted": f1w,
            "report"    : report,
            "y_te"      : y_te,
            "y_pred"    : y_pred,
            "classes"   : list(le.classes_),
            "pipe"      : pipe,
        })

        print(f"  {model_name:<22}: Acc={acc:.4f}  F1-macro={f1:.4f}  F1-weighted={f1w:.4f}")

print("\n✅ All experiments complete.")
# Out:
# ============================================================
# Strategy: BASELINE
#   Train size: 1230  |  Test size: 308
#   Classes: ['excited', 'happy', 'other', 'romantic', 'sad']
#   Train dist: {'romantic': 316, 'sad': 275, 'excited': 257, 'other': 197, 'happy': 185}
#   Logistic (L1)         : Acc=0.4383  F1-macro=0.4292  F1-weighted=0.4388
#   Logistic (ElasticNet) : Acc=0.4448  F1-macro=0.4356  F1-weighted=0.4450
#   Extra Trees           : Acc=0.5065  F1-macro=0.4586  F1-weighted=0.4784
#   AdaBoost              : Acc=0.4253  F1-macro=0.3021  F1-weighted=0.3256
#   LDA                   : Acc=0.4513  F1-macro=0.4228  F1-weighted=0.4420
#   QDA                   : Acc=0.4675  F1-macro=0.4195  F1-weighted=0.4428
#
# ============================================================
# Strategy: REMOVE_OTHER
#   Train size: 1032  |  Test size: 259
#   Classes: ['excited', 'happy', 'romantic', 'sad']
#   Train dist: {'romantic': 316, 'sad': 275, 'excited': 256, 'happy': 185}
#   Logistic (L1)         : Acc=0.5328  F1-macro=0.5228  F1-weighted=0.5223
#   Logistic (ElasticNet) : Acc=0.5290  F1-macro=0.5205  F1-weighted=0.5212
#   Extra Trees           : Acc=0.5483  F1-macro=0.4980  F1-weighted=0.5222
#   AdaBoost              : Acc=0.4788  F1-macro=0.3415  F1-weighted=0.3745
#   LDA                   : Acc=0.5290  F1-macro=0.4962  F1-weighted=0.5170
#   QDA                   : Acc=0.5019  F1-macro=0.4571  F1-weighted=0.4821
#
# ============================================================
# Strategy: OVERSAMPLE
#   Train size: 1580  |  Test size: 308
#   Classes: ['excited', 'happy', 'other', 'romantic', 'sad']
#   Train dist: {'other': 316, 'happy': 316, 'romantic': 316, 'sad': 316, 'excited': 316}
#   Logistic (L1)         : Acc=0.4481  F1-macro=0.4389  F1-weighted=0.4492
#   Logistic (ElasticNet) : Acc=0.4513  F1-macro=0.4412  F1-weighted=0.4520
#   Extra Trees           : Acc=0.4935  F1-macro=0.4711  F1-weighted=0.4818
#   AdaBoost              : Acc=0.4318  F1-macro=0.3716  F1-weighted=0.3961
#   LDA                   : Acc=0.4448  F1-macro=0.4340  F1-weighted=0.4480
#   QDA                   : Acc=0.4058  F1-macro=0.3762  F1-weighted=0.3960
#
# ============================================================
# Strategy: UNDERSAMPLE
#   Train size: 925  |  Test size: 308
#   Classes: ['excited', 'happy', 'other', 'romantic', 'sad']
#   Train dist: {'excited': 185, 'happy': 185, 'other': 185, 'romantic': 185, 'sad': 185}
#   Logistic (L1)         : Acc=0.4481  F1-macro=0.4388  F1-weighted=0.4489
#   Logistic (ElasticNet) : Acc=0.4513  F1-macro=0.4423  F1-weighted=0.4529
#   Extra Trees           : Acc=0.5097  F1-macro=0.4963  F1-weighted=0.5016
#   AdaBoost              : Acc=0.4253  F1-macro=0.3560  F1-weighted=0.3748
#   LDA                   : Acc=0.4383  F1-macro=0.4291  F1-weighted=0.4443
#   QDA                   : Acc=0.3994  F1-macro=0.3777  F1-weighted=0.3926
#
# ============================================================
# Strategy: REMOVE_OTHER+OVERSAMPLE
#   Train size: 1264  |  Test size: 259
#   Classes: ['excited', 'happy', 'romantic', 'sad']
#   Train dist: {'excited': 316, 'romantic': 316, 'sad': 316, 'happy': 316}
#   Logistic (L1)         : Acc=0.5135  F1-macro=0.5058  F1-weighted=0.5063
#   Logistic (ElasticNet) : Acc=0.5135  F1-macro=0.5056  F1-weighted=0.5064
#   Extra Trees           : Acc=0.5290  F1-macro=0.4906  F1-weighted=0.5086
#   AdaBoost              : Acc=0.4981  F1-macro=0.4706  F1-weighted=0.4779
#   LDA                   : Acc=0.5290  F1-macro=0.5212  F1-weighted=0.5303
#   QDA                   : Acc=0.5097  F1-macro=0.4819  F1-weighted=0.5021
#
# ============================================================
# Strategy: REMOVE_OTHER+UNDERSAMPLE
#   Train size: 740  |  Test size: 259
#   Classes: ['excited', 'happy', 'romantic', 'sad']
#   Train dist: {'excited': 185, 'happy': 185, 'romantic': 185, 'sad': 185}
#   Logistic (L1)         : Acc=0.5328  F1-macro=0.5201  F1-weighted=0.5316
#   Logistic (ElasticNet) : Acc=0.5251  F1-macro=0.5130  F1-weighted=0.5229
#   Extra Trees           : Acc=0.5058  F1-macro=0.4895  F1-weighted=0.5018
#   AdaBoost              : Acc=0.5135  F1-macro=0.4797  F1-weighted=0.4932
#   LDA                   : Acc=0.5328  F1-macro=0.5242  F1-weighted=0.5340
#   QDA                   : Acc=0.4749  F1-macro=0.4549  F1-weighted=0.4728
#
# ✅ All experiments complete.

# %%
# ── Summary table: all 30 experiments ────────────────────────────────────
summary = pd.DataFrame([{
    "Strategy"   : r["strategy"],
    "Model"      : r["model"],
    "Accuracy"   : round(r["accuracy"],  4),
    "F1-macro"   : round(r["f1_macro"],  4),
    "F1-weighted": round(r["f1_weighted"],4),
} for r in results])

# Highlight best F1-macro per strategy
def highlight_best(s):
    is_max = s == s.max()
    return ["background-color: #d4edda; font-weight: bold" if v else "" for v in is_max]

display(
    summary.style
    .apply(highlight_best, subset=["F1-macro"], axis=0)
    .format({"Accuracy": "{:.4f}", "F1-macro": "{:.4f}", "F1-weighted": "{:.4f}"})
    .set_caption("All Experiments — Green = best F1-macro per strategy")
)
# Out:
# <style type="text/css">
# #T_e1813_row34_col3 {
#   background-color: #d4edda;
#   font-weight: bold;
# }
# </style>
# <table id="T_e1813">
#   <caption>All Experiments — Green = best F1-macro per strategy</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1813_level0_col0" class="col_heading level0 col0" >Strategy</th>
#       <th id="T_e1813_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_e1813_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#       <th id="T_e1813_level0_col3" class="col_heading level0 col3" >F1-macro</th>
#       <th id="T_e1813_level0_col4" class="col_heading level0 col4" >F1-weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1813_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e1813_row0_col0" class="data row0 col0" >baseline</td>
#       <td id="T_e1813_row0_col1" class="data row0 col1" >Logistic (L1)</td>
#       <td id="T_e1813_row0_col2" class="data row0 col2" >0.4383</td>
#       <td id="T_e1813_row0_col3" class="data row0 col3" >0.4292</td>
#       <td id="T_e1813_row0_col4" class="data row0 col4" >0.4388</td>
#     </tr>
#     <tr>
#       <th id="T_e1813_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e1813_row1_col0" class="data row1 col0" >baseline</td>
#       <td id="T_e1813_row1_col1" class="data row1 col1" >Logistic (ElasticNet)</td>
#       <td id="T_e1813_row1_col2" class="data row1 col2" >0.4448</td>
#       <td id="T_e1813_row1_col3" class="data row1 col3" >0.4356</td>
#       <td id="T_e1813_row1_col4" class="data row1 col4" >0.4450</td>
#     </tr>
#     <tr>
#       <th id="T_e1813_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e1813_row2_col0" class="data row2 col0" >baseline</td>
#       <td id="T_e1813_row2_col1" class="data row2 col1" >Extra Trees</td>
#       <td id="T_e1813_row2_col2" class="data row2 col2" >0.5065</td>
#       <td id="T_e1813_row2_col3" class="data row2 col3" >0.4586</td>
#       <td id="T_e1813_row2_col4" class="data row2 col4" >0.4784</td>
#     </tr>
#     <tr>
#       <th id="T_e1813_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e1813_row3_col0" class="data row3 col0" >baseline</td>
#       <td id="T_e1813_row3_col1" class="data row3 col1" >AdaBoost</td>
#       <td id="T_e1813_row3_col2" class="data row3 col2" >0.4253</td>
#       <td id="T_e1813_row3_col3" class="data row3 col3" >0.3021</td>
#       <td id="T_e1813_row3_col4" class="data row3 col4" >0.3256</td>
#     </tr>
#     <tr>
#       <th id="T_e1813_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e1813_row4_col0" class="data row4 col0" >baseline</td>
#       <td id="T_e1813_row4_col1" class="data row4 col1" >LDA</td>
#       <td id="T_e1813_row4_col2" class="data row4 col2" >0.4513</td>
#       <td id="T_e1813_row4_col3" class="data row4 col3" >0.4228</td>
#       <td id="T_e1813_row4_col4" class="data row4 col4" >0.4420</td>
#     </tr>
#     <tr>
#       <th id="T_e1813_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e1813_row5_col0" class="data row5 col0" >baseline</td>
#       <td id="T_e1813_row5_col1" class="data row5 col1" >QDA</td>
#       <td id="T_e1813_row5_col2" class="data row5 col2" >0.4675</td>
#       <td id="T_e1813_row5_col3" class="data row5 col3" >0.4195</td>
#       <td id="T_e1813_row5_col4" class="data row5 col4" >0.4428</td>
#     </tr>
#     <tr>
#       <th id="T_e1813_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e1813_row6_col0" class="data row6 col0" >remove_other</td>
#       <td id="T_e1813_row6_col1" class="data row6 col1" >Logistic (L1)</td>
#       <td id="T_e1813_row6_col2" class="data row6 col2" >0.5328</td>
#       <td id="T_e1813_row6_col3" class="data row6 col3" >0.5228</td>
#       <td id="T_e1813_row6_col4" class="data row6 col4" >0.5223</td>
#     </tr>
#     <tr>
#       <th id="T_e1813_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e1813_row7_col0" class="data row7 col0" >remove_other</td>
#       <td id="T_e1813_row7_col1" class="data row7 col1" >Logistic (ElasticNet)</td>
#       <td id="T_e1813_row7_col2" class="data row7 col2" >0.5290</td>
#       <td id="T_e1813_row7_col3" class="data row7 col3" >0.5205</td>
#       <td id="T_e1813_row7_col4" class="data row7 col4" >0.5212</td>
#     </tr>
#     <tr>
#       <th id="T_e1813_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e1813_row8_col0" class="data row8 col0" >remove_other</td>
#       <td id="T_e1813_row8_col1" class="data row8 col1" >Extra Trees</td>
#       <td id="T_e1813_row8_col2" class="data row8 col2" >0.5483</td>
#       <td id="T_e1813_row8_col3" class="data row8 col3" >0.4980</td>
#       <td id="T_e1813_row8_col4" class="data row8 col4" >0.5222</td>
#     </tr>
#     <tr>
#       <th id="T_e1813_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e1813_row9_col0" class="data row9 col0" >remove_other</td>
#       <td id="T_e1813_row9_col1" class="data row9 col1" >AdaBoost</td>
#       <td id="T_e1813_row9_col2" class="data row9 col2" >0.4788</td>
#       <td id="T_e1813_row9_col3" class="data row9 col3" >0.3415</td>
#       <td id="T_e1813_row9_col4" class="data row9 col4" >0.3745</td>
#     </tr>
#     <tr>
#       <th id="T_e1813_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e1813_row10_col0" class="data row10 col0" >remove_other</td>
#       <td id="T_e1813_row10_col1" class="data row10 col1" >LDA</td>
#       <td id="T_e1813_row10_col2" class="data row10 col2" >0.5290</td>
#       <td id="T_e1813_row10_col3" class="data row10 col3" >0.4962</td>
#       <td id="T_e1813_row10_col4" class="data row10 col4" >0.5170</td>
#     </tr>
#     <tr>
#       <th id="T_e1813_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e1813_row11_col0" class="data row11 col0" >remove_other</td>
#       <td id="T_e1813_row11_col1" class="data row11 col1" >QDA</td>
#       <td id="T_e1813_row11_col2" class="data row11 col2" >0.5019</td>
#       <td id="T_e1813_row11_col3" class="data row11 col3" >0.4571</td>
#       <td id="T_e1813_row11_col4" class="data row11 col4" >0.4821</td>
#     </tr>
#     <tr>
#       <th id="T_e1813_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e1813_row12_col0" class="data row12 col0" >oversample</td>
#       <td id="T_e1813_row12_col1" class="data row12 col1" >Logistic (L1)</td>
#       <td id="T_e1813_row12_col2" class="data row12 col2" >0.4481</td>
#       <td id="T_e1813_row12_col3" class="data row12 col3" >0.4389</td>
#       <td id="T_e1813_row12_col4" class="data row12 col4" >0.4492</td>
#     </tr>
#     <tr>
#       <th id="T_e1813_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e1813_row13_col0" class="data row13 col0" >oversample</td>
#       <td id="T_e1813_row13_col1" class="data row13 col1" >Logistic (ElasticNet)</td>
#       <td id="T_e1813_row13_col2" class="data row13 col2" >0.4513</td>
#       <td id="T_e1813_row13_col3" class="data row13 col3" >0.4412</td>
#       <td id="T_e1813_row13_col4" class="data row13 col4" >0.4520</td>
#     </tr>
#     <tr>
#       <th id="T_e1813_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e1813_row14_col0" class="data row14 col0" >oversample</td>
#       <td id="T_e1813_row14_col1" class="data row14 col1" >Extra Trees</td>
#       <td id="T_e1813_row14_col2" class="data row14 col2" >0.4935</td>
#       <td id="T_e1813_row14_col3" class="data row14 col3" >0.4711</td>
#       <td id="T_e1813_row14_col4" class="data row14 col4" >0.4818</td>
#     </tr>
#     <tr>
#       <th id="T_e1813_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e1813_row15_col0" class="data row15 col0" >oversample</td>
#       <td id="T_e1813_row15_col1" class="data row15 col1" >AdaBoost</td>
#       <td id="T_e1813_row15_col2" class="data row15 col2" >0.4318</td>
#       <td id="T_e1813_row15_col3" class="data row15 col3" >0.3716</td>
#       <td id="T_e1813_row15_col4" class="data row15 col4" >0.3961</td>
#     </tr>
#     <tr>
#       <th id="T_e1813_level0_row16" class="r

# %%
# ── Best model per strategy ───────────────────────────────────────────────
best_per_strategy = (
    summary.sort_values("F1-macro", ascending=False)
           .groupby("Strategy").first()
           .reset_index()
           [["Strategy", "Model", "Accuracy", "F1-macro", "F1-weighted"]]
           .sort_values("F1-macro", ascending=False)
)

print("Best model per strategy (sorted by F1-macro):")
display(best_per_strategy.style.format({
    "Accuracy": "{:.4f}", "F1-macro": "{:.4f}", "F1-weighted": "{:.4f}"}))
# Out:
# Best model per strategy (sorted by F1-macro):
# <style type="text/css">
# </style>
# <table id="T_af03a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af03a_level0_col0" class="col_heading level0 col0" >Strategy</th>
#       <th id="T_af03a_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_af03a_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#       <th id="T_af03a_level0_col3" class="col_heading level0 col3" >F1-macro</th>
#       <th id="T_af03a_level0_col4" class="col_heading level0 col4" >F1-weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af03a_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_af03a_row0_col0" class="data row0 col0" >remove_other+undersample</td>
#       <td id="T_af03a_row0_col1" class="data row0 col1" >LDA</td>
#       <td id="T_af03a_row0_col2" class="data row0 col2" >0.5328</td>
#       <td id="T_af03a_row0_col3" class="data row0 col3" >0.5242</td>
#       <td id="T_af03a_row0_col4" class="data row0 col4" >0.5340</td>
#     </tr>
#     <tr>
#       <th id="T_af03a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_af03a_row1_col0" class="data row1 col0" >remove_other</td>
#       <td id="T_af03a_row1_col1" class="data row1 col1" >Logistic (L1)</td>
#       <td id="T_af03a_row1_col2" class="data row1 col2" >0.5328</td>
#       <td id="T_af03a_row1_col3" class="data row1 col3" >0.5228</td>
#       <td id="T_af03a_row1_col4" class="data row1 col4" >0.5223</td>
#     </tr>
#     <tr>
#       <th id="T_af03a_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_af03a_row2_col0" class="data row2 col0" >remove_other+oversample</td>
#       <td id="T_af03a_row2_col1" class="data row2 col1" >LDA</td>
#       <td id="T_af03a_row2_col2" class="data row2 col2" >0.5290</td>
#       <td id="T_af03a_row2_col3" class="data row2 col3" >0.5212</td>
#       <td id="T_af03a_row2_col4" class="data row2 col4" >0.5303</td>
#     </tr>
#     <tr>
#       <th id="T_af03a_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_af03a_row3_col0" class="data row3 col0" >undersample</td>
#       <td id="T_af03a_row3_col1" class="data row3 col1" >Extra Trees</td>
#       <td id="T_af03a_row3_col2" class="data row3 col2" >0.5097</td>
#       <td id="T_af03a_row3_col3" class="data row3 col3" >0.4963</td>
#       <td id="T_af03a_row3_col4" class="data row3 col4" >0.5016</td>
#     </tr>
#     <tr>
#       <th id="T_af03a_level0_row4" class="row_heading level0 row4" >1</th>
#       <td id="T_af03a_row4_col0" class="data row4 col0" >oversample</td>
#       <td id="T_af03a_row4_col1" class="data row4 col1" >Extra Trees</td>
#       <td id="T_af03a_row4_col2" class="data row4 col2" >0.4935</td>
#       <td id="T_af03a_row4_col3" class="data row4 col3" >0.4711</td>
#       <td id="T_af03a_row4_col4" class="data row4 col4" >0.4818</td>
#     </tr>
#     <tr>
#       <th id="T_af03a_level0_row5" class="row_heading level0 row5" >0</th>
#       <td id="T_af03a_row5_col0" class="data row5 col0" >baseline</td>
#       <td id="T_af03a_row5_col1" class="data row5 col1" >Extra Trees</td>
#       <td id="T_af03a_row5_col2" class="data row5 col2" >0.5065</td>
#       <td id="T_af03a_row5_col3" class="data row5 col3" >0.4586</td>
#       <td id="T_af03a_row5_col4" class="data row5 col4" >0.4784</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ── Heatmap: F1-macro for all model × strategy combinations ───────────────
pivot = summary.pivot(index="Model", columns="Strategy", values="F1-macro")
# Order strategies sensibly
col_order = [c for c in STRATEGIES if c in pivot.columns]
pivot = pivot[col_order]

fig, ax = plt.subplots(figsize=(14, 5))
sns.heatmap(pivot, annot=True, fmt=".3f", cmap="YlGn",
            linewidths=0.5, linecolor="white",
            annot_kws={"size": 11}, ax=ax,
            vmin=pivot.values.min() - 0.02,
            vmax=pivot.values.max() + 0.01)
ax.set_title("F1-macro Heatmap: Model × Sampling Strategy", fontsize=14, pad=12)
ax.set_xlabel("Strategy", fontsize=11)
ax.set_ylabel("Model", fontsize=11)
plt.xticks(rotation=25, ha="right")
plt.tight_layout()
plt.show()

# %%
# ── Heatmap: Accuracy ─────────────────────────────────────────────────────
pivot_acc = summary.pivot(index="Model", columns="Strategy", values="Accuracy")[col_order]

fig, ax = plt.subplots(figsize=(14, 5))
sns.heatmap(pivot_acc, annot=True, fmt=".3f", cmap="Blues",
            linewidths=0.5, linecolor="white",
            annot_kws={"size": 11}, ax=ax)
ax.set_title("Accuracy Heatmap: Model × Sampling Strategy", fontsize=14, pad=12)
ax.set_xlabel("Strategy", fontsize=11)
ax.set_ylabel("Model", fontsize=11)
plt.xticks(rotation=25, ha="right")
plt.tight_layout()
plt.show()

# %%
# ── Grouped bar: F1-macro per model across strategies ─────────────────────
fig, ax = plt.subplots(figsize=(15, 6))
model_names = list(MODELS.keys())
x = np.arange(len(model_names))
n_strat = len(STRATEGIES)
width = 0.13
colors_strat = plt.cm.Set2(np.linspace(0, 1, n_strat))

for i, strat in enumerate(STRATEGIES):
    vals = [summary.loc[(summary.Model == m) & (summary.Strategy == strat),
                        "F1-macro"].values[0] for m in model_names]
    offset = (i - n_strat / 2) * width + width / 2
    bars = ax.bar(x + offset, vals, width, label=strat, color=colors_strat[i])

ax.set_xlabel("Model", fontsize=12)
ax.set_ylabel("F1-macro", fontsize=12)
ax.set_title("F1-macro by Model and Sampling Strategy", fontsize=14)
ax.set_xticks(x); ax.set_xticklabels(model_names, fontsize=11)
ax.set_ylim(0, 1)
ax.legend(title="Strategy", bbox_to_anchor=(1.01, 1), loc="upper left", fontsize=9)
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# ── Per-class F1 breakdown for best experiment per strategy ───────────────
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

for ax_idx, strat in enumerate(STRATEGIES):
    # Find best model for this strategy
    strat_results = [r for r in results if r["strategy"] == strat]
    best = max(strat_results, key=lambda r: r["f1_macro"])
    classes = best["classes"]
    report  = best["report"]

    class_f1 = {cls: report[cls]["f1-score"] for cls in classes}
    mood_colors = {
        "happy":    "#2ecc71",
        "sad":      "#3498db",
        "romantic": "#e74c3c",
        "excited":  "#e67e22",
        "other":    "#95a5a6",
    }
    bar_colors = [mood_colors.get(c, "#7f8c8d") for c in class_f1]

    bars = axes[ax_idx].bar(class_f1.keys(), class_f1.values(), color=bar_colors)
    axes[ax_idx].set_title(
        f"{strat}\nBest: {best['model']}  (F1-macro={best['f1_macro']:.3f})",
        fontsize=10, fontweight="bold")
    axes[ax_idx].set_ylim(0, 1)
    axes[ax_idx].set_ylabel("F1-score")
    axes[ax_idx].axhline(best["f1_macro"], color="black",
                          linestyle="--", linewidth=1, alpha=0.5, label="macro avg")
    axes[ax_idx].legend(fontsize=8)
    for bar, (cls, val) in zip(bars, class_f1.items()):
        axes[ax_idx].text(bar.get_x() + bar.get_width()/2,
                           val + 0.01, f"{val:.2f}",
                           ha="center", va="bottom", fontsize=9)

plt.suptitle("Per-class F1 for Best Model per Strategy", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Confusion matrices for best model per strategy ────────────────────────
fig, axes = plt.subplots(2, 3, figsize=(18, 11))
axes = axes.flatten()

for ax_idx, strat in enumerate(STRATEGIES):
    strat_results = [r for r in results if r["strategy"] == strat]
    best = max(strat_results, key=lambda r: r["f1_macro"])

    cm   = confusion_matrix(best["y_te"], best["y_pred"])
    cm_n = cm.astype(float) / cm.sum(axis=1, keepdims=True)

    sns.heatmap(cm_n, annot=True, fmt=".2f", cmap="Blues",
                xticklabels=best["classes"], yticklabels=best["classes"],
                ax=axes[ax_idx], linewidths=0.3)
    axes[ax_idx].set_title(
        f"{strat}\n{best['model']}  Acc={best['accuracy']:.3f}",
        fontsize=10, fontweight="bold")
    axes[ax_idx].set_xlabel("Predicted"); axes[ax_idx].set_ylabel("Actual")

plt.suptitle("Confusion Matrices — Best Model per Strategy (normalised)",
             fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Full classification reports for every experiment ─────────────────────
for strat in STRATEGIES:
    print("\n" + "="*70)
    print(f"  STRATEGY: {strat.upper()}")
    print("="*70)
    for r in [x for x in results if x["strategy"] == strat]:
        print(f"\n--- {r['model']} ---")
        print(f"  Accuracy   : {r['accuracy']:.4f}")
        print(f"  F1-macro   : {r['f1_macro']:.4f}")
        print(f"  F1-weighted: {r['f1_weighted']:.4f}")
        rpt = r["report"]
        header = f"{'Class':<14} {'Precision':>10} {'Recall':>10} {'F1':>10} {'Support':>10}"
        print("  " + header)
        print("  " + "-"*len(header))
        for cls in r["classes"]:
            row = rpt[cls]
            print(f"  {cls:<14} {row['precision']:>10.4f} {row['recall']:>10.4f} "
                  f"{row['f1-score']:>10.4f} {int(row['support']):>10}")
        print(f"  {'macro avg':<14} {rpt['macro avg']['precision']:>10.4f} "
              f"{rpt['macro avg']['recall']:>10.4f} "
              f"{rpt['macro avg']['f1-score']:>10.4f} "
              f"{int(rpt['macro avg']['support']):>10}")
# Out:
# ======================================================================
#   STRATEGY: BASELINE
# ======================================================================
#
# --- Logistic (L1) ---
#   Accuracy   : 0.4383
#   F1-macro   : 0.4292
#   F1-weighted: 0.4388
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6912     0.7344     0.7121         64
#   happy              0.2281     0.2826     0.2524         46
#   other              0.3729     0.4400     0.4037         50
#   romantic           0.4677     0.3671     0.4113         79
#   sad                0.3871     0.3478     0.3664         69
#   macro avg          0.4294     0.4344     0.4292        308
#
# --- Logistic (ElasticNet) ---
#   Accuracy   : 0.4448
#   F1-macro   : 0.4356
#   F1-weighted: 0.4450
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6912     0.7344     0.7121         64
#   happy              0.2321     0.2826     0.2549         46
#   other              0.3898     0.4600     0.4220         50
#   romantic           0.4762     0.3797     0.4225         79
#   sad                0.3871     0.3478     0.3664         69
#   macro avg          0.4353     0.4409     0.4356        308
#
# --- Extra Trees ---
#   Accuracy   : 0.5065
#   F1-macro   : 0.4586
#   F1-weighted: 0.4784
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6190     0.8125     0.7027         64
#   happy              0.5000     0.1087     0.1786         46
#   other              0.6071     0.3400     0.4359         50
#   romantic           0.4202     0.6329     0.5051         79
#   sad                0.4776     0.4638     0.4706         69
#   macro avg          0.5248     0.4716     0.4586        308
#
# --- AdaBoost ---
#   Accuracy   : 0.4253
#   F1-macro   : 0.3021
#   F1-weighted: 0.3256
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5506     0.7656     0.6405         64
#   happy              0.0000     0.0000     0.0000         46
#   other              0.3333     0.3000     0.3158         50
#   romantic           0.3837     0.8354     0.5259         79
#   sad                0.5000     0.0145     0.0282         69
#   macro avg          0.3535     0.3831     0.3021        308
#
# --- LDA ---
#   Accuracy   : 0.4513
#   F1-macro   : 0.4228
#   F1-weighted: 0.4420
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6912     0.7344     0.7121         64
#   happy              0.2353     0.1739     0.2000         46
#   other              0.3556     0.3200     0.3368         50
#   romantic           0.4343     0.5443     0.4831         79
#   sad                0.4032     0.3623     0.3817         69
#   macro avg          0.4239     0.4270     0.4228        308
#
# --- QDA ---
#   Accuracy   : 0.4675
#   F1-macro   : 0.4195
#   F1-weighted: 0.4428
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6438     0.7344     0.6861         64
#   happy              0.1579     0.0652     0.0923         46
#   other              0.4419     0.3800     0.4086         50
#   romantic           0.4080     0.6456     0.5000         79
#   sad                0.5000     0.3478     0.4103         69
#   macro avg          0.4303     0.4346     0.4195        308
#
# ======================================================================
#   STRATEGY: REMOVE_OTHER
# ======================================================================
#
# --- Logistic (L1) ---
#   Accuracy   : 0.5328
#   F1-macro   : 0.5228
#   F1-weighted: 0.5223
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7647     0.8000     0.7820         65
#   happy              0.3922     0.4348     0.4124         46
#   romantic           0.4694     0.2911     0.3594         79
#   sad                0.4725     0.6232     0.5375         69
#   macro avg          0.5247     0.5373     0.5228        259
#
# --- Logistic (ElasticNet) ---
#   Accuracy   : 0.5290
#   F1-macro   : 0.5205
#   F1-weighted: 0.5212
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7536     0.8000     0.7761         65
#   happy              0.3846     0.4348     0.4082         46
#   romantic           0.4808     0.3165     0.3817         79
#   sad                0.4651     0.5797     0.5161         69
#   macro avg          0.5210     0.5327     0.5205        259
#
# --- Extra Trees ---
#   Accuracy   : 0.5483
#   F1-macro   : 0.4980
#   F1-weighted: 0.5222
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7286     0.7846     0.7556         65
#   happy              0.5556     0.1087     0.1818         46
#   romantic           0.4423     0.5823     0.5027         79
#   sad                0.5263     0.5797     0.5517         69
#   macro avg          0.5632     0.5138     0.4980        259
#
# --- AdaBoost ---
#   Accuracy   : 0.4788
#   F1-macro   : 0.3415
#   F1-weighted: 0.3745
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5851     0.8462     0.6918         65
#   happy              0.0000     0.0000     0.0000         46
#   romantic           0.4156     0.8101     0.5494         79
#   sad                0.4545     0.0725     0.1250         69
#   macro avg          0.3638     0.4322     0.3415        259
#
# --- LDA ---
#   Accuracy   : 0.5290
#   F1-macro   : 0.4962
#   F1-weighted: 0.5170
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7463     0.7692     0.7576         65
#   happy              0.3077     0.1739     0.2222         46
#   romantic           0.4681     0.5570     0.5087         79
#   sad                0.4861     0.5072     0.4965         69
#   macro avg          0.5020     0.5018     0.4962        259
#
# --- QDA ---
#   Accuracy   : 0.5019
#   F1-macro   : 0.4571
#   F1-weighted: 0.4821
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7000     0.7538     0.7259         65
#   happy              0.2273     0.1087     0.1471         46
#   romantic           0.4248     0.6076     0.5000         79
#   sad                0.5185     0.4058     0.4553         69
#   macro avg          0.4676     0.4690     0.4571        259
#
# ======================================================================
#   STRATEGY: OVERSAMPLE
# ======================================================================
#
# --- Logistic (L1) ---
#   Accuracy   : 0.4481
#   F1-macro   : 0.4389
#   F1-weighted: 0.4492
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6857     0.7500     0.7164         64
#   happy              0.2131     0.2826     0.2430         46
#   other              0.4107     0.4600     0.4340         50
#   romantic           0.5085     0.3797     0.4348         79
#   sad                0.3871     0.3478     0.3664         69
#   macro avg          0.4410     0.4440     0.4389        308
#
# --- Logistic (ElasticNet) ---
#   Accuracy   : 0.4513
#   F1-macro   : 0.4412
#   F1-weighted: 0.4520
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6901     0.7656     0.7259         64
#   happy              0.2131     0.2826     0.2430         46
#   other              0.4035     0.4600     0.4299         50
#   romantic           0.5172     0.3797     0.4380         79
#   sad                0.3934     0.3478     0.3692         69
#   macro avg          0.4435     0.4472     0.4412        308
#
# --- Extra Trees ---
#   Accuracy   : 0.4935
#   F1-macro   : 0.4711
#   F1-weighted: 0.4818
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6296     0.7969     0.7034         64
#   happy              0.4231     0.2391     0.3056         46
#   other              0.4375     0.4200     0.4286         50
#   romantic           0.4318     0.4810     0.4551         79
#   sad                0.4769     0.4493     0.4627         69
#   macro avg          0.4798     0.4773     0.4711        308
#
# --- AdaBoost ---
#   Accuracy   : 0.4318
#   F1-macro   : 0.3716
#   F1-weighted: 0.3961
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6104     0.7344     0.6667         64
#   happy              0.0000     0.0000     0.0000         46
#   other              0.3333     0.3800     0.3551         50
#   romantic           0.4085     0.3671     0.3867         79
#   sad                0.3800     0.5507     0.4497         69
#   macro avg          0.3464     0.4064     0.3716        308
#
# --- LDA ---
#   Accuracy   : 0.4448
#   F1-macro   : 0.4340
#   F1-weighted: 0.4480
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7121     0.7344     0.7231         64
#   happy              0.2097     0.2826     0.2407         46
#   other              0.3704     0.4000     0.3846         50
#   romantic           0.5000     0.4430     0.4698         79
#   sad                0.3929     0.3188     0.3520         69
#   macro avg          0.4370     0.4358     0.4340        308
#
# --- QDA ---
#   Accuracy   : 0.4058
#   F1-macro   : 0.3762
#   F1-weighted: 0.3960
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6301     0.7188     0.6715         64
#   happy              0.1429     0.1087     0.1235         46
#   other              0.3250     0.2600     0.2889         50
#   romantic           0.3364     0.4557     0.3871         79
#   sad                0.4717     0.3623     0.4098         69
#   macro avg          0.3812     0.3811     0.3762        308
#
# ======================================================================
#   STRATEGY: UNDERSAMPLE
# ======================================================================
#
# --- Logistic (L1) ---
#   Accuracy   : 0.4481
#   F1-macro   : 0.4388
#   F1-weighted: 0.4489
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7015     0.7344     0.7176         64
#   happy              0.2364     0.2826     0.2574         46
#   other              0.3651     0.4600     0.4071         50
#   romantic           0.4912     0.3544     0.4118         79
#   sad                0.4091     0.3913     0.4000         69
#   macro avg          0.4407     0.4445     0.4388        308
#
# --- Logistic (ElasticNet) ---
#   Accuracy   : 0.4513
#   F1-macro   : 0.4423
#   F1-weighted: 0.4529
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7015     0.7344     0.7176         64
#   happy              0.2456     0.3043     0.2718         46
#   other              0.3548     0.4400     0.3929         50
#   romantic           0.4915     0.3671     0.4203         79
#   sad                0.4286     0.3913     0.4091         69
#   macro avg          0.4444     0.4474     0.4423        308
#
# --- Extra Trees ---
#   Accuracy   : 0.5097
#   F1-macro   : 0.4963
#   F1-weighted: 0.5016
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6494     0.7812     0.7092         64
#   happy              0.4054     0.3261     0.3614         46
#   other              0.4355     0.5400     0.4821         50
#   romantic           0.4918     0.3797     0.4286         79
#   sad                0.4930     0.5072     0.5000         69
#   macro avg          0.4950     0.5069     0.4963        308
#
# --- AdaBoost ---
#   Accuracy   : 0.4253
#   F1-macro   : 0.3560
#   F1-weighted: 0.3748
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6154     0.7500     0.6761         64
#   happy              0.0000     0.0000     0.0000         46
#   other              0.3333     0.3800     0.3551         50
#   romantic           0.4324     0.2025     0.2759         79
#   sad                0.3582     0.6957     0.4729         69
#   macro avg          0.3479     0.4056     0.3560        308
#
# --- LDA ---
#   Accuracy   : 0.4383
#   F1-macro   : 0.4291
#   F1-weighted: 0.4443
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7143     0.7031     0.7087         64
#   happy              0.2203     0.2826     0.2476         46
#   other              0.3220     0.3800     0.3486         50
#   romantic           0.5238     0.4177     0.4648         79
#   sad                0.3906     0.3623     0.3759         69
#   macro avg          0.4342     0.4292     0.4291        308
#
# --- QDA ---
#   Accuracy   : 0.3994
#   F1-macro   : 0.3777
#   F1-weighted: 0.3926
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6515     0.6719     0.6615         64
#   happy              0.1316     0.1087     0.1190         46
#   other              0.3559     0.4200     0.3853         50
#   romantic           0.3608     0.4430     0.3977         79
#   sad                0.3958     0.2754     0.3248         69
#   macro avg          0.3791     0.3838     0.3777        308
#
# ======================================================================
#   STRATEGY: REMOVE_OTHER+OVERSAMPLE
# ======================================================================
#
# --- Logistic (L1) ---
#   Accuracy   : 0.5135
#   F1-macro   : 0.5058
#   F1-weighted: 0.5063
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7647     0.8000     0.7820         65
#   happy              0.3509     0.4348     0.3883         46
#   romantic           0.4694     0.2911     0.3594         79
#   sad                0.4471     0.5507     0.4935         69
#   macro avg          0.5080     0.5192     0.5058        259
#
# --- Logistic (ElasticNet) ---
#   Accuracy   : 0.5135
#   F1-macro   : 0.5056
#   F1-weighted: 0.5064
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7647     0.8000     0.7820         65
#   happy              0.3509     0.4348     0.3883         46
#   romantic           0.4894     0.2911     0.3651         79
#   sad                0.4368     0.5507     0.4872         69
#   macro avg          0.5104     0.5192     0.5056        259
#
# --- Extra Trees ---
#   Accuracy   : 0.5290
#   F1-macro   : 0.4906
#   F1-weighted: 0.5086
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7083     0.7846     0.7445         65
#   happy              0.4667     0.1522     0.2295         46
#   romantic           0.4458     0.4684     0.4568         79
#   sad                0.4719     0.6087     0.5316         69
#   macro avg          0.5232     0.5035     0.4906        259
#
# --- AdaBoost ---
#   Accuracy   : 0.4981
#   F1-macro   : 0.4706
#   F1-weighted: 0.4779
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6806     0.7538     0.7153         65
#   happy              0.2766     0.2826     0.2796         46
#   romantic           0.4750     0.2405     0.3193         79
#   sad                0.4800     0.6957     0.5680         69
#   macro avg          0.4780     0.4932     0.4706        259
#
# --- LDA ---
#   Accuracy   : 0.5290
#   F1-macro   : 0.5212
#   F1-weighted: 0.5303
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7692     0.7692     0.7692         65
#   happy              0.3103     0.3913     0.3462         46
#   romantic           0.5345     0.3924     0.4526         79
#   sad                0.4872     0.5507     0.5170         69
#   macro avg          0.5253     0.5259     0.5212        259
#
# --- QDA ---
#   Accuracy   : 0.5097
#   F1-macro   : 0.4819
#   F1-weighted: 0.5021
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7101     0.7538     0.7313         65
#   happy              0.2500     0.1957     0.2195         46
#   romantic           0.4624     0.5443     0.5000         79
#   sad                0.5082     0.4493     0.4769         69
#   macro avg          0.4827     0.4858     0.4819        259
#
# ======================================================================
#   STRATEGY: REMOVE_OTHER+UNDERSAMPLE
# ======================================================================
#
# --- Logistic (L1) ---
#   Accuracy   : 0.5328
#   F1-macro   : 0.5201
#   F1-weighted: 0.5316
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7183     0.7846     0.7500         65
#   happy              0.3036     0.3696     0.3333         46
#   romantic           0.6200     0.3924     0.4806         79
#   sad                0.4756     0.5652     0.5166         69
#   macro avg          0.5294     0.5280     0.5201        259
#
# --- Logistic (ElasticNet) ---
#   Accuracy   : 0.5251
#   F1-macro   : 0.5130
#   F1-weighted: 0.5229
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7143     0.7692     0.7407         65
#   happy              0.3148     0.3696     0.3400         46
#   romantic           0.5882     0.3797     0.4615         79
#   sad                0.4643     0.5652     0.5098         69
#   macro avg          0.5204     0.5209     0.5130        259
#
# --- Extra Trees ---
#   Accuracy   : 0.5058
#   F1-macro   : 0.4895
#   F1-weighted: 0.5018
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7042     0.7692     0.7353         65
#   happy              0.2826     0.2826     0.2826         46
#   romantic           0.4571     0.4051     0.4295         79
#   sad                0.5000     0.5217     0.5106         69
#   macro avg          0.4860     0.4947     0.4895        259
#
# --- AdaBoost ---
#   Accuracy   : 0.5135
#   F1-macro   : 0.4797
#   F1-weighted: 0.4932
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6800     0.7846     0.7286         65
#   happy              0.2703     0.2174     0.2410         46
#   romantic           0.5000     0.3038     0.3780         79
#   sad                0.4848     0.6957     0.5714         69
#   macro avg          0.4838     0.5004     0.4797        259
#
# --- LDA ---
#   Accuracy   : 0.5328
#   F1-macro   : 0.5242
#   F1-weighted: 0.5340
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7576     0.7692     0.7634         65
#   happy              0.3158     0.3913     0.3495         46
#   romantic           0.5614     0.4051     0.4706         79
#   sad                0.4810     0.5507     0.5135         69
#   macro avg          0.5289     0.5291     0.5242        259
#
# --- QDA ---
#   Accuracy   : 0.4749
#   F1-macro   : 0.4549
#   F1-weighted: 0.4728
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6571     0.7077     0.6815         65
#   happy              0.2174     0.2174     0.2174         46
#   romantic           0.4419     0.4810     0.4606         79
#   sad                0.5088     0.4203     0.4603         69
#   macro avg          0.4563     0.4566     0.4549        259

# %%
# ── Overall leaderboard: top 10 experiments ──────────────────────────────
leaderboard = summary.sort_values("F1-macro", ascending=False).head(10).reset_index(drop=True)
leaderboard.index += 1
print("Top 10 experiments overall:")
display(leaderboard.style
    .format({"Accuracy": "{:.4f}", "F1-macro": "{:.4f}", "F1-weighted": "{:.4f}"})
    .bar(subset=["F1-macro"], color="#2ecc71", vmin=0, vmax=1)
    .set_caption("Top 10 — sorted by F1-macro"))
# Out:
# Top 10 experiments overall:
# <style type="text/css">
# #T_b7bd6_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 52.4%, transparent 52.4%);
# }
# #T_b7bd6_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 52.3%, transparent 52.3%);
# }
# #T_b7bd6_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 52.1%, transparent 52.1%);
# }
# #T_b7bd6_row3_col3, #T_b7bd6_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 52.0%, transparent 52.0%);
# }
# #T_b7bd6_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 51.3%, transparent 51.3%);
# }
# #T_b7bd6_row6_col3, #T_b7bd6_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 50.6%, transparent 50.6%);
# }
# #T_b7bd6_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 49.8%, transparent 49.8%);
# }
# #T_b7bd6_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 49.6%, transparent 49.6%);
# }
# </style>
# <table id="T_b7bd6">
#   <caption>Top 10 — sorted by F1-macro</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7bd6_level0_col0" class="col_heading level0 col0" >Strategy</th>
#       <th id="T_b7bd6_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_b7bd6_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#       <th id="T_b7bd6_level0_col3" class="col_heading level0 col3" >F1-macro</th>
#       <th id="T_b7bd6_level0_col4" class="col_heading level0 col4" >F1-weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7bd6_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b7bd6_row0_col0" class="data row0 col0" >remove_other+undersample</td>
#       <td id="T_b7bd6_row0_col1" class="data row0 col1" >LDA</td>
#       <td id="T_b7bd6_row0_col2" class="data row0 col2" >0.5328</td>
#       <td id="T_b7bd6_row0_col3" class="data row0 col3" >0.5242</td>
#       <td id="T_b7bd6_row0_col4" class="data row0 col4" >0.5340</td>
#     </tr>
#     <tr>
#       <th id="T_b7bd6_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b7bd6_row1_col0" class="data row1 col0" >remove_other</td>
#       <td id="T_b7bd6_row1_col1" class="data row1 col1" >Logistic (L1)</td>
#       <td id="T_b7bd6_row1_col2" class="data row1 col2" >0.5328</td>
#       <td id="T_b7bd6_row1_col3" class="data row1 col3" >0.5228</td>
#       <td id="T_b7bd6_row1_col4" class="data row1 col4" >0.5223</td>
#     </tr>
#     <tr>
#       <th id="T_b7bd6_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_b7bd6_row2_col0" class="data row2 col0" >remove_other+oversample</td>
#       <td id="T_b7bd6_row2_col1" class="data row2 col1" >LDA</td>
#       <td id="T_b7bd6_row2_col2" class="data row2 col2" >0.5290</td>
#       <td id="T_b7bd6_row2_col3" class="data row2 col3" >0.5212</td>
#       <td id="T_b7bd6_row2_col4" class="data row2 col4" >0.5303</td>
#     </tr>
#     <tr>
#       <th id="T_b7bd6_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_b7bd6_row3_col0" class="data row3 col0" >remove_other</td>
#       <td id="T_b7bd6_row3_col1" class="data row3 col1" >Logistic (ElasticNet)</td>
#       <td id="T_b7bd6_row3_col2" class="data row3 col2" >0.5290</td>
#       <td id="T_b7bd6_row3_col3" class="data row3 col3" >0.5205</td>
#       <td id="T_b7bd6_row3_col4" class="data row3 col4" >0.5212</td>
#     </tr>
#     <tr>
#       <th id="T_b7bd6_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_b7bd6_row4_col0" class="data row4 col0" >remove_other+undersample</td>
#       <td id="T_b7bd6_row4_col1" class="data row4 col1" >Logistic (L1)</td>
#       <td id="T_b7bd6_row4_col2" class="data row4 col2" >0.5328</td>
#       <td id="T_b7bd6_row4_col3" class="data row4 col3" >0.5201</td>
#       <td id="T_b7bd6_row4_col4" class="data row4 col4" >0.5316</td>
#     </tr>
#     <tr>
#       <th id="T_b7bd6_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_b7bd6_row5_col0" class="data row5 col0" >remove_other+undersample</td>
#       <td id="T_b7bd6_row5_col1" class="data row5 col1" >Logistic (ElasticNet)</td>
#       <td id="T_b7bd6_row5_col2" class="data row5 col2" >0.5251</td>
#       <td id="T_b7bd6_row5_col3" class="data row5 col3" >0.5130</td>
#       <td id="T_b7bd6_row5_col4" class="data row5 col4" >0.5229</td>
#     </tr>
#     <tr>
#       <th id="T_b7bd6_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_b7bd6_row6_col0" class="data row6 col0" >remove_other+oversample</td>
#       <td id="T_b7bd6_row6_col1" class="data row6 col1" >Logistic (L1)</td>
#       <td id="T_b7bd6_row6_col2" class="data row6 col2" >0.5135</td>
#       <td id="T_b7bd6_row6_col3" class="data row6 col3" >0.5058</td>
#       <td id="T_b7bd6_row6_col4" class="data row6 col4" >0.5063</td>
#     </tr>
#     <tr>
#       <th id="T_b7bd6_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_b7bd6_row7_col0" class="data row7 col0" >remove_other+oversample</td>
#       <td id="T_b7bd6_row7_col1" class="data row7 col1" >Logistic (ElasticNet)</td>
#       <td id="T_b7bd6_row7_col2" class="data row7 col2" >0.5135</td>
#       <td id="T_b7bd6_row7_col3" class="data row7 col3" >0.5056</td>
#       <td id="T_b7bd6_row7_col4" class="data row7 col4" >0.5064</td>
#     </tr>
#     <tr>
#       <th id="T_b7bd6_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_b7bd6_row8_col0" class="data row8 col0" >remove_other</td>
#       <td id="T_b7bd6_row8_col1" class="data row8 col1" >Extra Trees</td>
#       <td id="T_b7bd6_row8_col2" class="data row8 col2" >0.5483</td>
#       <td id="T_b7bd6_row8_col3" class="data row8 col3" >0.4980</td>
#       <td id="T_b7bd6_row8_col4" class="data row8 col4" >0.5222</td>
#     </tr>
#     <tr>
#       <th id="T_b7bd6_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_b7bd6_row9_col0" class="data row9 col0" >undersample</td>
#       <td id="T_b7bd6_row9_col1" class="data row9 col1" >Extra Trees</td>
#       <td id="T_b7bd6_row9_col2" class="data row9 col2" >0.5097</td>
#       <td id="T_b7bd6_row9_col3" class="data row9 col3" >0.4963</td>
#       <td id="T_b7bd6_row9_col4" class="data row9 col4" >0.5016</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ── Impact analysis: removing 'other' class ──────────────────────────────
baseline_f1    = summary[summary.Strategy == "baseline"].set_index("Model")["F1-macro"]
no_other_f1    = summary[summary.Strategy == "remove_other"].set_index("Model")["F1-macro"]
delta = (no_other_f1 - baseline_f1).sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(9, 4))
colors = ["#2ecc71" if v >= 0 else "#e74c3c" for v in delta.values]
ax.barh(delta.index, delta.values, color=colors)
ax.axvline(0, color="black", linewidth=1)
ax.set_xlabel("F1-macro change")
ax.set_title("Impact of Removing 'other' Class on F1-macro\n(green = improvement)")
for i, v in enumerate(delta.values):
    ax.text(v + (0.001 if v >= 0 else -0.001), i,
            f"{v:+.4f}", va="center",
            ha="left" if v >= 0 else "right", fontsize=10)
plt.tight_layout()
plt.show()

print("\nDelta F1-macro (remove_other - baseline):")
print(delta.to_string())
# Out:
# Delta F1-macro (remove_other - baseline):
# Model
# Logistic (L1)           0.0936
# Logistic (ElasticNet)   0.0849
# LDA                     0.0734
# AdaBoost                0.0394
# Extra Trees             0.0394
# QDA                     0.0376

# %%
# ── Impact analysis: sampling strategies vs baseline ─────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for ax, ref_strat, compare_strat, title in [
    (axes[0], "baseline",     "oversample",  "Oversample vs Baseline"),
    (axes[1], "baseline",     "undersample", "Undersample vs Baseline"),
]:
    ref  = summary[summary.Strategy == ref_strat].set_index("Model")["F1-macro"]
    comp = summary[summary.Strategy == compare_strat].set_index("Model")["F1-macro"]
    delta = (comp - ref).sort_values(ascending=False)
    colors = ["#2ecc71" if v >= 0 else "#e74c3c" for v in delta.values]
    ax.barh(delta.index, delta.values, color=colors)
    ax.axvline(0, color="black", linewidth=1)
    ax.set_xlabel("F1-macro change")
    ax.set_title(title)
    for i, v in enumerate(delta.values):
        ax.text(v + (0.001 if v >= 0 else -0.001), i,
                f"{v:+.4f}", va="center",
                ha="left" if v >= 0 else "right", fontsize=9)

plt.suptitle("Sampling Strategy Impact on F1-macro", fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Save summary to CSV ───────────────────────────────────────────────────
summary.to_csv("experiment_results.csv", index=False)
print("Saved to experiment_results.csv")
print()
print("Final summary:")
display(summary.sort_values(["Strategy", "F1-macro"], ascending=[True, False]))
# Out:
# Saved to experiment_results.csv
#
# Final summary:
#                     Strategy                  Model  Accuracy  F1-macro  \
# 2                   baseline            Extra Trees    0.5065    0.4586
# 1                   baseline  Logistic (ElasticNet)    0.4448    0.4356
# 0                   baseline          Logistic (L1)    0.4383    0.4292
# 4                   baseline                    LDA    0.4513    0.4228
# 5                   baseline                    QDA    0.4675    0.4195
# 3                   baseline               AdaBoost    0.4253    0.3021
# 14                oversample            Extra Trees    0.4935    0.4711
# 13                oversample  Logistic (ElasticNet)    0.4513    0.4412
# 12                oversample          Logistic (L1)    0.4481    0.4389
# 16                oversample                    LDA    0.4448    0.4340
# 17                oversample                    QDA    0.4058    0.3762
# 15                oversample               AdaBoost    0.4318    0.3716
# 6               remove_other          Logistic (L1)    0.5328    0.5228
# 7               remove_other  Logistic (ElasticNet)    0.5290    0.5205
# 8               remove_other            Extra Trees    0.5483    0.4980
# 10              remove_other                    LDA    0.5290    0.4962
# 11              remove_other                    QDA    0.5019    0.4571
# 9               remove_other               AdaBoost    0.4788    0.3415
# 28   remove_other+oversample                    LDA    0.5290    0.5212
# 24   remove_other+oversample          Logistic (L1)    0.5135    0.5058
# 25   remove_other+oversample  Logistic (ElasticNet)    0.5135    0.5056
# 26   remove_other+oversample            Extra Trees    0.5290    0.4906
# 29   remove_other+oversample                    QDA    0.5097    0.4819
# 27   remove_other+oversample               AdaBoost    0.4981    0.4706
# 34  remove_other+undersample                    LDA    0.5328    0.5242
# 30  remove_other+undersample          Logistic (L1)    0.5328    0.5201
# 31  remove_other+undersample  Logistic (ElasticNet)    0.5251    0.5130
# 32  remove_other+undersample            Extra Trees    0.5058    0.4895
# 33  remove_other+undersample               AdaBoost    0.5135    0.4797
# 35  remove_other+undersample                    QDA    0.4749    0.4549
# 20               undersample            Extra Trees    0.5097    0.4963
# 19               undersample  Logistic (ElasticNet)    0.4513    0.4423
# 18               undersample          Logistic (L1)    0.4481    0.4388
# 22               undersample                    LDA    0.4383    0.4291
# 23               undersample                    QDA    0.3994    0.3777
# 21               undersample               AdaBoost    0.4253    0.3560
#
#     F1-weighted
# 2        0.4784
# 1        0.4450
# 0        0.4388
# 4        0.4420
# 5        0.4428
# 3        0.3256
# 14       0.4818
# 13       0.4520
# 12       0.4492
# 16       0.4480
# 17       0.3960
# 15       0.3961
# 6        0.5223
# 7        0.5212
# 8        0.5222
# 10       0.5170
# 11       0.4821
# 9        0.3745
# 28       0.5303
# 24       0.5063
# 25       0.5064
# 26       0.5086
# 29       0.5021
# 27       0.4779
# 34       0.5340
# 30       0.5316
# 31       0.5229
# 32       0.5018
# 33       0.4932
# 35       0.4728
# 20       0.5016
# 19       0.4529
# 18       0.4489
# 22       0.4443
# 23       0.3926
# 21       0.3748

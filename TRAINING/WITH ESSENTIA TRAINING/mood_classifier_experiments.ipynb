# %% [markdown]
# # Hindi Song Mood Classifier — Experiment Grid
# ### Comparing models × sampling strategies
# **Models:** XGBoost, SVM, Logistic Regression, KNN, Random Forest
# **Strategies:** Baseline · Remove 'other' · Oversample (SMOTE) · Undersample · Remove+Oversample · Remove+Undersample
# **Total experiments:** 30 combinations

# %%
# Run once to install dependencies
# !pip install xgboost imbalanced-learn scikit-learn pandas matplotlib seaborn openpyxl

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from itertools import product

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import (classification_report, confusion_matrix,
                              accuracy_score, f1_score)
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as ImbPipeline

RANDOM_STATE = 42
pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:.4f}".format)
print("All imports OK")
# Out:
# All imports OK

# %%
# ── Load dataset ──────────────────────────────────────────────────────────
EXCEL_PATH = "scaled_features.xlsx"
TARGET_COL = "FINAL MOOD"

META_COLS = ["ID", "Song Title", "Film / Album", "Year",
             "ChatGPT Mood", "Claude Mood", "deepseek/copilot Mood",
             "FINAL MOOD", "Test", "File name"]

df = pd.read_excel(EXCEL_PATH)
FEATURE_COLS = [c for c in df.columns if c not in META_COLS]

print(f"Dataset shape   : {df.shape}")
print(f"Feature columns : {len(FEATURE_COLS)}")
print()
print("Class distribution:")
print(df[TARGET_COL].value_counts().to_string())
# Out:
# Dataset shape   : (1538, 66)
# Feature columns : 56
#
# Class distribution:
# FINAL MOOD
# romantic    395
# sad         344
# excited     321
# other       247
# happy       231

# %%
# ── Class distribution visualisation ─────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

counts = df[TARGET_COL].value_counts()
colors = ["#e74c3c", "#e67e22", "#3498db", "#2ecc71", "#9b59b6"]

axes[0].bar(counts.index, counts.values, color=colors)
axes[0].set_title("Full Dataset — Class Distribution", fontsize=13)
axes[0].set_xlabel("Mood"); axes[0].set_ylabel("Count")
for i, (cls, v) in enumerate(counts.items()):
    axes[0].text(i, v + 3, str(v), ha="center", fontsize=10, fontweight="bold")

counts_no_other = df.loc[df[TARGET_COL] != "other", TARGET_COL].value_counts()
axes[1].bar(counts_no_other.index, counts_no_other.values, color=colors[:4])
axes[1].set_title("Without 'other' Class", fontsize=13)
axes[1].set_xlabel("Mood"); axes[1].set_ylabel("Count")
for i, (cls, v) in enumerate(counts_no_other.items()):
    axes[1].text(i, v + 3, str(v), ha="center", fontsize=10, fontweight="bold")

plt.suptitle("Class Imbalance Overview", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Feature selection: drop low-variance + highly correlated ──────────────
from sklearn.preprocessing import MinMaxScaler

def drop_low_variance(X_df, threshold=0.01):
    scaled = pd.DataFrame(MinMaxScaler().fit_transform(X_df), columns=X_df.columns)
    return [c for c in scaled.columns if scaled[c].var() > threshold]

def drop_correlated(X_df, threshold=0.90):
    corr  = X_df.corr().abs()
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
    drop  = {c for c in upper.columns if any(upper[c] > threshold)}
    return [c for c in X_df.columns if c not in drop]

X_full = df[FEATURE_COLS].copy()
keep   = drop_low_variance(X_full)
X_full = X_full[keep]
keep   = drop_correlated(X_full)
X_full = X_full[keep]

print(f"Features after selection: {X_full.shape[1]}  (was {len(FEATURE_COLS)})")

y_full = df[TARGET_COL].values
# Out:
# Features after selection: 35  (was 56)

# %%
# ── Define models and sampling strategies ─────────────────────────────────

MODELS = {
    "XGBoost": XGBClassifier(
        n_estimators=300, max_depth=6, learning_rate=0.1,
        use_label_encoder=False, eval_metric="mlogloss",
        random_state=RANDOM_STATE, n_jobs=-1),
    "SVM": SVC(
        kernel="rbf", C=10, gamma="scale",
        class_weight="balanced", probability=True, random_state=RANDOM_STATE),
    "Logistic Regression": LogisticRegression(
        C=1.0, max_iter=1000, class_weight="balanced", random_state=RANDOM_STATE),
    "KNN": KNeighborsClassifier(n_neighbors=7, metric="euclidean"),
    "Random Forest": RandomForestClassifier(
        n_estimators=300, class_weight="balanced",
        random_state=RANDOM_STATE, n_jobs=-1),
}

STRATEGIES = [
    "baseline",
    "remove_other",
    "oversample",
    "undersample",
    "remove_other+oversample",
    "remove_other+undersample",
]

print(f"Models     : {list(MODELS.keys())}")
print(f"Strategies : {STRATEGIES}")
print(f"\nTotal experiments : {len(MODELS) * len(STRATEGIES)}")
# Out:
# Models     : ['XGBoost', 'SVM', 'Logistic Regression', 'KNN', 'Random Forest']
# Strategies : ['baseline', 'remove_other', 'oversample', 'undersample', 'remove_other+oversample', 'remove_other+undersample']
#
# Total experiments : 30

# %%
# ── Run all 30 experiments ────────────────────────────────────────────────

def prepare_data(strategy, X, y):
    """Apply sampling strategy and return (X_train, X_test, y_train, y_test, classes)."""
    remove_other = "remove_other" in strategy

    if remove_other:
        mask = y != "other"
        X_use, y_use = X[mask], y[mask]
    else:
        X_use, y_use = X.copy(), y.copy()

    le = LabelEncoder()
    y_enc = le.fit_transform(y_use)

    X_tr, X_te, y_tr, y_te = train_test_split(
        X_use.values, y_enc, test_size=0.2,
        stratify=y_enc, random_state=RANDOM_STATE)

    if "oversample" in strategy:
        sm = SMOTE(random_state=RANDOM_STATE)
        X_tr, y_tr = sm.fit_resample(X_tr, y_tr)
    elif "undersample" in strategy:
        rus = RandomUnderSampler(random_state=RANDOM_STATE)
        X_tr, y_tr = rus.fit_resample(X_tr, y_tr)

    return X_tr, X_te, y_tr, y_te, le


results = []  # list of dicts, one per experiment

for strategy in STRATEGIES:
    X_tr, X_te, y_tr, y_te, le = prepare_data(strategy, X_full, y_full)
    n_classes = len(le.classes_)

    print(f"\n{'='*60}")
    print(f"Strategy: {strategy.upper()}")
    print(f"  Train size: {len(X_tr)}  |  Test size: {len(X_te)}")
    print(f"  Classes: {list(le.classes_)}")
    tr_dist = pd.Series(y_tr).value_counts().to_dict()
    print(f"  Train dist: { {le.classes_[k]: v for k, v in tr_dist.items()} }")

    for model_name, clf in MODELS.items():
        # Wrap in scaling pipeline
        pipe = Pipeline([("sc", StandardScaler()), ("clf", clf)])

        pipe.fit(X_tr, y_tr)
        y_pred = pipe.predict(X_te)

        acc = accuracy_score(y_te, y_pred)
        f1  = f1_score(y_te, y_pred, average="macro")
        f1w = f1_score(y_te, y_pred, average="weighted")

        report = classification_report(
            y_te, y_pred, target_names=le.classes_, output_dict=True)

        results.append({
            "strategy"  : strategy,
            "model"     : model_name,
            "accuracy"  : acc,
            "f1_macro"  : f1,
            "f1_weighted": f1w,
            "report"    : report,
            "y_te"      : y_te,
            "y_pred"    : y_pred,
            "classes"   : list(le.classes_),
            "pipe"      : pipe,
        })

        print(f"  {model_name:<22}: Acc={acc:.4f}  F1-macro={f1:.4f}  F1-weighted={f1w:.4f}")

print("\n✅ All experiments complete.")
# Out:
# ============================================================
# Strategy: BASELINE
#   Train size: 1230  |  Test size: 308
#   Classes: ['excited', 'happy', 'other', 'romantic', 'sad']
#   Train dist: {'romantic': 316, 'sad': 275, 'excited': 257, 'other': 197, 'happy': 185}
#   XGBoost               : Acc=0.4708  F1-macro=0.4410  F1-weighted=0.4577
#   SVM                   : Acc=0.4351  F1-macro=0.4267  F1-weighted=0.4321
#   Logistic Regression   : Acc=0.4416  F1-macro=0.4315  F1-weighted=0.4418
#   KNN                   : Acc=0.4058  F1-macro=0.3726  F1-weighted=0.3865
#   Random Forest         : Acc=0.4903  F1-macro=0.4416  F1-weighted=0.4612
#
# ============================================================
# Strategy: REMOVE_OTHER
#   Train size: 1032  |  Test size: 259
#   Classes: ['excited', 'happy', 'romantic', 'sad']
#   Train dist: {'romantic': 316, 'sad': 275, 'excited': 256, 'happy': 185}
#   XGBoost               : Acc=0.5135  F1-macro=0.4884  F1-weighted=0.5012
#   SVM                   : Acc=0.4865  F1-macro=0.4841  F1-weighted=0.4862
#   Logistic Regression   : Acc=0.5174  F1-macro=0.5105  F1-weighted=0.5096
#   KNN                   : Acc=0.5174  F1-macro=0.4680  F1-weighted=0.4959
#   Random Forest         : Acc=0.5405  F1-macro=0.4973  F1-weighted=0.5193
#
# ============================================================
# Strategy: OVERSAMPLE
#   Train size: 1580  |  Test size: 308
#   Classes: ['excited', 'happy', 'other', 'romantic', 'sad']
#   Train dist: {'other': 316, 'happy': 316, 'romantic': 316, 'sad': 316, 'excited': 316}
#   XGBoost               : Acc=0.4805  F1-macro=0.4624  F1-weighted=0.4757
#   SVM                   : Acc=0.4481  F1-macro=0.4384  F1-weighted=0.4429
#   Logistic Regression   : Acc=0.4481  F1-macro=0.4378  F1-weighted=0.4497
#   KNN                   : Acc=0.4058  F1-macro=0.3971  F1-weighted=0.3995
#   Random Forest         : Acc=0.5000  F1-macro=0.4796  F1-weighted=0.4908
#
# ============================================================
# Strategy: UNDERSAMPLE
#   Train size: 925  |  Test size: 308
#   Classes: ['excited', 'happy', 'other', 'romantic', 'sad']
#   Train dist: {'excited': 185, 'happy': 185, 'other': 185, 'romantic': 185, 'sad': 185}
#   XGBoost               : Acc=0.4545  F1-macro=0.4426  F1-weighted=0.4517
#   SVM                   : Acc=0.4221  F1-macro=0.4165  F1-weighted=0.4191
#   Logistic Regression   : Acc=0.4545  F1-macro=0.4435  F1-weighted=0.4566
#   KNN                   : Acc=0.3701  F1-macro=0.3561  F1-weighted=0.3625
#   Random Forest         : Acc=0.4838  F1-macro=0.4715  F1-weighted=0.4799
#
# ============================================================
# Strategy: REMOVE_OTHER+OVERSAMPLE
#   Train size: 1264  |  Test size: 259
#   Classes: ['excited', 'happy', 'romantic', 'sad']
#   Train dist: {'excited': 316, 'romantic': 316, 'sad': 316, 'happy': 316}
#   XGBoost               : Acc=0.5328  F1-macro=0.5161  F1-weighted=0.5244
#   SVM                   : Acc=0.4749  F1-macro=0.4700  F1-weighted=0.4792
#   Logistic Regression   : Acc=0.5097  F1-macro=0.5025  F1-weighted=0.5028
#   KNN                   : Acc=0.4402  F1-macro=0.4371  F1-weighted=0.4511
#   Random Forest         : Acc=0.5328  F1-macro=0.5027  F1-weighted=0.5193
#
# ============================================================
# Strategy: REMOVE_OTHER+UNDERSAMPLE
#   Train size: 740  |  Test size: 259
#   Classes: ['excited', 'happy', 'romantic', 'sad']
#   Train dist: {'excited': 185, 'happy': 185, 'romantic': 185, 'sad': 185}
#   XGBoost               : Acc=0.5135  F1-macro=0.5017  F1-weighted=0.5123
#   SVM                   : Acc=0.5135  F1-macro=0.5119  F1-weighted=0.5158
#   Logistic Regression   : Acc=0.5290  F1-macro=0.5163  F1-weighted=0.5266
#   KNN                   : Acc=0.5135  F1-macro=0.4986  F1-weighted=0.5136
#   Random Forest         : Acc=0.5174  F1-macro=0.5038  F1-weighted=0.5149
#
# ✅ All experiments complete.

# %%
# ── Summary table: all 30 experiments ────────────────────────────────────
summary = pd.DataFrame([{
    "Strategy"   : r["strategy"],
    "Model"      : r["model"],
    "Accuracy"   : round(r["accuracy"],  4),
    "F1-macro"   : round(r["f1_macro"],  4),
    "F1-weighted": round(r["f1_weighted"],4),
} for r in results])

# Highlight best F1-macro per strategy
def highlight_best(s):
    is_max = s == s.max()
    return ["background-color: #d4edda; font-weight: bold" if v else "" for v in is_max]

display(
    summary.style
    .apply(highlight_best, subset=["F1-macro"], axis=0)
    .format({"Accuracy": "{:.4f}", "F1-macro": "{:.4f}", "F1-weighted": "{:.4f}"})
    .set_caption("All Experiments — Green = best F1-macro per strategy")
)
# Out:
# <style type="text/css">
# #T_dfd60_row27_col3 {
#   background-color: #d4edda;
#   font-weight: bold;
# }
# </style>
# <table id="T_dfd60">
#   <caption>All Experiments — Green = best F1-macro per strategy</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dfd60_level0_col0" class="col_heading level0 col0" >Strategy</th>
#       <th id="T_dfd60_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_dfd60_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#       <th id="T_dfd60_level0_col3" class="col_heading level0 col3" >F1-macro</th>
#       <th id="T_dfd60_level0_col4" class="col_heading level0 col4" >F1-weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dfd60_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dfd60_row0_col0" class="data row0 col0" >baseline</td>
#       <td id="T_dfd60_row0_col1" class="data row0 col1" >XGBoost</td>
#       <td id="T_dfd60_row0_col2" class="data row0 col2" >0.4708</td>
#       <td id="T_dfd60_row0_col3" class="data row0 col3" >0.4410</td>
#       <td id="T_dfd60_row0_col4" class="data row0 col4" >0.4577</td>
#     </tr>
#     <tr>
#       <th id="T_dfd60_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dfd60_row1_col0" class="data row1 col0" >baseline</td>
#       <td id="T_dfd60_row1_col1" class="data row1 col1" >SVM</td>
#       <td id="T_dfd60_row1_col2" class="data row1 col2" >0.4351</td>
#       <td id="T_dfd60_row1_col3" class="data row1 col3" >0.4267</td>
#       <td id="T_dfd60_row1_col4" class="data row1 col4" >0.4321</td>
#     </tr>
#     <tr>
#       <th id="T_dfd60_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dfd60_row2_col0" class="data row2 col0" >baseline</td>
#       <td id="T_dfd60_row2_col1" class="data row2 col1" >Logistic Regression</td>
#       <td id="T_dfd60_row2_col2" class="data row2 col2" >0.4416</td>
#       <td id="T_dfd60_row2_col3" class="data row2 col3" >0.4315</td>
#       <td id="T_dfd60_row2_col4" class="data row2 col4" >0.4418</td>
#     </tr>
#     <tr>
#       <th id="T_dfd60_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dfd60_row3_col0" class="data row3 col0" >baseline</td>
#       <td id="T_dfd60_row3_col1" class="data row3 col1" >KNN</td>
#       <td id="T_dfd60_row3_col2" class="data row3 col2" >0.4058</td>
#       <td id="T_dfd60_row3_col3" class="data row3 col3" >0.3726</td>
#       <td id="T_dfd60_row3_col4" class="data row3 col4" >0.3865</td>
#     </tr>
#     <tr>
#       <th id="T_dfd60_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dfd60_row4_col0" class="data row4 col0" >baseline</td>
#       <td id="T_dfd60_row4_col1" class="data row4 col1" >Random Forest</td>
#       <td id="T_dfd60_row4_col2" class="data row4 col2" >0.4903</td>
#       <td id="T_dfd60_row4_col3" class="data row4 col3" >0.4416</td>
#       <td id="T_dfd60_row4_col4" class="data row4 col4" >0.4612</td>
#     </tr>
#     <tr>
#       <th id="T_dfd60_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dfd60_row5_col0" class="data row5 col0" >remove_other</td>
#       <td id="T_dfd60_row5_col1" class="data row5 col1" >XGBoost</td>
#       <td id="T_dfd60_row5_col2" class="data row5 col2" >0.5135</td>
#       <td id="T_dfd60_row5_col3" class="data row5 col3" >0.4884</td>
#       <td id="T_dfd60_row5_col4" class="data row5 col4" >0.5012</td>
#     </tr>
#     <tr>
#       <th id="T_dfd60_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dfd60_row6_col0" class="data row6 col0" >remove_other</td>
#       <td id="T_dfd60_row6_col1" class="data row6 col1" >SVM</td>
#       <td id="T_dfd60_row6_col2" class="data row6 col2" >0.4865</td>
#       <td id="T_dfd60_row6_col3" class="data row6 col3" >0.4841</td>
#       <td id="T_dfd60_row6_col4" class="data row6 col4" >0.4862</td>
#     </tr>
#     <tr>
#       <th id="T_dfd60_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dfd60_row7_col0" class="data row7 col0" >remove_other</td>
#       <td id="T_dfd60_row7_col1" class="data row7 col1" >Logistic Regression</td>
#       <td id="T_dfd60_row7_col2" class="data row7 col2" >0.5174</td>
#       <td id="T_dfd60_row7_col3" class="data row7 col3" >0.5105</td>
#       <td id="T_dfd60_row7_col4" class="data row7 col4" >0.5096</td>
#     </tr>
#     <tr>
#       <th id="T_dfd60_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dfd60_row8_col0" class="data row8 col0" >remove_other</td>
#       <td id="T_dfd60_row8_col1" class="data row8 col1" >KNN</td>
#       <td id="T_dfd60_row8_col2" class="data row8 col2" >0.5174</td>
#       <td id="T_dfd60_row8_col3" class="data row8 col3" >0.4680</td>
#       <td id="T_dfd60_row8_col4" class="data row8 col4" >0.4959</td>
#     </tr>
#     <tr>
#       <th id="T_dfd60_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dfd60_row9_col0" class="data row9 col0" >remove_other</td>
#       <td id="T_dfd60_row9_col1" class="data row9 col1" >Random Forest</td>
#       <td id="T_dfd60_row9_col2" class="data row9 col2" >0.5405</td>
#       <td id="T_dfd60_row9_col3" class="data row9 col3" >0.4973</td>
#       <td id="T_dfd60_row9_col4" class="data row9 col4" >0.5193</td>
#     </tr>
#     <tr>
#       <th id="T_dfd60_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_dfd60_row10_col0" class="data row10 col0" >oversample</td>
#       <td id="T_dfd60_row10_col1" class="data row10 col1" >XGBoost</td>
#       <td id="T_dfd60_row10_col2" class="data row10 col2" >0.4805</td>
#       <td id="T_dfd60_row10_col3" class="data row10 col3" >0.4624</td>
#       <td id="T_dfd60_row10_col4" class="data row10 col4" >0.4757</td>
#     </tr>
#     <tr>
#       <th id="T_dfd60_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_dfd60_row11_col0" class="data row11 col0" >oversample</td>
#       <td id="T_dfd60_row11_col1" class="data row11 col1" >SVM</td>
#       <td id="T_dfd60_row11_col2" class="data row11 col2" >0.4481</td>
#       <td id="T_dfd60_row11_col3" class="data row11 col3" >0.4384</td>
#       <td id="T_dfd60_row11_col4" class="data row11 col4" >0.4429</td>
#     </tr>
#     <tr>
#       <th id="T_dfd60_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_dfd60_row12_col0" class="data row12 col0" >oversample</td>
#       <td id="T_dfd60_row12_col1" class="data row12 col1" >Logistic Regression</td>
#       <td id="T_dfd60_row12_col2" class="data row12 col2" >0.4481</td>
#       <td id="T_dfd60_row12_col3" class="data row12 col3" >0.4378</td>
#       <td id="T_dfd60_row12_col4" class="data row12 col4" >0.4497</td>
#     </tr>
#     <tr>
#       <th id="T_dfd60_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_dfd60_row13_col0" class="data row13 col0" >oversample</td>
#       <td id="T_dfd60_row13_col1" class="data row13 col1" >KNN</td>
#       <td id="T_dfd60_row13_col2" class="data row13 col2" >0.4058</td>
#       <td id="T_dfd60_row13_col3" class="data row13 col3" >0.3971</td>
#       <td id="T_dfd60_row13_col4" class="data row13 col4" >0.3995</td>
#     </tr>
#     <tr>
#       <th id="T_dfd60_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_dfd60_row14_col0" class="data row14 col0" >oversample</td>
#       <td id="T_dfd60_row14_col1" class="data row14 col1" >Random Forest</td>
#       <td id="T_dfd60_row14_col2" class="data row14 col2" >0.5000</td>
#       <td id="T_dfd60_row14_col3" class="data row14 col3" >0.4796</td>
#       <td id="T_dfd60_row14_col4" class="data row14 col4" >0.4908</td>
#     </tr>
#     <tr>
#       <th id="T_dfd60_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_dfd60_row15_col0" class="data row15 col0" >undersample</td>
#       <td id="T_dfd60_row15_col1" class="data row15 col1" >XGBoost</td>
#       <td id="T_dfd60_row15_col2" class="data row15 col2" >0.4545</td>
#       <td id="T_dfd60_row15_col3" class="data row15 col3" >0.4426</td>
#       <td id="T_dfd60_row15_col4" class="data row15 col4" >0.4517</td>
#     </tr>
#     <tr>
#       <th id="T_dfd60_level0_row16" class="row_heading level0 row16" >16

# %%
# ── Best model per strategy ───────────────────────────────────────────────
best_per_strategy = (
    summary.sort_values("F1-macro", ascending=False)
           .groupby("Strategy").first()
           .reset_index()
           [["Strategy", "Model", "Accuracy", "F1-macro", "F1-weighted"]]
           .sort_values("F1-macro", ascending=False)
)

print("Best model per strategy (sorted by F1-macro):")
display(best_per_strategy.style.format({
    "Accuracy": "{:.4f}", "F1-macro": "{:.4f}", "F1-weighted": "{:.4f}"}))
# Out:
# Best model per strategy (sorted by F1-macro):
# <style type="text/css">
# </style>
# <table id="T_8340f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8340f_level0_col0" class="col_heading level0 col0" >Strategy</th>
#       <th id="T_8340f_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_8340f_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#       <th id="T_8340f_level0_col3" class="col_heading level0 col3" >F1-macro</th>
#       <th id="T_8340f_level0_col4" class="col_heading level0 col4" >F1-weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8340f_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_8340f_row0_col0" class="data row0 col0" >remove_other+undersample</td>
#       <td id="T_8340f_row0_col1" class="data row0 col1" >Logistic Regression</td>
#       <td id="T_8340f_row0_col2" class="data row0 col2" >0.5290</td>
#       <td id="T_8340f_row0_col3" class="data row0 col3" >0.5163</td>
#       <td id="T_8340f_row0_col4" class="data row0 col4" >0.5266</td>
#     </tr>
#     <tr>
#       <th id="T_8340f_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_8340f_row1_col0" class="data row1 col0" >remove_other+oversample</td>
#       <td id="T_8340f_row1_col1" class="data row1 col1" >XGBoost</td>
#       <td id="T_8340f_row1_col2" class="data row1 col2" >0.5328</td>
#       <td id="T_8340f_row1_col3" class="data row1 col3" >0.5161</td>
#       <td id="T_8340f_row1_col4" class="data row1 col4" >0.5244</td>
#     </tr>
#     <tr>
#       <th id="T_8340f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8340f_row2_col0" class="data row2 col0" >remove_other</td>
#       <td id="T_8340f_row2_col1" class="data row2 col1" >Logistic Regression</td>
#       <td id="T_8340f_row2_col2" class="data row2 col2" >0.5174</td>
#       <td id="T_8340f_row2_col3" class="data row2 col3" >0.5105</td>
#       <td id="T_8340f_row2_col4" class="data row2 col4" >0.5096</td>
#     </tr>
#     <tr>
#       <th id="T_8340f_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_8340f_row3_col0" class="data row3 col0" >oversample</td>
#       <td id="T_8340f_row3_col1" class="data row3 col1" >Random Forest</td>
#       <td id="T_8340f_row3_col2" class="data row3 col2" >0.5000</td>
#       <td id="T_8340f_row3_col3" class="data row3 col3" >0.4796</td>
#       <td id="T_8340f_row3_col4" class="data row3 col4" >0.4908</td>
#     </tr>
#     <tr>
#       <th id="T_8340f_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_8340f_row4_col0" class="data row4 col0" >undersample</td>
#       <td id="T_8340f_row4_col1" class="data row4 col1" >Random Forest</td>
#       <td id="T_8340f_row4_col2" class="data row4 col2" >0.4838</td>
#       <td id="T_8340f_row4_col3" class="data row4 col3" >0.4715</td>
#       <td id="T_8340f_row4_col4" class="data row4 col4" >0.4799</td>
#     </tr>
#     <tr>
#       <th id="T_8340f_level0_row5" class="row_heading level0 row5" >0</th>
#       <td id="T_8340f_row5_col0" class="data row5 col0" >baseline</td>
#       <td id="T_8340f_row5_col1" class="data row5 col1" >Random Forest</td>
#       <td id="T_8340f_row5_col2" class="data row5 col2" >0.4903</td>
#       <td id="T_8340f_row5_col3" class="data row5 col3" >0.4416</td>
#       <td id="T_8340f_row5_col4" class="data row5 col4" >0.4612</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ── Heatmap: F1-macro for all model × strategy combinations ───────────────
pivot = summary.pivot(index="Model", columns="Strategy", values="F1-macro")
# Order strategies sensibly
col_order = [c for c in STRATEGIES if c in pivot.columns]
pivot = pivot[col_order]

fig, ax = plt.subplots(figsize=(14, 5))
sns.heatmap(pivot, annot=True, fmt=".3f", cmap="YlGn",
            linewidths=0.5, linecolor="white",
            annot_kws={"size": 11}, ax=ax,
            vmin=pivot.values.min() - 0.02,
            vmax=pivot.values.max() + 0.01)
ax.set_title("F1-macro Heatmap: Model × Sampling Strategy", fontsize=14, pad=12)
ax.set_xlabel("Strategy", fontsize=11)
ax.set_ylabel("Model", fontsize=11)
plt.xticks(rotation=25, ha="right")
plt.tight_layout()
plt.show()

# %%
# ── Heatmap: Accuracy ─────────────────────────────────────────────────────
pivot_acc = summary.pivot(index="Model", columns="Strategy", values="Accuracy")[col_order]

fig, ax = plt.subplots(figsize=(14, 5))
sns.heatmap(pivot_acc, annot=True, fmt=".3f", cmap="Blues",
            linewidths=0.5, linecolor="white",
            annot_kws={"size": 11}, ax=ax)
ax.set_title("Accuracy Heatmap: Model × Sampling Strategy", fontsize=14, pad=12)
ax.set_xlabel("Strategy", fontsize=11)
ax.set_ylabel("Model", fontsize=11)
plt.xticks(rotation=25, ha="right")
plt.tight_layout()
plt.show()

# %%
# ── Grouped bar: F1-macro per model across strategies ─────────────────────
fig, ax = plt.subplots(figsize=(15, 6))
model_names = list(MODELS.keys())
x = np.arange(len(model_names))
n_strat = len(STRATEGIES)
width = 0.13
colors_strat = plt.cm.Set2(np.linspace(0, 1, n_strat))

for i, strat in enumerate(STRATEGIES):
    vals = [summary.loc[(summary.Model == m) & (summary.Strategy == strat),
                        "F1-macro"].values[0] for m in model_names]
    offset = (i - n_strat / 2) * width + width / 2
    bars = ax.bar(x + offset, vals, width, label=strat, color=colors_strat[i])

ax.set_xlabel("Model", fontsize=12)
ax.set_ylabel("F1-macro", fontsize=12)
ax.set_title("F1-macro by Model and Sampling Strategy", fontsize=14)
ax.set_xticks(x); ax.set_xticklabels(model_names, fontsize=11)
ax.set_ylim(0, 1)
ax.legend(title="Strategy", bbox_to_anchor=(1.01, 1), loc="upper left", fontsize=9)
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# ── Per-class F1 breakdown for best experiment per strategy ───────────────
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

for ax_idx, strat in enumerate(STRATEGIES):
    # Find best model for this strategy
    strat_results = [r for r in results if r["strategy"] == strat]
    best = max(strat_results, key=lambda r: r["f1_macro"])
    classes = best["classes"]
    report  = best["report"]

    class_f1 = {cls: report[cls]["f1-score"] for cls in classes}
    mood_colors = {
        "happy":    "#2ecc71",
        "sad":      "#3498db",
        "romantic": "#e74c3c",
        "excited":  "#e67e22",
        "other":    "#95a5a6",
    }
    bar_colors = [mood_colors.get(c, "#7f8c8d") for c in class_f1]

    bars = axes[ax_idx].bar(class_f1.keys(), class_f1.values(), color=bar_colors)
    axes[ax_idx].set_title(
        f"{strat}\nBest: {best['model']}  (F1-macro={best['f1_macro']:.3f})",
        fontsize=10, fontweight="bold")
    axes[ax_idx].set_ylim(0, 1)
    axes[ax_idx].set_ylabel("F1-score")
    axes[ax_idx].axhline(best["f1_macro"], color="black",
                          linestyle="--", linewidth=1, alpha=0.5, label="macro avg")
    axes[ax_idx].legend(fontsize=8)
    for bar, (cls, val) in zip(bars, class_f1.items()):
        axes[ax_idx].text(bar.get_x() + bar.get_width()/2,
                           val + 0.01, f"{val:.2f}",
                           ha="center", va="bottom", fontsize=9)

plt.suptitle("Per-class F1 for Best Model per Strategy", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Confusion matrices for best model per strategy ────────────────────────
fig, axes = plt.subplots(2, 3, figsize=(18, 11))
axes = axes.flatten()

for ax_idx, strat in enumerate(STRATEGIES):
    strat_results = [r for r in results if r["strategy"] == strat]
    best = max(strat_results, key=lambda r: r["f1_macro"])

    cm   = confusion_matrix(best["y_te"], best["y_pred"])
    cm_n = cm.astype(float) / cm.sum(axis=1, keepdims=True)

    sns.heatmap(cm_n, annot=True, fmt=".2f", cmap="Blues",
                xticklabels=best["classes"], yticklabels=best["classes"],
                ax=axes[ax_idx], linewidths=0.3)
    axes[ax_idx].set_title(
        f"{strat}\n{best['model']}  Acc={best['accuracy']:.3f}",
        fontsize=10, fontweight="bold")
    axes[ax_idx].set_xlabel("Predicted"); axes[ax_idx].set_ylabel("Actual")

plt.suptitle("Confusion Matrices — Best Model per Strategy (normalised)",
             fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Full classification reports for every experiment ─────────────────────
for strat in STRATEGIES:
    print("\n" + "="*70)
    print(f"  STRATEGY: {strat.upper()}")
    print("="*70)
    for r in [x for x in results if x["strategy"] == strat]:
        print(f"\n--- {r['model']} ---")
        print(f"  Accuracy   : {r['accuracy']:.4f}")
        print(f"  F1-macro   : {r['f1_macro']:.4f}")
        print(f"  F1-weighted: {r['f1_weighted']:.4f}")
        rpt = r["report"]
        header = f"{'Class':<14} {'Precision':>10} {'Recall':>10} {'F1':>10} {'Support':>10}"
        print("  " + header)
        print("  " + "-"*len(header))
        for cls in r["classes"]:
            row = rpt[cls]
            print(f"  {cls:<14} {row['precision']:>10.4f} {row['recall']:>10.4f} "
                  f"{row['f1-score']:>10.4f} {int(row['support']):>10}")
        print(f"  {'macro avg':<14} {rpt['macro avg']['precision']:>10.4f} "
              f"{rpt['macro avg']['recall']:>10.4f} "
              f"{rpt['macro avg']['f1-score']:>10.4f} "
              f"{int(rpt['macro avg']['support']):>10}")
# Out:
# ======================================================================
#   STRATEGY: BASELINE
# ======================================================================
#
# --- XGBoost ---
#   Accuracy   : 0.4708
#   F1-macro   : 0.4410
#   F1-weighted: 0.4577
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6901     0.7656     0.7259         64
#   happy              0.3200     0.1739     0.2254         46
#   other              0.4211     0.3200     0.3636         50
#   romantic           0.3860     0.5570     0.4560         79
#   sad                0.4667     0.4058     0.4341         69
#   macro avg          0.4568     0.4445     0.4410        308
#
# --- SVM ---
#   Accuracy   : 0.4351
#   F1-macro   : 0.4267
#   F1-weighted: 0.4321
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6761     0.7500     0.7111         64
#   happy              0.2692     0.3043     0.2857         46
#   other              0.4186     0.3600     0.3871         50
#   romantic           0.3467     0.3291     0.3377         79
#   sad                0.4179     0.4058     0.4118         69
#   macro avg          0.4257     0.4299     0.4267        308
#
# --- Logistic Regression ---
#   Accuracy   : 0.4416
#   F1-macro   : 0.4315
#   F1-weighted: 0.4418
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6812     0.7344     0.7068         64
#   happy              0.2281     0.2826     0.2524         46
#   other              0.3729     0.4400     0.4037         50
#   romantic           0.4762     0.3797     0.4225         79
#   sad                0.4000     0.3478     0.3721         69
#   macro avg          0.4317     0.4369     0.4315        308
#
# --- KNN ---
#   Accuracy   : 0.4058
#   F1-macro   : 0.3726
#   F1-weighted: 0.3865
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6296     0.7969     0.7034         64
#   happy              0.1786     0.1087     0.1351         46
#   other              0.3696     0.3400     0.3542         50
#   romantic           0.3398     0.4430     0.3846         79
#   sad                0.3400     0.2464     0.2857         69
#   macro avg          0.3715     0.3870     0.3726        308
#
# --- Random Forest ---
#   Accuracy   : 0.4903
#   F1-macro   : 0.4416
#   F1-weighted: 0.4612
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6296     0.7969     0.7034         64
#   happy              0.5000     0.1087     0.1786         46
#   other              0.5714     0.3200     0.4103         50
#   romantic           0.4160     0.6582     0.5098         79
#   sad                0.4219     0.3913     0.4060         69
#   macro avg          0.5078     0.4550     0.4416        308
#
# ======================================================================
#   STRATEGY: REMOVE_OTHER
# ======================================================================
#
# --- XGBoost ---
#   Accuracy   : 0.5135
#   F1-macro   : 0.4884
#   F1-weighted: 0.5012
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7681     0.8154     0.7910         65
#   happy              0.3913     0.1957     0.2609         46
#   romantic           0.4177     0.4177     0.4177         79
#   sad                0.4318     0.5507     0.4841         69
#   macro avg          0.5022     0.4949     0.4884        259
#
# --- SVM ---
#   Accuracy   : 0.4865
#   F1-macro   : 0.4841
#   F1-weighted: 0.4862
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7656     0.7538     0.7597         65
#   happy              0.3617     0.3696     0.3656         46
#   romantic           0.4000     0.3544     0.3758         79
#   sad                0.4103     0.4638     0.4354         69
#   macro avg          0.4844     0.4854     0.4841        259
#
# --- Logistic Regression ---
#   Accuracy   : 0.5174
#   F1-macro   : 0.5105
#   F1-weighted: 0.5096
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7536     0.8000     0.7761         65
#   happy              0.3922     0.4348     0.4124         46
#   romantic           0.4615     0.3038     0.3664         79
#   sad                0.4368     0.5507     0.4872         69
#   macro avg          0.5110     0.5223     0.5105        259
#
# --- KNN ---
#   Accuracy   : 0.5174
#   F1-macro   : 0.4680
#   F1-weighted: 0.4959
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7324     0.8000     0.7647         65
#   happy              0.1905     0.0870     0.1194         46
#   romantic           0.4632     0.5570     0.5057         79
#   sad                0.4722     0.4928     0.4823         69
#   macro avg          0.4646     0.4842     0.4680        259
#
# --- Random Forest ---
#   Accuracy   : 0.5405
#   F1-macro   : 0.4973
#   F1-weighted: 0.5193
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7353     0.7692     0.7519         65
#   happy              0.5000     0.1304     0.2069         46
#   romantic           0.4455     0.5696     0.5000         79
#   sad                0.5000     0.5652     0.5306         69
#   macro avg          0.5452     0.5086     0.4973        259
#
# ======================================================================
#   STRATEGY: OVERSAMPLE
# ======================================================================
#
# --- XGBoost ---
#   Accuracy   : 0.4805
#   F1-macro   : 0.4624
#   F1-weighted: 0.4757
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7273     0.7500     0.7385         64
#   happy              0.2353     0.1739     0.2000         46
#   other              0.4894     0.4600     0.4742         50
#   romantic           0.3878     0.4810     0.4294         79
#   sad                0.4921     0.4493     0.4697         69
#   macro avg          0.4663     0.4628     0.4624        308
#
# --- SVM ---
#   Accuracy   : 0.4481
#   F1-macro   : 0.4384
#   F1-weighted: 0.4429
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6622     0.7656     0.7101         64
#   happy              0.2979     0.3043     0.3011         46
#   other              0.4615     0.3600     0.4045         50
#   romantic           0.3377     0.3291     0.3333         79
#   sad                0.4366     0.4493     0.4429         69
#   macro avg          0.4392     0.4417     0.4384        308
#
# --- Logistic Regression ---
#   Accuracy   : 0.4481
#   F1-macro   : 0.4378
#   F1-weighted: 0.4497
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6901     0.7656     0.7259         64
#   happy              0.2063     0.2826     0.2385         46
#   other              0.3860     0.4400     0.4112         50
#   romantic           0.5263     0.3797     0.4412         79
#   sad                0.4000     0.3478     0.3721         69
#   macro avg          0.4418     0.4432     0.4378        308
#
# --- KNN ---
#   Accuracy   : 0.4058
#   F1-macro   : 0.3971
#   F1-weighted: 0.3995
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7015     0.7344     0.7176         64
#   happy              0.2321     0.2826     0.2549         46
#   other              0.3103     0.5400     0.3942         50
#   romantic           0.3878     0.2405     0.2969         79
#   sad                0.3878     0.2754     0.3220         69
#   macro avg          0.4039     0.4146     0.3971        308
#
# --- Random Forest ---
#   Accuracy   : 0.5000
#   F1-macro   : 0.4796
#   F1-weighted: 0.4908
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6494     0.7812     0.7092         64
#   happy              0.3871     0.2609     0.3117         46
#   other              0.4375     0.4200     0.4286         50
#   romantic           0.4557     0.4557     0.4557         79
#   sad                0.4795     0.5072     0.4930         69
#   macro avg          0.4818     0.4850     0.4796        308
#
# ======================================================================
#   STRATEGY: UNDERSAMPLE
# ======================================================================
#
# --- XGBoost ---
#   Accuracy   : 0.4545
#   F1-macro   : 0.4426
#   F1-weighted: 0.4517
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6857     0.7500     0.7164         64
#   happy              0.2157     0.2391     0.2268         46
#   other              0.4000     0.5200     0.4522         50
#   romantic           0.4286     0.3418     0.3803         79
#   sad                0.4746     0.4058     0.4375         69
#   macro avg          0.4409     0.4513     0.4426        308
#
# --- SVM ---
#   Accuracy   : 0.4221
#   F1-macro   : 0.4165
#   F1-weighted: 0.4191
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6620     0.7344     0.6963         64
#   happy              0.2687     0.3913     0.3186         46
#   other              0.3585     0.3800     0.3689         50
#   romantic           0.3594     0.2911     0.3217         79
#   sad                0.4340     0.3333     0.3770         69
#   macro avg          0.4165     0.4260     0.4165        308
#
# --- Logistic Regression ---
#   Accuracy   : 0.4545
#   F1-macro   : 0.4435
#   F1-weighted: 0.4566
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7015     0.7344     0.7176         64
#   happy              0.2364     0.2826     0.2574         46
#   other              0.3621     0.4200     0.3889         50
#   romantic           0.5079     0.4051     0.4507         79
#   sad                0.4154     0.3913     0.4030         69
#   macro avg          0.4446     0.4467     0.4435        308
#
# --- KNN ---
#   Accuracy   : 0.3701
#   F1-macro   : 0.3561
#   F1-weighted: 0.3625
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6076     0.7500     0.6713         64
#   happy              0.1639     0.2174     0.1869         46
#   other              0.3065     0.3800     0.3393         50
#   romantic           0.3654     0.2405     0.2901         79
#   sad                0.3333     0.2609     0.2927         69
#   macro avg          0.3553     0.3698     0.3561        308
#
# --- Random Forest ---
#   Accuracy   : 0.4838
#   F1-macro   : 0.4715
#   F1-weighted: 0.4799
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6667     0.7500     0.7059         64
#   happy              0.3182     0.3043     0.3111         46
#   other              0.3968     0.5000     0.4425         50
#   romantic           0.4627     0.3924     0.4247         79
#   sad                0.5000     0.4493     0.4733         69
#   macro avg          0.4689     0.4792     0.4715        308
#
# ======================================================================
#   STRATEGY: REMOVE_OTHER+OVERSAMPLE
# ======================================================================
#
# --- XGBoost ---
#   Accuracy   : 0.5328
#   F1-macro   : 0.5161
#   F1-weighted: 0.5244
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.8030     0.8154     0.8092         65
#   happy              0.3714     0.2826     0.3210         46
#   romantic           0.4394     0.3671     0.4000         79
#   sad                0.4674     0.6232     0.5342         69
#   macro avg          0.5203     0.5221     0.5161        259
#
# --- SVM ---
#   Accuracy   : 0.4749
#   F1-macro   : 0.4700
#   F1-weighted: 0.4792
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7797     0.7077     0.7419         65
#   happy              0.2857     0.3043     0.2947         46
#   romantic           0.4211     0.4051     0.4129         79
#   sad                0.4133     0.4493     0.4306         69
#   macro avg          0.4749     0.4666     0.4700        259
#
# --- Logistic Regression ---
#   Accuracy   : 0.5097
#   F1-macro   : 0.5025
#   F1-weighted: 0.5028
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7647     0.8000     0.7820         65
#   happy              0.3509     0.4348     0.3883         46
#   romantic           0.4694     0.2911     0.3594         79
#   sad                0.4353     0.5362     0.4805         69
#   macro avg          0.5051     0.5155     0.5025        259
#
# --- KNN ---
#   Accuracy   : 0.4402
#   F1-macro   : 0.4371
#   F1-weighted: 0.4511
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6714     0.7231     0.6963         65
#   happy              0.1852     0.3261     0.2362         46
#   romantic           0.6279     0.3418     0.4426         79
#   sad                0.3846     0.3623     0.3731         69
#   macro avg          0.4673     0.4383     0.4371        259
#
# --- Random Forest ---
#   Accuracy   : 0.5328
#   F1-macro   : 0.5027
#   F1-weighted: 0.5193
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7391     0.7846     0.7612         65
#   happy              0.3214     0.1957     0.2432         46
#   romantic           0.4474     0.4304     0.4387         79
#   sad                0.5116     0.6377     0.5677         69
#   macro avg          0.5049     0.5121     0.5027        259
#
# ======================================================================
#   STRATEGY: REMOVE_OTHER+UNDERSAMPLE
# ======================================================================
#
# --- XGBoost ---
#   Accuracy   : 0.5135
#   F1-macro   : 0.5017
#   F1-weighted: 0.5123
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7353     0.7692     0.7519         65
#   happy              0.2885     0.3261     0.3061         46
#   romantic           0.4697     0.3924     0.4276         79
#   sad                0.5068     0.5362     0.5211         69
#   macro avg          0.5001     0.5060     0.5017        259
#
# --- SVM ---
#   Accuracy   : 0.5135
#   F1-macro   : 0.5119
#   F1-weighted: 0.5158
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7344     0.7231     0.7287         65
#   happy              0.3438     0.4783     0.4000         46
#   romantic           0.4848     0.4051     0.4414         79
#   sad                0.4923     0.4638     0.4776         69
#   macro avg          0.5138     0.5175     0.5119        259
#
# --- Logistic Regression ---
#   Accuracy   : 0.5290
#   F1-macro   : 0.5163
#   F1-weighted: 0.5266
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7143     0.7692     0.7407         65
#   happy              0.3148     0.3696     0.3400         46
#   romantic           0.6000     0.3797     0.4651         79
#   sad                0.4706     0.5797     0.5195         69
#   macro avg          0.5249     0.5246     0.5163        259
#
# --- KNN ---
#   Accuracy   : 0.5135
#   F1-macro   : 0.4986
#   F1-weighted: 0.5136
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7042     0.7692     0.7353         65
#   happy              0.2642     0.3043     0.2828         46
#   romantic           0.4756     0.4937     0.4845         79
#   sad                0.5660     0.4348     0.4918         69
#   macro avg          0.5025     0.5005     0.4986        259
#
# --- Random Forest ---
#   Accuracy   : 0.5174
#   F1-macro   : 0.5038
#   F1-weighted: 0.5149
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7101     0.7538     0.7313         65
#   happy              0.2778     0.3261     0.3000         46
#   romantic           0.4754     0.3671     0.4143         79
#   sad                0.5467     0.5942     0.5694         69
#   macro avg          0.5025     0.5103     0.5038        259

# %%
# ── Overall leaderboard: top 10 experiments ──────────────────────────────
leaderboard = summary.sort_values("F1-macro", ascending=False).head(10).reset_index(drop=True)
leaderboard.index += 1
print("Top 10 experiments overall:")
display(leaderboard.style
    .format({"Accuracy": "{:.4f}", "F1-macro": "{:.4f}", "F1-weighted": "{:.4f}"})
    .bar(subset=["F1-macro"], color="#2ecc71", vmin=0, vmax=1)
    .set_caption("Top 10 — sorted by F1-macro"))
# Out:
# Top 10 experiments overall:
# <style type="text/css">
# #T_648fb_row0_col3, #T_648fb_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 51.6%, transparent 51.6%);
# }
# #T_648fb_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 51.2%, transparent 51.2%);
# }
# #T_648fb_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 51.0%, transparent 51.0%);
# }
# #T_648fb_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 50.4%, transparent 50.4%);
# }
# #T_648fb_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 50.3%, transparent 50.3%);
# }
# #T_648fb_row6_col3, #T_648fb_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 50.2%, transparent 50.2%);
# }
# #T_648fb_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 49.9%, transparent 49.9%);
# }
# #T_648fb_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 49.7%, transparent 49.7%);
# }
# </style>
# <table id="T_648fb">
#   <caption>Top 10 — sorted by F1-macro</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_648fb_level0_col0" class="col_heading level0 col0" >Strategy</th>
#       <th id="T_648fb_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_648fb_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#       <th id="T_648fb_level0_col3" class="col_heading level0 col3" >F1-macro</th>
#       <th id="T_648fb_level0_col4" class="col_heading level0 col4" >F1-weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_648fb_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_648fb_row0_col0" class="data row0 col0" >remove_other+undersample</td>
#       <td id="T_648fb_row0_col1" class="data row0 col1" >Logistic Regression</td>
#       <td id="T_648fb_row0_col2" class="data row0 col2" >0.5290</td>
#       <td id="T_648fb_row0_col3" class="data row0 col3" >0.5163</td>
#       <td id="T_648fb_row0_col4" class="data row0 col4" >0.5266</td>
#     </tr>
#     <tr>
#       <th id="T_648fb_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_648fb_row1_col0" class="data row1 col0" >remove_other+oversample</td>
#       <td id="T_648fb_row1_col1" class="data row1 col1" >XGBoost</td>
#       <td id="T_648fb_row1_col2" class="data row1 col2" >0.5328</td>
#       <td id="T_648fb_row1_col3" class="data row1 col3" >0.5161</td>
#       <td id="T_648fb_row1_col4" class="data row1 col4" >0.5244</td>
#     </tr>
#     <tr>
#       <th id="T_648fb_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_648fb_row2_col0" class="data row2 col0" >remove_other+undersample</td>
#       <td id="T_648fb_row2_col1" class="data row2 col1" >SVM</td>
#       <td id="T_648fb_row2_col2" class="data row2 col2" >0.5135</td>
#       <td id="T_648fb_row2_col3" class="data row2 col3" >0.5119</td>
#       <td id="T_648fb_row2_col4" class="data row2 col4" >0.5158</td>
#     </tr>
#     <tr>
#       <th id="T_648fb_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_648fb_row3_col0" class="data row3 col0" >remove_other</td>
#       <td id="T_648fb_row3_col1" class="data row3 col1" >Logistic Regression</td>
#       <td id="T_648fb_row3_col2" class="data row3 col2" >0.5174</td>
#       <td id="T_648fb_row3_col3" class="data row3 col3" >0.5105</td>
#       <td id="T_648fb_row3_col4" class="data row3 col4" >0.5096</td>
#     </tr>
#     <tr>
#       <th id="T_648fb_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_648fb_row4_col0" class="data row4 col0" >remove_other+undersample</td>
#       <td id="T_648fb_row4_col1" class="data row4 col1" >Random Forest</td>
#       <td id="T_648fb_row4_col2" class="data row4 col2" >0.5174</td>
#       <td id="T_648fb_row4_col3" class="data row4 col3" >0.5038</td>
#       <td id="T_648fb_row4_col4" class="data row4 col4" >0.5149</td>
#     </tr>
#     <tr>
#       <th id="T_648fb_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_648fb_row5_col0" class="data row5 col0" >remove_other+oversample</td>
#       <td id="T_648fb_row5_col1" class="data row5 col1" >Random Forest</td>
#       <td id="T_648fb_row5_col2" class="data row5 col2" >0.5328</td>
#       <td id="T_648fb_row5_col3" class="data row5 col3" >0.5027</td>
#       <td id="T_648fb_row5_col4" class="data row5 col4" >0.5193</td>
#     </tr>
#     <tr>
#       <th id="T_648fb_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_648fb_row6_col0" class="data row6 col0" >remove_other+oversample</td>
#       <td id="T_648fb_row6_col1" class="data row6 col1" >Logistic Regression</td>
#       <td id="T_648fb_row6_col2" class="data row6 col2" >0.5097</td>
#       <td id="T_648fb_row6_col3" class="data row6 col3" >0.5025</td>
#       <td id="T_648fb_row6_col4" class="data row6 col4" >0.5028</td>
#     </tr>
#     <tr>
#       <th id="T_648fb_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_648fb_row7_col0" class="data row7 col0" >remove_other+undersample</td>
#       <td id="T_648fb_row7_col1" class="data row7 col1" >XGBoost</td>
#       <td id="T_648fb_row7_col2" class="data row7 col2" >0.5135</td>
#       <td id="T_648fb_row7_col3" class="data row7 col3" >0.5017</td>
#       <td id="T_648fb_row7_col4" class="data row7 col4" >0.5123</td>
#     </tr>
#     <tr>
#       <th id="T_648fb_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_648fb_row8_col0" class="data row8 col0" >remove_other+undersample</td>
#       <td id="T_648fb_row8_col1" class="data row8 col1" >KNN</td>
#       <td id="T_648fb_row8_col2" class="data row8 col2" >0.5135</td>
#       <td id="T_648fb_row8_col3" class="data row8 col3" >0.4986</td>
#       <td id="T_648fb_row8_col4" class="data row8 col4" >0.5136</td>
#     </tr>
#     <tr>
#       <th id="T_648fb_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_648fb_row9_col0" class="data row9 col0" >remove_other</td>
#       <td id="T_648fb_row9_col1" class="data row9 col1" >Random Forest</td>
#       <td id="T_648fb_row9_col2" class="data row9 col2" >0.5405</td>
#       <td id="T_648fb_row9_col3" class="data row9 col3" >0.4973</td>
#       <td id="T_648fb_row9_col4" class="data row9 col4" >0.5193</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ── Impact analysis: removing 'other' class ──────────────────────────────
baseline_f1    = summary[summary.Strategy == "baseline"].set_index("Model")["F1-macro"]
no_other_f1    = summary[summary.Strategy == "remove_other"].set_index("Model")["F1-macro"]
delta = (no_other_f1 - baseline_f1).sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(9, 4))
colors = ["#2ecc71" if v >= 0 else "#e74c3c" for v in delta.values]
ax.barh(delta.index, delta.values, color=colors)
ax.axvline(0, color="black", linewidth=1)
ax.set_xlabel("F1-macro change")
ax.set_title("Impact of Removing 'other' Class on F1-macro\n(green = improvement)")
for i, v in enumerate(delta.values):
    ax.text(v + (0.001 if v >= 0 else -0.001), i,
            f"{v:+.4f}", va="center",
            ha="left" if v >= 0 else "right", fontsize=10)
plt.tight_layout()
plt.show()

print("\nDelta F1-macro (remove_other - baseline):")
print(delta.to_string())
# Out:
# Delta F1-macro (remove_other - baseline):
# Model
# KNN                   0.0954
# Logistic Regression   0.0790
# SVM                   0.0574
# Random Forest         0.0557
# XGBoost               0.0474

# %%
# ── Impact analysis: sampling strategies vs baseline ─────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for ax, ref_strat, compare_strat, title in [
    (axes[0], "baseline",     "oversample",  "Oversample vs Baseline"),
    (axes[1], "baseline",     "undersample", "Undersample vs Baseline"),
]:
    ref  = summary[summary.Strategy == ref_strat].set_index("Model")["F1-macro"]
    comp = summary[summary.Strategy == compare_strat].set_index("Model")["F1-macro"]
    delta = (comp - ref).sort_values(ascending=False)
    colors = ["#2ecc71" if v >= 0 else "#e74c3c" for v in delta.values]
    ax.barh(delta.index, delta.values, color=colors)
    ax.axvline(0, color="black", linewidth=1)
    ax.set_xlabel("F1-macro change")
    ax.set_title(title)
    for i, v in enumerate(delta.values):
        ax.text(v + (0.001 if v >= 0 else -0.001), i,
                f"{v:+.4f}", va="center",
                ha="left" if v >= 0 else "right", fontsize=9)

plt.suptitle("Sampling Strategy Impact on F1-macro", fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Save summary to CSV ───────────────────────────────────────────────────
summary.to_csv("experiment_results.csv", index=False)
print("Saved to experiment_results.csv")
print()
print("Final summary:")
display(summary.sort_values(["Strategy", "F1-macro"], ascending=[True, False]))
# Out:
# Saved to experiment_results.csv
#
# Final summary:
#                     Strategy                Model  Accuracy  F1-macro  \
# 4                   baseline        Random Forest    0.4903    0.4416
# 0                   baseline              XGBoost    0.4708    0.4410
# 2                   baseline  Logistic Regression    0.4416    0.4315
# 1                   baseline                  SVM    0.4351    0.4267
# 3                   baseline                  KNN    0.4058    0.3726
# 14                oversample        Random Forest    0.5000    0.4796
# 10                oversample              XGBoost    0.4805    0.4624
# 11                oversample                  SVM    0.4481    0.4384
# 12                oversample  Logistic Regression    0.4481    0.4378
# 13                oversample                  KNN    0.4058    0.3971
# 7               remove_other  Logistic Regression    0.5174    0.5105
# 9               remove_other        Random Forest    0.5405    0.4973
# 5               remove_other              XGBoost    0.5135    0.4884
# 6               remove_other                  SVM    0.4865    0.4841
# 8               remove_other                  KNN    0.5174    0.4680
# 20   remove_other+oversample              XGBoost    0.5328    0.5161
# 24   remove_other+oversample        Random Forest    0.5328    0.5027
# 22   remove_other+oversample  Logistic Regression    0.5097    0.5025
# 21   remove_other+oversample                  SVM    0.4749    0.4700
# 23   remove_other+oversample                  KNN    0.4402    0.4371
# 27  remove_other+undersample  Logistic Regression    0.5290    0.5163
# 26  remove_other+undersample                  SVM    0.5135    0.5119
# 29  remove_other+undersample        Random Forest    0.5174    0.5038
# 25  remove_other+undersample              XGBoost    0.5135    0.5017
# 28  remove_other+undersample                  KNN    0.5135    0.4986
# 19               undersample        Random Forest    0.4838    0.4715
# 17               undersample  Logistic Regression    0.4545    0.4435
# 15               undersample              XGBoost    0.4545    0.4426
# 16               undersample                  SVM    0.4221    0.4165
# 18               undersample                  KNN    0.3701    0.3561
#
#     F1-weighted
# 4        0.4612
# 0        0.4577
# 2        0.4418
# 1        0.4321
# 3        0.3865
# 14       0.4908
# 10       0.4757
# 11       0.4429
# 12       0.4497
# 13       0.3995
# 7        0.5096
# 9        0.5193
# 5        0.5012
# 6        0.4862
# 8        0.4959
# 20       0.5244
# 24       0.5193
# 22       0.5028
# 21       0.4792
# 23       0.4511
# 27       0.5266
# 26       0.5158
# 29       0.5149
# 25       0.5123
# 28       0.5136
# 19       0.4799
# 17       0.4566
# 15       0.4517
# 16       0.4191
# 18       0.3625

# %% [markdown]
# # Hindi Song Mood Classifier — Experiment Grid
# ### Comparing models × sampling strategies
# **Models:** XGBoost, SVM, Logistic Regression, KNN, Random Forest
# **Strategies:** Baseline · Remove 'other' · Oversample (SMOTE) · Undersample · Remove+Oversample · Remove+Undersample
# **Total experiments:** 30 combinations

# %%
# Run once to install dependencies
# !pip install xgboost imbalanced-learn scikit-learn pandas matplotlib seaborn openpyxl

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from itertools import product

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import (classification_report, confusion_matrix,
                              accuracy_score, f1_score)
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as ImbPipeline

from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier

from sklearn.linear_model import RidgeClassifier, LogisticRegression
from sklearn.ensemble import ExtraTreesClassifier, AdaBoostClassifier, StackingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier

RANDOM_STATE = 42
pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:.4f}".format)
print("All imports OK")
# Out:
# All imports OK

# %%
# ── Load dataset ──────────────────────────────────────────────────────────
EXCEL_PATH = "3 moods with final mood_edited.xlsx"
TARGET_COL = "FINAL MOOD"

META_COLS = ["ID", "Song Title", "Film / Album", "Year",
             "ChatGPT Mood", "Claude Mood", "deepseek/copilot Mood",
             "FINAL MOOD", "Test", "File name"]

df = pd.read_excel(EXCEL_PATH)
FEATURE_COLS = [c for c in df.columns if c not in META_COLS]

print(f"Dataset shape   : {df.shape}")
print(f"Feature columns : {len(FEATURE_COLS)}")
print()
print("Class distribution:")
print(df[TARGET_COL].value_counts().to_string())
# Out:
# Dataset shape   : (1606, 61)
# Feature columns : 51
#
# Class distribution:
# FINAL MOOD
# romantic    398
# other       345
# sad         340
# excited     325
# happy       198

# %%
# ── Class distribution visualisation ─────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

counts = df[TARGET_COL].value_counts()
colors = ["#e74c3c", "#e67e22", "#3498db", "#2ecc71", "#9b59b6"]

axes[0].bar(counts.index, counts.values, color=colors)
axes[0].set_title("Full Dataset — Class Distribution", fontsize=13)
axes[0].set_xlabel("Mood"); axes[0].set_ylabel("Count")
for i, (cls, v) in enumerate(counts.items()):
    axes[0].text(i, v + 3, str(v), ha="center", fontsize=10, fontweight="bold")

counts_no_other = df.loc[df[TARGET_COL] != "other", TARGET_COL].value_counts()
axes[1].bar(counts_no_other.index, counts_no_other.values, color=colors[:4])
axes[1].set_title("Without 'other' Class", fontsize=13)
axes[1].set_xlabel("Mood"); axes[1].set_ylabel("Count")
for i, (cls, v) in enumerate(counts_no_other.items()):
    axes[1].text(i, v + 3, str(v), ha="center", fontsize=10, fontweight="bold")

plt.suptitle("Class Imbalance Overview", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Feature selection: drop low-variance + highly correlated ──────────────
from sklearn.preprocessing import MinMaxScaler

def drop_low_variance(X_df, threshold=0.01):
    scaled = pd.DataFrame(MinMaxScaler().fit_transform(X_df), columns=X_df.columns)
    return [c for c in scaled.columns if scaled[c].var() > threshold]

def drop_correlated(X_df, threshold=0.90):
    corr  = X_df.corr().abs()
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
    drop  = {c for c in upper.columns if any(upper[c] > threshold)}
    return [c for c in X_df.columns if c not in drop]

X_full = df[FEATURE_COLS].copy()
keep   = drop_low_variance(X_full)
X_full = X_full[keep]
keep   = drop_correlated(X_full)
X_full = X_full[keep]

print(f"Features after selection: {X_full.shape[1]}  (was {len(FEATURE_COLS)})")

y_full = df[TARGET_COL].values
# Out:
# Features after selection: 28  (was 51)

# %%
# ── Define models and sampling strategies ─────────────────────────────────

MODELS = {
    "LightGBM": LGBMClassifier(
        n_estimators=300, learning_rate=0.1,
        random_state=RANDOM_STATE, n_jobs=-1),

    "Gradient Boosting": GradientBoostingClassifier(
        n_estimators=200, learning_rate=0.1,
        random_state=RANDOM_STATE),
    "Decision Tree": DecisionTreeClassifier(
        max_depth=6, class_weight="balanced",
        random_state=RANDOM_STATE),
    "SGD": SGDClassifier(
        loss="log_loss", max_iter=1000, tol=1e-3,
        class_weight="balanced", random_state=RANDOM_STATE),
    "Naive Bayes": GaussianNB(),
    "Ridge": RidgeClassifier(random_state=RANDOM_STATE),
}

STRATEGIES = [
    "baseline",
    "remove_other",
    "oversample",
    "undersample",
    "remove_other+oversample",
    "remove_other+undersample",
]

print(f"Models     : {list(MODELS.keys())}")
print(f"Strategies : {STRATEGIES}")
print(f"\nTotal experiments : {len(MODELS) * len(STRATEGIES)}")
# Out:
# Models     : ['LightGBM', 'Gradient Boosting', 'Decision Tree', 'SGD', 'Naive Bayes', 'Ridge']
# Strategies : ['baseline', 'remove_other', 'oversample', 'undersample', 'remove_other+oversample', 'remove_other+undersample']
#
# Total experiments : 36

# %%
# ── Run all 30 experiments ────────────────────────────────────────────────

def prepare_data(strategy, X, y):
    """Apply sampling strategy and return (X_train, X_test, y_train, y_test, classes)."""
    remove_other = "remove_other" in strategy

    if remove_other:
        mask = y != "other"
        X_use, y_use = X[mask], y[mask]
    else:
        X_use, y_use = X.copy(), y.copy()

    le = LabelEncoder()
    y_enc = le.fit_transform(y_use)

    X_tr, X_te, y_tr, y_te = train_test_split(
        X_use.values, y_enc, test_size=0.2,
        stratify=y_enc, random_state=RANDOM_STATE)

    if "oversample" in strategy:
        sm = SMOTE(random_state=RANDOM_STATE)
        X_tr, y_tr = sm.fit_resample(X_tr, y_tr)
    elif "undersample" in strategy:
        rus = RandomUnderSampler(random_state=RANDOM_STATE)
        X_tr, y_tr = rus.fit_resample(X_tr, y_tr)

    return X_tr, X_te, y_tr, y_te, le


results = []  # list of dicts, one per experiment

for strategy in STRATEGIES:
    X_tr, X_te, y_tr, y_te, le = prepare_data(strategy, X_full, y_full)
    n_classes = len(le.classes_)

    print(f"\n{'='*60}")
    print(f"Strategy: {strategy.upper()}")
    print(f"  Train size: {len(X_tr)}  |  Test size: {len(X_te)}")
    print(f"  Classes: {list(le.classes_)}")
    tr_dist = pd.Series(y_tr).value_counts().to_dict()
    print(f"  Train dist: { {le.classes_[k]: v for k, v in tr_dist.items()} }")

    for model_name, clf in MODELS.items():
        # Wrap in scaling pipeline
        pipe = Pipeline([("sc", StandardScaler()), ("clf", clf)])

        pipe.fit(X_tr, y_tr)
        y_pred = pipe.predict(X_te)

        acc = accuracy_score(y_te, y_pred)
        f1  = f1_score(y_te, y_pred, average="macro")
        f1w = f1_score(y_te, y_pred, average="weighted")

        report = classification_report(
            y_te, y_pred, target_names=le.classes_, output_dict=True)

        results.append({
            "strategy"  : strategy,
            "model"     : model_name,
            "accuracy"  : acc,
            "f1_macro"  : f1,
            "f1_weighted": f1w,
            "report"    : report,
            "y_te"      : y_te,
            "y_pred"    : y_pred,
            "classes"   : list(le.classes_),
            "pipe"      : pipe,
        })

        print(f"  {model_name:<22}: Acc={acc:.4f}  F1-macro={f1:.4f}  F1-weighted={f1w:.4f}")

print("\n✅ All experiments complete.")
# Out:
# ============================================================
# Strategy: BASELINE
#   Train size: 1284  |  Test size: 322
#   Classes: ['excited', 'happy', 'other', 'romantic', 'sad']
#   Train dist: {'romantic': 318, 'other': 276, 'sad': 272, 'excited': 260, 'happy': 158}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001242 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6915
# [LightGBM] [Info] Number of data points in the train set: 1284, number of used features: 28
# [LightGBM] [Info] Start training from score -1.597054
# [LightGBM] [Info] Start training from score -2.095140
# [LightGBM] [Info] Start training from score -1.537335
# [LightGBM] [Info] Start training from score -1.395684
# [LightGBM] [Info] Start training from score -1.551933
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#   LightGBM              : Acc=0.4534  F1-macro=0.4376  F1-weighted=0.4497
#   Gradient Boosting     : Acc=0.4565  F1-macro=0.4445  F1-weighted=0.4539
#   Decision Tree         : Acc=0.3634  F1-macro=0.3568  F1-weighted=0.3672
#   SGD                   : Acc=0.3106  F1-macro=0.3050  F1-weighted=0.3142
#   Naive Bayes           : Acc=0.4596  F1-macro=0.4166  F1-weighted=0.4369
#   Ridge                 : Acc=0.4720  F1-macro=0.4096  F1-weighted=0.4399
#
# ============================================================
# Strategy: REMOVE_OTHER
#   Train size: 1008  |  Test size: 253
#   Classes: ['excited', 'happy', 'romantic', 'sad']
#   Train dist: {'romantic': 318, 'sad': 272, 'excited': 260, 'happy': 158}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000765 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6913
# [LightGBM] [Info] Number of data points in the train set: 1008, number of used features: 28
# [LightGBM] [Info] Start training from score -1.355042
# [LightGBM] [Info] Start training from score -1.853128
# [LightGBM] [Info] Start training from score -1.153672
# [LightGBM] [Info] Start training from score -1.309921
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#   LightGBM              : Acc=0.5375  F1-macro=0.5192  F1-weighted=0.5362
#   Gradient Boosting     : Acc=0.5771  F1-macro=0.5588  F1-weighted=0.5809
#   Decision Tree         : Acc=0.4980  F1-macro=0.4870  F1-weighted=0.4942
#   SGD                   : Acc=0.4506  F1-macro=0.4286  F1-weighted=0.4443
#   Naive Bayes           : Acc=0.5771  F1-macro=0.5217  F1-weighted=0.5565
#   Ridge                 : Acc=0.5613  F1-macro=0.5082  F1-weighted=0.5375
#
# ✅ All experiments complete.

# %%
# ── Summary table: all 30 experiments ────────────────────────────────────
summary = pd.DataFrame([{
    "Strategy"   : r["strategy"],
    "Model"      : r["model"],
    "Accuracy"   : round(r["accuracy"],  4),
    "F1-macro"   : round(r["f1_macro"],  4),
    "F1-weighted": round(r["f1_weighted"],4),
} for r in results])

# Highlight best F1-macro per strategy
def highlight_best(s):
    is_max = s == s.max()
    return ["background-color: #d4edda; font-weight: bold" if v else "" for v in is_max]

display(
    summary.style
    .apply(highlight_best, subset=["F1-macro"], axis=0)
    .format({"Accuracy": "{:.4f}", "F1-macro": "{:.4f}", "F1-weighted": "{:.4f}"})
    .set_caption("All Experiments — Green = best F1-macro per strategy")
)
# Out:
# <style type="text/css">
# #T_29110_row25_col3 {
#   background-color: #d4edda;
#   font-weight: bold;
# }
# </style>
# <table id="T_29110">
#   <caption>All Experiments — Green = best F1-macro per strategy</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29110_level0_col0" class="col_heading level0 col0" >Strategy</th>
#       <th id="T_29110_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_29110_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#       <th id="T_29110_level0_col3" class="col_heading level0 col3" >F1-macro</th>
#       <th id="T_29110_level0_col4" class="col_heading level0 col4" >F1-weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29110_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29110_row0_col0" class="data row0 col0" >baseline</td>
#       <td id="T_29110_row0_col1" class="data row0 col1" >LightGBM</td>
#       <td id="T_29110_row0_col2" class="data row0 col2" >0.4534</td>
#       <td id="T_29110_row0_col3" class="data row0 col3" >0.4376</td>
#       <td id="T_29110_row0_col4" class="data row0 col4" >0.4497</td>
#     </tr>
#     <tr>
#       <th id="T_29110_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_29110_row1_col0" class="data row1 col0" >baseline</td>
#       <td id="T_29110_row1_col1" class="data row1 col1" >Gradient Boosting</td>
#       <td id="T_29110_row1_col2" class="data row1 col2" >0.4565</td>
#       <td id="T_29110_row1_col3" class="data row1 col3" >0.4445</td>
#       <td id="T_29110_row1_col4" class="data row1 col4" >0.4539</td>
#     </tr>
#     <tr>
#       <th id="T_29110_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_29110_row2_col0" class="data row2 col0" >baseline</td>
#       <td id="T_29110_row2_col1" class="data row2 col1" >Decision Tree</td>
#       <td id="T_29110_row2_col2" class="data row2 col2" >0.3634</td>
#       <td id="T_29110_row2_col3" class="data row2 col3" >0.3568</td>
#       <td id="T_29110_row2_col4" class="data row2 col4" >0.3672</td>
#     </tr>
#     <tr>
#       <th id="T_29110_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_29110_row3_col0" class="data row3 col0" >baseline</td>
#       <td id="T_29110_row3_col1" class="data row3 col1" >SGD</td>
#       <td id="T_29110_row3_col2" class="data row3 col2" >0.3106</td>
#       <td id="T_29110_row3_col3" class="data row3 col3" >0.3050</td>
#       <td id="T_29110_row3_col4" class="data row3 col4" >0.3142</td>
#     </tr>
#     <tr>
#       <th id="T_29110_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_29110_row4_col0" class="data row4 col0" >baseline</td>
#       <td id="T_29110_row4_col1" class="data row4 col1" >Naive Bayes</td>
#       <td id="T_29110_row4_col2" class="data row4 col2" >0.4596</td>
#       <td id="T_29110_row4_col3" class="data row4 col3" >0.4166</td>
#       <td id="T_29110_row4_col4" class="data row4 col4" >0.4369</td>
#     </tr>
#     <tr>
#       <th id="T_29110_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_29110_row5_col0" class="data row5 col0" >baseline</td>
#       <td id="T_29110_row5_col1" class="data row5 col1" >Ridge</td>
#       <td id="T_29110_row5_col2" class="data row5 col2" >0.4720</td>
#       <td id="T_29110_row5_col3" class="data row5 col3" >0.4096</td>
#       <td id="T_29110_row5_col4" class="data row5 col4" >0.4399</td>
#     </tr>
#     <tr>
#       <th id="T_29110_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_29110_row6_col0" class="data row6 col0" >remove_other</td>
#       <td id="T_29110_row6_col1" class="data row6 col1" >LightGBM</td>
#       <td id="T_29110_row6_col2" class="data row6 col2" >0.5929</td>
#       <td id="T_29110_row6_col3" class="data row6 col3" >0.5487</td>
#       <td id="T_29110_row6_col4" class="data row6 col4" >0.5774</td>
#     </tr>
#     <tr>
#       <th id="T_29110_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_29110_row7_col0" class="data row7 col0" >remove_other</td>
#       <td id="T_29110_row7_col1" class="data row7 col1" >Gradient Boosting</td>
#       <td id="T_29110_row7_col2" class="data row7 col2" >0.5613</td>
#       <td id="T_29110_row7_col3" class="data row7 col3" >0.5063</td>
#       <td id="T_29110_row7_col4" class="data row7 col4" >0.5409</td>
#     </tr>
#     <tr>
#       <th id="T_29110_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_29110_row8_col0" class="data row8 col0" >remove_other</td>
#       <td id="T_29110_row8_col1" class="data row8 col1" >Decision Tree</td>
#       <td id="T_29110_row8_col2" class="data row8 col2" >0.4427</td>
#       <td id="T_29110_row8_col3" class="data row8 col3" >0.4139</td>
#       <td id="T_29110_row8_col4" class="data row8 col4" >0.4319</td>
#     </tr>
#     <tr>
#       <th id="T_29110_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_29110_row9_col0" class="data row9 col0" >remove_other</td>
#       <td id="T_29110_row9_col1" class="data row9 col1" >SGD</td>
#       <td id="T_29110_row9_col2" class="data row9 col2" >0.4506</td>
#       <td id="T_29110_row9_col3" class="data row9 col3" >0.4402</td>
#       <td id="T_29110_row9_col4" class="data row9 col4" >0.4631</td>
#     </tr>
#     <tr>
#       <th id="T_29110_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_29110_row10_col0" class="data row10 col0" >remove_other</td>
#       <td id="T_29110_row10_col1" class="data row10 col1" >Naive Bayes</td>
#       <td id="T_29110_row10_col2" class="data row10 col2" >0.5573</td>
#       <td id="T_29110_row10_col3" class="data row10 col3" >0.5041</td>
#       <td id="T_29110_row10_col4" class="data row10 col4" >0.5345</td>
#     </tr>
#     <tr>
#       <th id="T_29110_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_29110_row11_col0" class="data row11 col0" >remove_other</td>
#       <td id="T_29110_row11_col1" class="data row11 col1" >Ridge</td>
#       <td id="T_29110_row11_col2" class="data row11 col2" >0.5731</td>
#       <td id="T_29110_row11_col3" class="data row11 col3" >0.4791</td>
#       <td id="T_29110_row11_col4" class="data row11 col4" >0.5274</td>
#     </tr>
#     <tr>
#       <th id="T_29110_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_29110_row12_col0" class="data row12 col0" >oversample</td>
#       <td id="T_29110_row12_col1" class="data row12 col1" >LightGBM</td>
#       <td id="T_29110_row12_col2" class="data row12 col2" >0.4752</td>
#       <td id="T_29110_row12_col3" class="data row12 col3" >0.4671</td>
#       <td id="T_29110_row12_col4" class="data row12 col4" >0.4727</td>
#     </tr>
#     <tr>
#       <th id="T_29110_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_29110_row13_col0" class="data row13 col0" >oversample</td>
#       <td id="T_29110_row13_col1" class="data row13 col1" >Gradient Boosting</td>
#       <td id="T_29110_row13_col2" class="data row13 col2" >0.4317</td>
#       <td id="T_29110_row13_col3" class="data row13 col3" >0.4254</td>
#       <td id="T_29110_row13_col4" class="data row13 col4" >0.4343</td>
#     </tr>
#     <tr>
#       <th id="T_29110_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_29110_row14_col0" class="data row14 col0" >oversample</td>
#       <td id="T_29110_row14_col1" class="data row14 col1" >Decision Tree</td>
#       <td id="T_29110_row14_col2" class="data row14 col2" >0.3571</td>
#       <td id="T_29110_row14_col3" class="data row14 col3" >0.3466</td>
#       <td id="T_29110_row14_col4" class="data row14 col4" >0.3518</td>
#     </tr>
#     <tr>
#       <th id="T_29110_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_29110_row15_col0" class="data row15 col0" >oversample</td>
#       <td id="T_29110_row15_col1" class="data row15 col1" >SGD</td>
#       <td id="T_29110_row15_col2" class="data row15 col2" >0.4658</td>
#       <td id="T_29110_row15_col3" class="data row15 col3" >0.4308</td>
#       <td id="T_29110_row15_col4" class="data row15 col4" >0.4490</td>
#     </tr>
#     <tr>
#       <th id="T_29110_level0_row16" class="row_heading level

# %%
# ── Best model per strategy ───────────────────────────────────────────────
best_per_strategy = (
    summary.sort_values("F1-macro", ascending=False)
           .groupby("Strategy").first()
           .reset_index()
           [["Strategy", "Model", "Accuracy", "F1-macro", "F1-weighted"]]
           .sort_values("F1-macro", ascending=False)
)

print("Best model per strategy (sorted by F1-macro):")
display(best_per_strategy.style.format({
    "Accuracy": "{:.4f}", "F1-macro": "{:.4f}", "F1-weighted": "{:.4f}"}))
# Out:
# Best model per strategy (sorted by F1-macro):
# <style type="text/css">
# </style>
# <table id="T_194ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_194ed_level0_col0" class="col_heading level0 col0" >Strategy</th>
#       <th id="T_194ed_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_194ed_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#       <th id="T_194ed_level0_col3" class="col_heading level0 col3" >F1-macro</th>
#       <th id="T_194ed_level0_col4" class="col_heading level0 col4" >F1-weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_194ed_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_194ed_row0_col0" class="data row0 col0" >remove_other+oversample</td>
#       <td id="T_194ed_row0_col1" class="data row0 col1" >Gradient Boosting</td>
#       <td id="T_194ed_row0_col2" class="data row0 col2" >0.5810</td>
#       <td id="T_194ed_row0_col3" class="data row0 col3" >0.5620</td>
#       <td id="T_194ed_row0_col4" class="data row0 col4" >0.5805</td>
#     </tr>
#     <tr>
#       <th id="T_194ed_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_194ed_row1_col0" class="data row1 col0" >remove_other+undersample</td>
#       <td id="T_194ed_row1_col1" class="data row1 col1" >Gradient Boosting</td>
#       <td id="T_194ed_row1_col2" class="data row1 col2" >0.5771</td>
#       <td id="T_194ed_row1_col3" class="data row1 col3" >0.5588</td>
#       <td id="T_194ed_row1_col4" class="data row1 col4" >0.5809</td>
#     </tr>
#     <tr>
#       <th id="T_194ed_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_194ed_row2_col0" class="data row2 col0" >remove_other</td>
#       <td id="T_194ed_row2_col1" class="data row2 col1" >LightGBM</td>
#       <td id="T_194ed_row2_col2" class="data row2 col2" >0.5929</td>
#       <td id="T_194ed_row2_col3" class="data row2 col3" >0.5487</td>
#       <td id="T_194ed_row2_col4" class="data row2 col4" >0.5774</td>
#     </tr>
#     <tr>
#       <th id="T_194ed_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_194ed_row3_col0" class="data row3 col0" >oversample</td>
#       <td id="T_194ed_row3_col1" class="data row3 col1" >LightGBM</td>
#       <td id="T_194ed_row3_col2" class="data row3 col2" >0.4752</td>
#       <td id="T_194ed_row3_col3" class="data row3 col3" >0.4671</td>
#       <td id="T_194ed_row3_col4" class="data row3 col4" >0.4727</td>
#     </tr>
#     <tr>
#       <th id="T_194ed_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_194ed_row4_col0" class="data row4 col0" >baseline</td>
#       <td id="T_194ed_row4_col1" class="data row4 col1" >Gradient Boosting</td>
#       <td id="T_194ed_row4_col2" class="data row4 col2" >0.4565</td>
#       <td id="T_194ed_row4_col3" class="data row4 col3" >0.4445</td>
#       <td id="T_194ed_row4_col4" class="data row4 col4" >0.4539</td>
#     </tr>
#     <tr>
#       <th id="T_194ed_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_194ed_row5_col0" class="data row5 col0" >undersample</td>
#       <td id="T_194ed_row5_col1" class="data row5 col1" >LightGBM</td>
#       <td id="T_194ed_row5_col2" class="data row5 col2" >0.4161</td>
#       <td id="T_194ed_row5_col3" class="data row5 col3" >0.4153</td>
#       <td id="T_194ed_row5_col4" class="data row5 col4" >0.4222</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ── Heatmap: F1-macro for all model × strategy combinations ───────────────
pivot = summary.pivot(index="Model", columns="Strategy", values="F1-macro")
# Order strategies sensibly
col_order = [c for c in STRATEGIES if c in pivot.columns]
pivot = pivot[col_order]

fig, ax = plt.subplots(figsize=(14, 5))
sns.heatmap(pivot, annot=True, fmt=".3f", cmap="YlGn",
            linewidths=0.5, linecolor="white",
            annot_kws={"size": 11}, ax=ax,
            vmin=pivot.values.min() - 0.02,
            vmax=pivot.values.max() + 0.01)
ax.set_title("F1-macro Heatmap: Model × Sampling Strategy", fontsize=14, pad=12)
ax.set_xlabel("Strategy", fontsize=11)
ax.set_ylabel("Model", fontsize=11)
plt.xticks(rotation=25, ha="right")
plt.tight_layout()
plt.show()

# %%
# ── Heatmap: Accuracy ─────────────────────────────────────────────────────
pivot_acc = summary.pivot(index="Model", columns="Strategy", values="Accuracy")[col_order]

fig, ax = plt.subplots(figsize=(14, 5))
sns.heatmap(pivot_acc, annot=True, fmt=".3f", cmap="Blues",
            linewidths=0.5, linecolor="white",
            annot_kws={"size": 11}, ax=ax)
ax.set_title("Accuracy Heatmap: Model × Sampling Strategy", fontsize=14, pad=12)
ax.set_xlabel("Strategy", fontsize=11)
ax.set_ylabel("Model", fontsize=11)
plt.xticks(rotation=25, ha="right")
plt.tight_layout()
plt.show()

# %%
# ── Grouped bar: F1-macro per model across strategies ─────────────────────
fig, ax = plt.subplots(figsize=(15, 6))
model_names = list(MODELS.keys())
x = np.arange(len(model_names))
n_strat = len(STRATEGIES)
width = 0.13
colors_strat = plt.cm.Set2(np.linspace(0, 1, n_strat))

for i, strat in enumerate(STRATEGIES):
    vals = [summary.loc[(summary.Model == m) & (summary.Strategy == strat),
                        "F1-macro"].values[0] for m in model_names]
    offset = (i - n_strat / 2) * width + width / 2
    bars = ax.bar(x + offset, vals, width, label=strat, color=colors_strat[i])

ax.set_xlabel("Model", fontsize=12)
ax.set_ylabel("F1-macro", fontsize=12)
ax.set_title("F1-macro by Model and Sampling Strategy", fontsize=14)
ax.set_xticks(x); ax.set_xticklabels(model_names, fontsize=11)
ax.set_ylim(0, 1)
ax.legend(title="Strategy", bbox_to_anchor=(1.01, 1), loc="upper left", fontsize=9)
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# ── Per-class F1 breakdown for best experiment per strategy ───────────────
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

for ax_idx, strat in enumerate(STRATEGIES):
    # Find best model for this strategy
    strat_results = [r for r in results if r["strategy"] == strat]
    best = max(strat_results, key=lambda r: r["f1_macro"])
    classes = best["classes"]
    report  = best["report"]

    class_f1 = {cls: report[cls]["f1-score"] for cls in classes}
    mood_colors = {
        "happy":    "#2ecc71",
        "sad":      "#3498db",
        "romantic": "#e74c3c",
        "excited":  "#e67e22",
        "other":    "#95a5a6",
    }
    bar_colors = [mood_colors.get(c, "#7f8c8d") for c in class_f1]

    bars = axes[ax_idx].bar(class_f1.keys(), class_f1.values(), color=bar_colors)
    axes[ax_idx].set_title(
        f"{strat}\nBest: {best['model']}  (F1-macro={best['f1_macro']:.3f})",
        fontsize=10, fontweight="bold")
    axes[ax_idx].set_ylim(0, 1)
    axes[ax_idx].set_ylabel("F1-score")
    axes[ax_idx].axhline(best["f1_macro"], color="black",
                          linestyle="--", linewidth=1, alpha=0.5, label="macro avg")
    axes[ax_idx].legend(fontsize=8)
    for bar, (cls, val) in zip(bars, class_f1.items()):
        axes[ax_idx].text(bar.get_x() + bar.get_width()/2,
                           val + 0.01, f"{val:.2f}",
                           ha="center", va="bottom", fontsize=9)

plt.suptitle("Per-class F1 for Best Model per Strategy", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Confusion matrices for best model per strategy ────────────────────────
fig, axes = plt.subplots(2, 3, figsize=(18, 11))
axes = axes.flatten()

for ax_idx, strat in enumerate(STRATEGIES):
    strat_results = [r for r in results if r["strategy"] == strat]
    best = max(strat_results, key=lambda r: r["f1_macro"])

    cm   = confusion_matrix(best["y_te"], best["y_pred"])
    cm_n = cm.astype(float) / cm.sum(axis=1, keepdims=True)

    sns.heatmap(cm_n, annot=True, fmt=".2f", cmap="Blues",
                xticklabels=best["classes"], yticklabels=best["classes"],
                ax=axes[ax_idx], linewidths=0.3)
    axes[ax_idx].set_title(
        f"{strat}\n{best['model']}  Acc={best['accuracy']:.3f}",
        fontsize=10, fontweight="bold")
    axes[ax_idx].set_xlabel("Predicted"); axes[ax_idx].set_ylabel("Actual")

plt.suptitle("Confusion Matrices — Best Model per Strategy (normalised)",
             fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Full classification reports for every experiment ─────────────────────
for strat in STRATEGIES:
    print("\n" + "="*70)
    print(f"  STRATEGY: {strat.upper()}")
    print("="*70)
    for r in [x for x in results if x["strategy"] == strat]:
        print(f"\n--- {r['model']} ---")
        print(f"  Accuracy   : {r['accuracy']:.4f}")
        print(f"  F1-macro   : {r['f1_macro']:.4f}")
        print(f"  F1-weighted: {r['f1_weighted']:.4f}")
        rpt = r["report"]
        header = f"{'Class':<14} {'Precision':>10} {'Recall':>10} {'F1':>10} {'Support':>10}"
        print("  " + header)
        print("  " + "-"*len(header))
        for cls in r["classes"]:
            row = rpt[cls]
            print(f"  {cls:<14} {row['precision']:>10.4f} {row['recall']:>10.4f} "
                  f"{row['f1-score']:>10.4f} {int(row['support']):>10}")
        print(f"  {'macro avg':<14} {rpt['macro avg']['precision']:>10.4f} "
              f"{rpt['macro avg']['recall']:>10.4f} "
              f"{rpt['macro avg']['f1-score']:>10.4f} "
              f"{int(rpt['macro avg']['support']):>10}")
# Out:
# ======================================================================
#   STRATEGY: BASELINE
# ======================================================================
#
# --- LightGBM ---
#   Accuracy   : 0.4534
#   F1-macro   : 0.4376
#   F1-weighted: 0.4497
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7344     0.7231     0.7287         65
#   happy              0.3478     0.2000     0.2540         40
#   other              0.3824     0.3768     0.3796         69
#   romantic           0.3789     0.4500     0.4114         80
#   sad                0.4028     0.4265     0.4143         68
#   macro avg          0.4493     0.4353     0.4376        322
#
# --- Gradient Boosting ---
#   Accuracy   : 0.4565
#   F1-macro   : 0.4445
#   F1-weighted: 0.4539
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6970     0.7077     0.7023         65
#   happy              0.4091     0.2250     0.2903         40
#   other              0.4923     0.4638     0.4776         69
#   romantic           0.3684     0.4375     0.4000         80
#   sad                0.3378     0.3676     0.3521         68
#   macro avg          0.4609     0.4403     0.4445        322
#
# --- Decision Tree ---
#   Accuracy   : 0.3634
#   F1-macro   : 0.3568
#   F1-weighted: 0.3672
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6119     0.6308     0.6212         65
#   happy              0.1579     0.2250     0.1856         40
#   other              0.4364     0.3478     0.3871         69
#   romantic           0.3000     0.3000     0.3000         80
#   sad                0.3016     0.2794     0.2901         68
#   macro avg          0.3616     0.3566     0.3568        322
#
# --- SGD ---
#   Accuracy   : 0.3106
#   F1-macro   : 0.3050
#   F1-weighted: 0.3142
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6875     0.3385     0.4536         65
#   happy              0.1714     0.1500     0.1600         40
#   other              0.3333     0.4348     0.3774         69
#   romantic           0.2687     0.2250     0.2449         80
#   sad                0.2449     0.3529     0.2892         68
#   macro avg          0.3412     0.3002     0.3050        322
#
# --- Naive Bayes ---
#   Accuracy   : 0.4596
#   F1-macro   : 0.4166
#   F1-weighted: 0.4369
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5532     0.8000     0.6541         65
#   happy              0.3333     0.1000     0.1538         40
#   other              0.4286     0.3913     0.4091         69
#   romantic           0.4156     0.4000     0.4076         80
#   sad                0.4342     0.4853     0.4583         68
#   macro avg          0.4330     0.4353     0.4166        322
#
# --- Ridge ---
#   Accuracy   : 0.4720
#   F1-macro   : 0.4096
#   F1-weighted: 0.4399
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5667     0.7846     0.6581         65
#   happy              0.5000     0.0250     0.0476         40
#   other              0.4605     0.5072     0.4828         69
#   romantic           0.4000     0.4750     0.4343         80
#   sad                0.4576     0.3971     0.4252         68
#   macro avg          0.4770     0.4378     0.4096        322
#
# ======================================================================
#   STRATEGY: REMOVE_OTHER
# ======================================================================
#
# --- LightGBM ---
#   Accuracy   : 0.5929
#   F1-macro   : 0.5487
#   F1-weighted: 0.5774
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7222     0.8000     0.7591         65
#   happy              0.4444     0.2000     0.2759         40
#   romantic           0.5263     0.6250     0.5714         80
#   sad                0.5882     0.5882     0.5882         68
#   macro avg          0.5703     0.5533     0.5487        253
#
# --- Gradient Boosting ---
#   Accuracy   : 0.5613
#   F1-macro   : 0.5063
#   F1-weighted: 0.5409
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7059     0.7385     0.7218         65
#   happy              0.3846     0.1250     0.1887         40
#   romantic           0.4902     0.6250     0.5495         80
#   sad                0.5571     0.5735     0.5652         68
#   macro avg          0.5345     0.5155     0.5063        253
#
# --- Decision Tree ---
#   Accuracy   : 0.4427
#   F1-macro   : 0.4139
#   F1-weighted: 0.4319
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6780     0.6154     0.6452         65
#   happy              0.1633     0.2000     0.1798         40
#   romantic           0.4737     0.2250     0.3051         80
#   sad                0.4299     0.6765     0.5257         68
#   macro avg          0.4362     0.4292     0.4139        253
#
# --- SGD ---
#   Accuracy   : 0.4506
#   F1-macro   : 0.4402
#   F1-weighted: 0.4631
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7619     0.7385     0.7500         65
#   happy              0.1515     0.2500     0.1887         40
#   romantic           0.4048     0.4250     0.4146         80
#   sad                0.5500     0.3235     0.4074         68
#   macro avg          0.4670     0.4342     0.4402        253
#
# --- Naive Bayes ---
#   Accuracy   : 0.5573
#   F1-macro   : 0.5041
#   F1-weighted: 0.5345
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6279     0.8308     0.7152         65
#   happy              0.3750     0.1500     0.2143         40
#   romantic           0.5185     0.5250     0.5217         80
#   sad                0.5571     0.5735     0.5652         68
#   macro avg          0.5196     0.5198     0.5041        253
#
# --- Ridge ---
#   Accuracy   : 0.5731
#   F1-macro   : 0.4791
#   F1-weighted: 0.5274
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6374     0.8923     0.7436         65
#   happy              0.2500     0.0250     0.0455         40
#   romantic           0.5106     0.6000     0.5517         80
#   sad                0.5938     0.5588     0.5758         68
#   macro avg          0.4979     0.5190     0.4791        253
#
# ======================================================================
#   STRATEGY: OVERSAMPLE
# ======================================================================
#
# --- LightGBM ---
#   Accuracy   : 0.4752
#   F1-macro   : 0.4671
#   F1-weighted: 0.4727
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7143     0.7692     0.7407         65
#   happy              0.3514     0.3250     0.3377         40
#   other              0.5000     0.4783     0.4889         69
#   romantic           0.3735     0.3875     0.3804         80
#   sad                0.3939     0.3824     0.3881         68
#   macro avg          0.4666     0.4685     0.4671        322
#
# --- Gradient Boosting ---
#   Accuracy   : 0.4317
#   F1-macro   : 0.4254
#   F1-weighted: 0.4343
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7273     0.7385     0.7328         65
#   happy              0.2115     0.2750     0.2391         40
#   other              0.4746     0.4058     0.4375         69
#   romantic           0.3117     0.3000     0.3057         80
#   sad                0.4118     0.4118     0.4118         68
#   macro avg          0.4274     0.4262     0.4254        322
#
# --- Decision Tree ---
#   Accuracy   : 0.3571
#   F1-macro   : 0.3466
#   F1-weighted: 0.3518
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5660     0.4615     0.5085         65
#   happy              0.1486     0.2750     0.1930         40
#   other              0.3365     0.5072     0.4046         69
#   romantic           0.3103     0.1125     0.1651         80
#   sad                0.4839     0.4412     0.4615         68
#   macro avg          0.3691     0.3595     0.3466        322
#
# --- SGD ---
#   Accuracy   : 0.4658
#   F1-macro   : 0.4308
#   F1-weighted: 0.4490
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5914     0.8462     0.6962         65
#   happy              0.2069     0.1500     0.1739         40
#   other              0.4925     0.4783     0.4853         69
#   romantic           0.4242     0.3500     0.3836         80
#   sad                0.4179     0.4118     0.4148         68
#   macro avg          0.4266     0.4472     0.4308        322
#
# --- Naive Bayes ---
#   Accuracy   : 0.4410
#   F1-macro   : 0.4137
#   F1-weighted: 0.4211
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5824     0.8154     0.6795         65
#   happy              0.2647     0.2250     0.2432         40
#   other              0.4118     0.4058     0.4088         69
#   romantic           0.3830     0.2250     0.2835         80
#   sad                0.4146     0.5000     0.4533         68
#   macro avg          0.4113     0.4342     0.4137        322
#
# --- Ridge ---
#   Accuracy   : 0.4348
#   F1-macro   : 0.4079
#   F1-weighted: 0.4195
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5638     0.8154     0.6667         65
#   happy              0.2051     0.2000     0.2025         40
#   other              0.4429     0.4493     0.4460         69
#   romantic           0.3559     0.2625     0.3022         80
#   sad                0.4500     0.3971     0.4219         68
#   macro avg          0.4035     0.4248     0.4079        322
#
# ======================================================================
#   STRATEGY: UNDERSAMPLE
# ======================================================================
#
# --- LightGBM ---
#   Accuracy   : 0.4161
#   F1-macro   : 0.4153
#   F1-weighted: 0.4222
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6610     0.6000     0.6290         65
#   happy              0.2373     0.3500     0.2828         40
#   other              0.4219     0.3913     0.4060         69
#   romantic           0.3415     0.3500     0.3457         80
#   sad                0.4483     0.3824     0.4127         68
#   macro avg          0.4220     0.4147     0.4153        322
#
# --- Gradient Boosting ---
#   Accuracy   : 0.4068
#   F1-macro   : 0.4080
#   F1-weighted: 0.4109
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6949     0.6308     0.6613         65
#   happy              0.2540     0.4000     0.3107         40
#   other              0.4259     0.3333     0.3740         69
#   romantic           0.3529     0.3000     0.3243         80
#   sad                0.3462     0.3971     0.3699         68
#   macro avg          0.4148     0.4122     0.4080        322
#
# --- Decision Tree ---
#   Accuracy   : 0.3075
#   F1-macro   : 0.3042
#   F1-weighted: 0.3070
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.4821     0.4154     0.4463         65
#   happy              0.1961     0.2500     0.2198         40
#   other              0.3433     0.3333     0.3382         69
#   romantic           0.2745     0.1750     0.2137         80
#   sad                0.2577     0.3676     0.3030         68
#   macro avg          0.3107     0.3083     0.3042        322
#
# --- SGD ---
#   Accuracy   : 0.3634
#   F1-macro   : 0.3431
#   F1-weighted: 0.3552
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5270     0.6000     0.5612         65
#   happy              0.1429     0.1250     0.1333         40
#   other              0.4032     0.3623     0.3817         69
#   romantic           0.2537     0.2125     0.2313         80
#   sad                0.3690     0.4559     0.4079         68
#   macro avg          0.3392     0.3511     0.3431        322
#
# --- Naive Bayes ---
#   Accuracy   : 0.4348
#   F1-macro   : 0.3977
#   F1-weighted: 0.4154
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5833     0.7538     0.6577         65
#   happy              0.2105     0.1000     0.1356         40
#   other              0.3780     0.4493     0.4106         69
#   romantic           0.3770     0.2875     0.3262         80
#   sad                0.4342     0.4853     0.4583         68
#   macro avg          0.3966     0.4152     0.3977        322
#
# --- Ridge ---
#   Accuracy   : 0.4037
#   F1-macro   : 0.3767
#   F1-weighted: 0.3894
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5765     0.7538     0.6533         65
#   happy              0.1714     0.1500     0.1600         40
#   other              0.3974     0.4493     0.4218         69
#   romantic           0.3276     0.2375     0.2754         80
#   sad                0.3788     0.3676     0.3731         68
#   macro avg          0.3703     0.3917     0.3767        322
#
# ======================================================================
#   STRATEGY: REMOVE_OTHER+OVERSAMPLE
# ======================================================================
#
# --- LightGBM ---
#   Accuracy   : 0.5771
#   F1-macro   : 0.5471
#   F1-weighted: 0.5686
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7027     0.8000     0.7482         65
#   happy              0.3793     0.2750     0.3188         40
#   romantic           0.5122     0.5250     0.5185         80
#   sad                0.6029     0.6029     0.6029         68
#   macro avg          0.5493     0.5507     0.5471        253
#
# --- Gradient Boosting ---
#   Accuracy   : 0.5810
#   F1-macro   : 0.5620
#   F1-weighted: 0.5805
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7576     0.7692     0.7634         65
#   happy              0.3684     0.3500     0.3590         40
#   romantic           0.5116     0.5500     0.5301         80
#   sad                0.6190     0.5735     0.5954         68
#   macro avg          0.5642     0.5607     0.5620        253
#
# --- Decision Tree ---
#   Accuracy   : 0.4387
#   F1-macro   : 0.4220
#   F1-weighted: 0.4314
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6923     0.5538     0.6154         65
#   happy              0.2034     0.3000     0.2424         40
#   romantic           0.3333     0.2000     0.2500         80
#   sad                0.5000     0.6912     0.5802         68
#   macro avg          0.4323     0.4363     0.4220        253
#
# --- SGD ---
#   Accuracy   : 0.4901
#   F1-macro   : 0.4702
#   F1-weighted: 0.4934
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7188     0.7077     0.7132         65
#   happy              0.2174     0.2500     0.2326         40
#   romantic           0.4684     0.4625     0.4654         80
#   sad                0.4844     0.4559     0.4697         68
#   macro avg          0.4722     0.4690     0.4702        253
#
# --- Naive Bayes ---
#   Accuracy   : 0.5336
#   F1-macro   : 0.4992
#   F1-weighted: 0.5186
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6548     0.8462     0.7383         65
#   happy              0.2391     0.2750     0.2558         40
#   romantic           0.5556     0.3125     0.4000         80
#   sad                0.5641     0.6471     0.6027         68
#   macro avg          0.5034     0.5202     0.4992        253
#
# --- Ridge ---
#   Accuracy   : 0.5415
#   F1-macro   : 0.5016
#   F1-weighted: 0.5276
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6591     0.8923     0.7582         65
#   happy              0.2093     0.2250     0.2169         40
#   romantic           0.5918     0.3625     0.4496         80
#   sad                0.5616     0.6029     0.5816         68
#   macro avg          0.5055     0.5207     0.5016        253
#
# ======================================================================
#   STRATEGY: REMOVE_OTHER+UNDERSAMPLE
# ======================================================================
#
# --- LightGBM ---
#   Accuracy   : 0.5375
#   F1-macro   : 0.5192
#   F1-weighted: 0.5362
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7576     0.7692     0.7634         65
#   happy              0.2708     0.3250     0.2955         40
#   romantic           0.4688     0.3750     0.4167         80
#   sad                0.5733     0.6324     0.6014         68
#   macro avg          0.5176     0.5254     0.5192        253
#
# --- Gradient Boosting ---
#   Accuracy   : 0.5771
#   F1-macro   : 0.5588
#   F1-weighted: 0.5809
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7313     0.7538     0.7424         65
#   happy              0.3000     0.3750     0.3333         40
#   romantic           0.5775     0.5125     0.5430         80
#   sad                0.6308     0.6029     0.6165         68
#   macro avg          0.5599     0.5611     0.5588        253
#
# --- Decision Tree ---
#   Accuracy   : 0.4980
#   F1-macro   : 0.4870
#   F1-weighted: 0.4942
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7000     0.7538     0.7259         65
#   happy              0.2687     0.4500     0.3364         40
#   romantic           0.4783     0.2750     0.3492         80
#   sad                0.5286     0.5441     0.5362         68
#   macro avg          0.4939     0.5057     0.4870        253
#
# --- SGD ---
#   Accuracy   : 0.4506
#   F1-macro   : 0.4286
#   F1-weighted: 0.4443
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6883     0.8154     0.7465         65
#   happy              0.1754     0.2500     0.2062         40
#   romantic           0.4118     0.2625     0.3206         80
#   sad                0.4412     0.4412     0.4412         68
#   macro avg          0.4292     0.4423     0.4286        253
#
# --- Naive Bayes ---
#   Accuracy   : 0.5771
#   F1-macro   : 0.5217
#   F1-weighted: 0.5565
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6353     0.8308     0.7200         65
#   happy              0.2727     0.1500     0.1935         40
#   romantic           0.5694     0.5125     0.5395         80
#   sad                0.6081     0.6618     0.6338         68
#   macro avg          0.5214     0.5388     0.5217        253
#
# --- Ridge ---
#   Accuracy   : 0.5613
#   F1-macro   : 0.5082
#   F1-weighted: 0.5375
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6484     0.9077     0.7564         65
#   happy              0.2121     0.1750     0.1918         40
#   romantic           0.5918     0.3625     0.4496         80
#   sad                0.5875     0.6912     0.6351         68
#   macro avg          0.5100     0.5341     0.5082        253

# %%
# ── Overall leaderboard: top 10 experiments ──────────────────────────────
leaderboard = summary.sort_values("F1-macro", ascending=False).head(10).reset_index(drop=True)
leaderboard.index += 1
print("Top 10 experiments overall:")
display(leaderboard.style
    .format({"Accuracy": "{:.4f}", "F1-macro": "{:.4f}", "F1-weighted": "{:.4f}"})
    .bar(subset=["F1-macro"], color="#2ecc71", vmin=0, vmax=1)
    .set_caption("Top 10 — sorted by F1-macro"))
# Out:
# Top 10 experiments overall:
# <style type="text/css">
# #T_95780_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 56.2%, transparent 56.2%);
# }
# #T_95780_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 55.9%, transparent 55.9%);
# }
# #T_95780_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 54.9%, transparent 54.9%);
# }
# #T_95780_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 54.7%, transparent 54.7%);
# }
# #T_95780_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 52.2%, transparent 52.2%);
# }
# #T_95780_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 51.9%, transparent 51.9%);
# }
# #T_95780_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 50.8%, transparent 50.8%);
# }
# #T_95780_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 50.6%, transparent 50.6%);
# }
# #T_95780_row8_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 50.4%, transparent 50.4%);
# }
# #T_95780_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 50.2%, transparent 50.2%);
# }
# </style>
# <table id="T_95780">
#   <caption>Top 10 — sorted by F1-macro</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95780_level0_col0" class="col_heading level0 col0" >Strategy</th>
#       <th id="T_95780_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_95780_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#       <th id="T_95780_level0_col3" class="col_heading level0 col3" >F1-macro</th>
#       <th id="T_95780_level0_col4" class="col_heading level0 col4" >F1-weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95780_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_95780_row0_col0" class="data row0 col0" >remove_other+oversample</td>
#       <td id="T_95780_row0_col1" class="data row0 col1" >Gradient Boosting</td>
#       <td id="T_95780_row0_col2" class="data row0 col2" >0.5810</td>
#       <td id="T_95780_row0_col3" class="data row0 col3" >0.5620</td>
#       <td id="T_95780_row0_col4" class="data row0 col4" >0.5805</td>
#     </tr>
#     <tr>
#       <th id="T_95780_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_95780_row1_col0" class="data row1 col0" >remove_other+undersample</td>
#       <td id="T_95780_row1_col1" class="data row1 col1" >Gradient Boosting</td>
#       <td id="T_95780_row1_col2" class="data row1 col2" >0.5771</td>
#       <td id="T_95780_row1_col3" class="data row1 col3" >0.5588</td>
#       <td id="T_95780_row1_col4" class="data row1 col4" >0.5809</td>
#     </tr>
#     <tr>
#       <th id="T_95780_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_95780_row2_col0" class="data row2 col0" >remove_other</td>
#       <td id="T_95780_row2_col1" class="data row2 col1" >LightGBM</td>
#       <td id="T_95780_row2_col2" class="data row2 col2" >0.5929</td>
#       <td id="T_95780_row2_col3" class="data row2 col3" >0.5487</td>
#       <td id="T_95780_row2_col4" class="data row2 col4" >0.5774</td>
#     </tr>
#     <tr>
#       <th id="T_95780_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_95780_row3_col0" class="data row3 col0" >remove_other+oversample</td>
#       <td id="T_95780_row3_col1" class="data row3 col1" >LightGBM</td>
#       <td id="T_95780_row3_col2" class="data row3 col2" >0.5771</td>
#       <td id="T_95780_row3_col3" class="data row3 col3" >0.5471</td>
#       <td id="T_95780_row3_col4" class="data row3 col4" >0.5686</td>
#     </tr>
#     <tr>
#       <th id="T_95780_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_95780_row4_col0" class="data row4 col0" >remove_other+undersample</td>
#       <td id="T_95780_row4_col1" class="data row4 col1" >Naive Bayes</td>
#       <td id="T_95780_row4_col2" class="data row4 col2" >0.5771</td>
#       <td id="T_95780_row4_col3" class="data row4 col3" >0.5217</td>
#       <td id="T_95780_row4_col4" class="data row4 col4" >0.5565</td>
#     </tr>
#     <tr>
#       <th id="T_95780_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_95780_row5_col0" class="data row5 col0" >remove_other+undersample</td>
#       <td id="T_95780_row5_col1" class="data row5 col1" >LightGBM</td>
#       <td id="T_95780_row5_col2" class="data row5 col2" >0.5375</td>
#       <td id="T_95780_row5_col3" class="data row5 col3" >0.5192</td>
#       <td id="T_95780_row5_col4" class="data row5 col4" >0.5362</td>
#     </tr>
#     <tr>
#       <th id="T_95780_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_95780_row6_col0" class="data row6 col0" >remove_other+undersample</td>
#       <td id="T_95780_row6_col1" class="data row6 col1" >Ridge</td>
#       <td id="T_95780_row6_col2" class="data row6 col2" >0.5613</td>
#       <td id="T_95780_row6_col3" class="data row6 col3" >0.5082</td>
#       <td id="T_95780_row6_col4" class="data row6 col4" >0.5375</td>
#     </tr>
#     <tr>
#       <th id="T_95780_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_95780_row7_col0" class="data row7 col0" >remove_other</td>
#       <td id="T_95780_row7_col1" class="data row7 col1" >Gradient Boosting</td>
#       <td id="T_95780_row7_col2" class="data row7 col2" >0.5613</td>
#       <td id="T_95780_row7_col3" class="data row7 col3" >0.5063</td>
#       <td id="T_95780_row7_col4" class="data row7 col4" >0.5409</td>
#     </tr>
#     <tr>
#       <th id="T_95780_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_95780_row8_col0" class="data row8 col0" >remove_other</td>
#       <td id="T_95780_row8_col1" class="data row8 col1" >Naive Bayes</td>
#       <td id="T_95780_row8_col2" class="data row8 col2" >0.5573</td>
#       <td id="T_95780_row8_col3" class="data row8 col3" >0.5041</td>
#       <td id="T_95780_row8_col4" class="data row8 col4" >0.5345</td>
#     </tr>
#     <tr>
#       <th id="T_95780_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_95780_row9_col0" class="data row9 col0" >remove_other+oversample</td>
#       <td id="T_95780_row9_col1" class="data row9 col1" >Ridge</td>
#       <td id="T_95780_row9_col2" class="data row9 col2" >0.5415</td>
#       <td id="T_95780_row9_col3" class="data row9 col3" >0.5016</td>
#       <td id="T_95780_row9_col4" class="data row9 col4" >0.5276</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ── Impact analysis: removing 'other' class ──────────────────────────────
baseline_f1    = summary[summary.Strategy == "baseline"].set_index("Model")["F1-macro"]
no_other_f1    = summary[summary.Strategy == "remove_other"].set_index("Model")["F1-macro"]
delta = (no_other_f1 - baseline_f1).sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(9, 4))
colors = ["#2ecc71" if v >= 0 else "#e74c3c" for v in delta.values]
ax.barh(delta.index, delta.values, color=colors)
ax.axvline(0, color="black", linewidth=1)
ax.set_xlabel("F1-macro change")
ax.set_title("Impact of Removing 'other' Class on F1-macro\n(green = improvement)")
for i, v in enumerate(delta.values):
    ax.text(v + (0.001 if v >= 0 else -0.001), i,
            f"{v:+.4f}", va="center",
            ha="left" if v >= 0 else "right", fontsize=10)
plt.tight_layout()
plt.show()

print("\nDelta F1-macro (remove_other - baseline):")
print(delta.to_string())
# Out:
# Delta F1-macro (remove_other - baseline):
# Model
# SGD                 0.1352
# LightGBM            0.1111
# Naive Bayes         0.0875
# Ridge               0.0695
# Gradient Boosting   0.0618
# Decision Tree       0.0571

# %%
# ── Impact analysis: sampling strategies vs baseline ─────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for ax, ref_strat, compare_strat, title in [
    (axes[0], "baseline",     "oversample",  "Oversample vs Baseline"),
    (axes[1], "baseline",     "undersample", "Undersample vs Baseline"),
]:
    ref  = summary[summary.Strategy == ref_strat].set_index("Model")["F1-macro"]
    comp = summary[summary.Strategy == compare_strat].set_index("Model")["F1-macro"]
    delta = (comp - ref).sort_values(ascending=False)
    colors = ["#2ecc71" if v >= 0 else "#e74c3c" for v in delta.values]
    ax.barh(delta.index, delta.values, color=colors)
    ax.axvline(0, color="black", linewidth=1)
    ax.set_xlabel("F1-macro change")
    ax.set_title(title)
    for i, v in enumerate(delta.values):
        ax.text(v + (0.001 if v >= 0 else -0.001), i,
                f"{v:+.4f}", va="center",
                ha="left" if v >= 0 else "right", fontsize=9)

plt.suptitle("Sampling Strategy Impact on F1-macro", fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Save summary to CSV ───────────────────────────────────────────────────
summary.to_csv("experiment_results.csv", index=False)
print("Saved to experiment_results.csv")
print()
print("Final summary:")
display(summary.sort_values(["Strategy", "F1-macro"], ascending=[True, False]))
# Out:
# Saved to experiment_results.csv
#
# Final summary:
#                     Strategy              Model  Accuracy  F1-macro  \
# 1                   baseline  Gradient Boosting    0.4565    0.4445
# 0                   baseline           LightGBM    0.4534    0.4376
# 4                   baseline        Naive Bayes    0.4596    0.4166
# 5                   baseline              Ridge    0.4720    0.4096
# 2                   baseline      Decision Tree    0.3634    0.3568
# 3                   baseline                SGD    0.3106    0.3050
# 12                oversample           LightGBM    0.4752    0.4671
# 15                oversample                SGD    0.4658    0.4308
# 13                oversample  Gradient Boosting    0.4317    0.4254
# 16                oversample        Naive Bayes    0.4410    0.4137
# 17                oversample              Ridge    0.4348    0.4079
# 14                oversample      Decision Tree    0.3571    0.3466
# 6               remove_other           LightGBM    0.5929    0.5487
# 7               remove_other  Gradient Boosting    0.5613    0.5063
# 10              remove_other        Naive Bayes    0.5573    0.5041
# 11              remove_other              Ridge    0.5731    0.4791
# 9               remove_other                SGD    0.4506    0.4402
# 8               remove_other      Decision Tree    0.4427    0.4139
# 25   remove_other+oversample  Gradient Boosting    0.5810    0.5620
# 24   remove_other+oversample           LightGBM    0.5771    0.5471
# 29   remove_other+oversample              Ridge    0.5415    0.5016
# 28   remove_other+oversample        Naive Bayes    0.5336    0.4992
# 27   remove_other+oversample                SGD    0.4901    0.4702
# 26   remove_other+oversample      Decision Tree    0.4387    0.4220
# 31  remove_other+undersample  Gradient Boosting    0.5771    0.5588
# 34  remove_other+undersample        Naive Bayes    0.5771    0.5217
# 30  remove_other+undersample           LightGBM    0.5375    0.5192
# 35  remove_other+undersample              Ridge    0.5613    0.5082
# 32  remove_other+undersample      Decision Tree    0.4980    0.4870
# 33  remove_other+undersample                SGD    0.4506    0.4286
# 18               undersample           LightGBM    0.4161    0.4153
# 19               undersample  Gradient Boosting    0.4068    0.4080
# 22               undersample        Naive Bayes    0.4348    0.3977
# 23               undersample              Ridge    0.4037    0.3767
# 21               undersample                SGD    0.3634    0.3431
# 20               undersample      Decision Tree    0.3075    0.3042
#
#     F1-weighted
# 1        0.4539
# 0        0.4497
# 4        0.4369
# 5        0.4399
# 2        0.3672
# 3        0.3142
# 12       0.4727
# 15       0.4490
# 13       0.4343
# 16       0.4211
# 17       0.4195
# 14       0.3518
# 6        0.5774
# 7        0.5409
# 10       0.5345
# 11       0.5274
# 9        0.4631
# 8        0.4319
# 25       0.5805
# 24       0.5686
# 29       0.5276
# 28       0.5186
# 27       0.4934
# 26       0.4314
# 31       0.5809
# 34       0.5565
# 30       0.5362
# 35       0.5375
# 32       0.4942
# 33       0.4443
# 18       0.4222
# 19       0.4109
# 22       0.4154
# 23       0.3894
# 21       0.3552
# 20       0.3070

# %% [markdown]
# # Hindi Song Mood Classifier — Experiment Grid
# ### Comparing models × sampling strategies
# **Models:** XGBoost, SVM, Logistic Regression, KNN, Random Forest
# **Strategies:** Baseline · Remove 'other' · Oversample (SMOTE) · Undersample · Remove+Oversample · Remove+Undersample
# **Total experiments:** 30 combinations

# %%
# Run once to install dependencies
# !pip install xgboost imbalanced-learn scikit-learn pandas matplotlib seaborn openpyxl

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from itertools import product

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import (classification_report, confusion_matrix,
                              accuracy_score, f1_score)
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as ImbPipeline

RANDOM_STATE = 42
pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:.4f}".format)
print("All imports OK")
# Out:
# All imports OK

# %%
# ── Load dataset ──────────────────────────────────────────────────────────
EXCEL_PATH = "3 moods with final mood_edited.xlsx"
TARGET_COL = "FINAL MOOD"

META_COLS = ["ID", "Song Title", "Film / Album", "Year",
             "ChatGPT Mood", "Claude Mood", "deepseek/copilot Mood",
             "FINAL MOOD", "Test", "File name"]

df = pd.read_excel(EXCEL_PATH)
FEATURE_COLS = [c for c in df.columns if c not in META_COLS]

print(f"Dataset shape   : {df.shape}")
print(f"Feature columns : {len(FEATURE_COLS)}")
print()
print("Class distribution:")
print(df[TARGET_COL].value_counts().to_string())
# Out:
# Dataset shape   : (1606, 61)
# Feature columns : 51
#
# Class distribution:
# FINAL MOOD
# romantic    398
# other       345
# sad         340
# excited     325
# happy       198

# %%
# ── Class distribution visualisation ─────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

counts = df[TARGET_COL].value_counts()
colors = ["#e74c3c", "#e67e22", "#3498db", "#2ecc71", "#9b59b6"]

axes[0].bar(counts.index, counts.values, color=colors)
axes[0].set_title("Full Dataset — Class Distribution", fontsize=13)
axes[0].set_xlabel("Mood"); axes[0].set_ylabel("Count")
for i, (cls, v) in enumerate(counts.items()):
    axes[0].text(i, v + 3, str(v), ha="center", fontsize=10, fontweight="bold")

counts_no_other = df.loc[df[TARGET_COL] != "other", TARGET_COL].value_counts()
axes[1].bar(counts_no_other.index, counts_no_other.values, color=colors[:4])
axes[1].set_title("Without 'other' Class", fontsize=13)
axes[1].set_xlabel("Mood"); axes[1].set_ylabel("Count")
for i, (cls, v) in enumerate(counts_no_other.items()):
    axes[1].text(i, v + 3, str(v), ha="center", fontsize=10, fontweight="bold")

plt.suptitle("Class Imbalance Overview", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Feature selection: drop low-variance + highly correlated ──────────────
from sklearn.preprocessing import MinMaxScaler

def drop_low_variance(X_df, threshold=0.01):
    scaled = pd.DataFrame(MinMaxScaler().fit_transform(X_df), columns=X_df.columns)
    return [c for c in scaled.columns if scaled[c].var() > threshold]

def drop_correlated(X_df, threshold=0.90):
    corr  = X_df.corr().abs()
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
    drop  = {c for c in upper.columns if any(upper[c] > threshold)}
    return [c for c in X_df.columns if c not in drop]

X_full = df[FEATURE_COLS].copy()
keep   = drop_low_variance(X_full)
X_full = X_full[keep]
keep   = drop_correlated(X_full)
X_full = X_full[keep]

print(f"Features after selection: {X_full.shape[1]}  (was {len(FEATURE_COLS)})")

y_full = df[TARGET_COL].values
# Out:
# Features after selection: 28  (was 51)

# %%
# ── Define models and sampling strategies ─────────────────────────────────

MODELS = {
    "XGBoost": XGBClassifier(
        n_estimators=300, max_depth=6, learning_rate=0.1,
        use_label_encoder=False, eval_metric="mlogloss",
        random_state=RANDOM_STATE, n_jobs=-1),
    "SVM": SVC(
        kernel="rbf", C=10, gamma="scale",
        class_weight="balanced", probability=True, random_state=RANDOM_STATE),
    "Logistic Regression": LogisticRegression(
        C=1.0, max_iter=1000, class_weight="balanced", random_state=RANDOM_STATE),
    "KNN": KNeighborsClassifier(n_neighbors=7, metric="euclidean"),
    "Random Forest": RandomForestClassifier(
        n_estimators=300, class_weight="balanced",
        random_state=RANDOM_STATE, n_jobs=-1),
}

STRATEGIES = [
    "baseline",
    "remove_other",
    "oversample",
    "undersample",
    "remove_other+oversample",
    "remove_other+undersample",
]

print(f"Models     : {list(MODELS.keys())}")
print(f"Strategies : {STRATEGIES}")
print(f"\nTotal experiments : {len(MODELS) * len(STRATEGIES)}")
# Out:
# Models     : ['XGBoost', 'SVM', 'Logistic Regression', 'KNN', 'Random Forest']
# Strategies : ['baseline', 'remove_other', 'oversample', 'undersample', 'remove_other+oversample', 'remove_other+undersample']
#
# Total experiments : 30

# %%
# ── Run all 30 experiments ────────────────────────────────────────────────

def prepare_data(strategy, X, y):
    """Apply sampling strategy and return (X_train, X_test, y_train, y_test, classes)."""
    remove_other = "remove_other" in strategy

    if remove_other:
        mask = y != "other"
        X_use, y_use = X[mask], y[mask]
    else:
        X_use, y_use = X.copy(), y.copy()

    le = LabelEncoder()
    y_enc = le.fit_transform(y_use)

    X_tr, X_te, y_tr, y_te = train_test_split(
        X_use.values, y_enc, test_size=0.2,
        stratify=y_enc, random_state=RANDOM_STATE)

    if "oversample" in strategy:
        sm = SMOTE(random_state=RANDOM_STATE)
        X_tr, y_tr = sm.fit_resample(X_tr, y_tr)
    elif "undersample" in strategy:
        rus = RandomUnderSampler(random_state=RANDOM_STATE)
        X_tr, y_tr = rus.fit_resample(X_tr, y_tr)

    return X_tr, X_te, y_tr, y_te, le


results = []  # list of dicts, one per experiment

for strategy in STRATEGIES:
    X_tr, X_te, y_tr, y_te, le = prepare_data(strategy, X_full, y_full)
    n_classes = len(le.classes_)

    print(f"\n{'='*60}")
    print(f"Strategy: {strategy.upper()}")
    print(f"  Train size: {len(X_tr)}  |  Test size: {len(X_te)}")
    print(f"  Classes: {list(le.classes_)}")
    tr_dist = pd.Series(y_tr).value_counts().to_dict()
    print(f"  Train dist: { {le.classes_[k]: v for k, v in tr_dist.items()} }")

    for model_name, clf in MODELS.items():
        # Wrap in scaling pipeline
        pipe = Pipeline([("sc", StandardScaler()), ("clf", clf)])

        pipe.fit(X_tr, y_tr)
        y_pred = pipe.predict(X_te)

        acc = accuracy_score(y_te, y_pred)
        f1  = f1_score(y_te, y_pred, average="macro")
        f1w = f1_score(y_te, y_pred, average="weighted")

        report = classification_report(
            y_te, y_pred, target_names=le.classes_, output_dict=True)

        results.append({
            "strategy"  : strategy,
            "model"     : model_name,
            "accuracy"  : acc,
            "f1_macro"  : f1,
            "f1_weighted": f1w,
            "report"    : report,
            "y_te"      : y_te,
            "y_pred"    : y_pred,
            "classes"   : list(le.classes_),
            "pipe"      : pipe,
        })

        print(f"  {model_name:<22}: Acc={acc:.4f}  F1-macro={f1:.4f}  F1-weighted={f1w:.4f}")

print("\n✅ All experiments complete.")
# Out:
# ============================================================
# Strategy: BASELINE
#   Train size: 1284  |  Test size: 322
#   Classes: ['excited', 'happy', 'other', 'romantic', 'sad']
#   Train dist: {'romantic': 318, 'other': 276, 'sad': 272, 'excited': 260, 'happy': 158}
#   XGBoost               : Acc=0.4752  F1-macro=0.4500  F1-weighted=0.4662
#   SVM                   : Acc=0.4472  F1-macro=0.4380  F1-weighted=0.4471
#   Logistic Regression   : Acc=0.4472  F1-macro=0.4360  F1-weighted=0.4436
#   KNN                   : Acc=0.4068  F1-macro=0.3792  F1-weighted=0.3973
#   Random Forest         : Acc=0.4752  F1-macro=0.4375  F1-weighted=0.4562
#
# ============================================================
# Strategy: REMOVE_OTHER
#   Train size: 1008  |  Test size: 253
#   Classes: ['excited', 'happy', 'romantic', 'sad']
#   Train dist: {'romantic': 318, 'sad': 272, 'excited': 260, 'happy': 158}
#   XGBoost               : Acc=0.5929  F1-macro=0.5484  F1-weighted=0.5779
#   SVM                   : Acc=0.5217  F1-macro=0.5152  F1-weighted=0.5212
#   Logistic Regression   : Acc=0.5613  F1-macro=0.5359  F1-weighted=0.5604
#   KNN                   : Acc=0.5257  F1-macro=0.4646  F1-weighted=0.4979
#   Random Forest         : Acc=0.6008  F1-macro=0.5146  F1-weighted=0.5626
#
# ============================================================
# Strategy: OVERSAMPLE
#   Train size: 1590  |  Test size: 322
#   Classes: ['excited', 'happy', 'other', 'romantic', 'sad']
#   Train dist: {'happy': 318, 'romantic': 318, 'other': 318, 'excited': 318, 'sad': 318}
#   XGBoost               : Acc=0.4410  F1-macro=0.4300  F1-weighted=0.4395
#   SVM                   : Acc=0.4317  F1-macro=0.4234  F1-weighted=0.4300
#   Logistic Regression   : Acc=0.4441  F1-macro=0.4365  F1-weighted=0.4424
#   KNN                   : Acc=0.3354  F1-macro=0.3324  F1-weighted=0.3358
#   Random Forest         : Acc=0.4596  F1-macro=0.4486  F1-weighted=0.4522
#
# ============================================================
# Strategy: UNDERSAMPLE
#   Train size: 790  |  Test size: 322
#   Classes: ['excited', 'happy', 'other', 'romantic', 'sad']
#   Train dist: {'excited': 158, 'happy': 158, 'other': 158, 'romantic': 158, 'sad': 158}
#   XGBoost               : Acc=0.4068  F1-macro=0.4079  F1-weighted=0.4122
#   SVM                   : Acc=0.4130  F1-macro=0.4145  F1-weighted=0.4225
#   Logistic Regression   : Acc=0.4130  F1-macro=0.4043  F1-weighted=0.4139
#   KNN                   : Acc=0.3820  F1-macro=0.3729  F1-weighted=0.3750
#   Random Forest         : Acc=0.4627  F1-macro=0.4608  F1-weighted=0.4597
#
# ============================================================
# Strategy: REMOVE_OTHER+OVERSAMPLE
#   Train size: 1272  |  Test size: 253
#   Classes: ['excited', 'happy', 'romantic', 'sad']
#   Train dist: {'sad': 318, 'romantic': 318, 'happy': 318, 'excited': 318}
#   XGBoost               : Acc=0.5573  F1-macro=0.5281  F1-weighted=0.5509
#   SVM                   : Acc=0.5099  F1-macro=0.4974  F1-weighted=0.5074
#   Logistic Regression   : Acc=0.5494  F1-macro=0.5292  F1-weighted=0.5522
#   KNN                   : Acc=0.4308  F1-macro=0.4223  F1-weighted=0.4330
#   Random Forest         : Acc=0.5810  F1-macro=0.5453  F1-weighted=0.5726
#
# ============================================================
# Strategy: REMOVE_OTHER+UNDERSAMPLE
#   Train size: 632  |  Test size: 253
#   Classes: ['excited', 'happy', 'romantic', 'sad']
#   Train dist: {'excited': 158, 'happy': 158, 'romantic': 158, 'sad': 158}
#   XGBoost               : Acc=0.5731  F1-macro=0.5528  F1-weighted=0.5718
#   SVM                   : Acc=0.5138  F1-macro=0.5048  F1-weighted=0.5168
#   Logistic Regression   : Acc=0.5534  F1-macro=0.5301  F1-weighted=0.5557
#   KNN                   : Acc=0.5178  F1-macro=0.5024  F1-weighted=0.5146
#   Random Forest         : Acc=0.5929  F1-macro=0.5658  F1-weighted=0.5840
#
# ✅ All experiments complete.

# %%
# ── Summary table: all 30 experiments ────────────────────────────────────
summary = pd.DataFrame([{
    "Strategy"   : r["strategy"],
    "Model"      : r["model"],
    "Accuracy"   : round(r["accuracy"],  4),
    "F1-macro"   : round(r["f1_macro"],  4),
    "F1-weighted": round(r["f1_weighted"],4),
} for r in results])

# Highlight best F1-macro per strategy
def highlight_best(s):
    is_max = s == s.max()
    return ["background-color: #d4edda; font-weight: bold" if v else "" for v in is_max]

display(
    summary.style
    .apply(highlight_best, subset=["F1-macro"], axis=0)
    .format({"Accuracy": "{:.4f}", "F1-macro": "{:.4f}", "F1-weighted": "{:.4f}"})
    .set_caption("All Experiments — Green = best F1-macro per strategy")
)
# Out:
# <style type="text/css">
# #T_37228_row29_col3 {
#   background-color: #d4edda;
#   font-weight: bold;
# }
# </style>
# <table id="T_37228">
#   <caption>All Experiments — Green = best F1-macro per strategy</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37228_level0_col0" class="col_heading level0 col0" >Strategy</th>
#       <th id="T_37228_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_37228_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#       <th id="T_37228_level0_col3" class="col_heading level0 col3" >F1-macro</th>
#       <th id="T_37228_level0_col4" class="col_heading level0 col4" >F1-weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37228_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_37228_row0_col0" class="data row0 col0" >baseline</td>
#       <td id="T_37228_row0_col1" class="data row0 col1" >XGBoost</td>
#       <td id="T_37228_row0_col2" class="data row0 col2" >0.4752</td>
#       <td id="T_37228_row0_col3" class="data row0 col3" >0.4500</td>
#       <td id="T_37228_row0_col4" class="data row0 col4" >0.4662</td>
#     </tr>
#     <tr>
#       <th id="T_37228_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_37228_row1_col0" class="data row1 col0" >baseline</td>
#       <td id="T_37228_row1_col1" class="data row1 col1" >SVM</td>
#       <td id="T_37228_row1_col2" class="data row1 col2" >0.4472</td>
#       <td id="T_37228_row1_col3" class="data row1 col3" >0.4380</td>
#       <td id="T_37228_row1_col4" class="data row1 col4" >0.4471</td>
#     </tr>
#     <tr>
#       <th id="T_37228_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_37228_row2_col0" class="data row2 col0" >baseline</td>
#       <td id="T_37228_row2_col1" class="data row2 col1" >Logistic Regression</td>
#       <td id="T_37228_row2_col2" class="data row2 col2" >0.4472</td>
#       <td id="T_37228_row2_col3" class="data row2 col3" >0.4360</td>
#       <td id="T_37228_row2_col4" class="data row2 col4" >0.4436</td>
#     </tr>
#     <tr>
#       <th id="T_37228_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_37228_row3_col0" class="data row3 col0" >baseline</td>
#       <td id="T_37228_row3_col1" class="data row3 col1" >KNN</td>
#       <td id="T_37228_row3_col2" class="data row3 col2" >0.4068</td>
#       <td id="T_37228_row3_col3" class="data row3 col3" >0.3792</td>
#       <td id="T_37228_row3_col4" class="data row3 col4" >0.3973</td>
#     </tr>
#     <tr>
#       <th id="T_37228_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_37228_row4_col0" class="data row4 col0" >baseline</td>
#       <td id="T_37228_row4_col1" class="data row4 col1" >Random Forest</td>
#       <td id="T_37228_row4_col2" class="data row4 col2" >0.4752</td>
#       <td id="T_37228_row4_col3" class="data row4 col3" >0.4375</td>
#       <td id="T_37228_row4_col4" class="data row4 col4" >0.4562</td>
#     </tr>
#     <tr>
#       <th id="T_37228_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_37228_row5_col0" class="data row5 col0" >remove_other</td>
#       <td id="T_37228_row5_col1" class="data row5 col1" >XGBoost</td>
#       <td id="T_37228_row5_col2" class="data row5 col2" >0.5929</td>
#       <td id="T_37228_row5_col3" class="data row5 col3" >0.5484</td>
#       <td id="T_37228_row5_col4" class="data row5 col4" >0.5779</td>
#     </tr>
#     <tr>
#       <th id="T_37228_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_37228_row6_col0" class="data row6 col0" >remove_other</td>
#       <td id="T_37228_row6_col1" class="data row6 col1" >SVM</td>
#       <td id="T_37228_row6_col2" class="data row6 col2" >0.5217</td>
#       <td id="T_37228_row6_col3" class="data row6 col3" >0.5152</td>
#       <td id="T_37228_row6_col4" class="data row6 col4" >0.5212</td>
#     </tr>
#     <tr>
#       <th id="T_37228_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_37228_row7_col0" class="data row7 col0" >remove_other</td>
#       <td id="T_37228_row7_col1" class="data row7 col1" >Logistic Regression</td>
#       <td id="T_37228_row7_col2" class="data row7 col2" >0.5613</td>
#       <td id="T_37228_row7_col3" class="data row7 col3" >0.5359</td>
#       <td id="T_37228_row7_col4" class="data row7 col4" >0.5604</td>
#     </tr>
#     <tr>
#       <th id="T_37228_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_37228_row8_col0" class="data row8 col0" >remove_other</td>
#       <td id="T_37228_row8_col1" class="data row8 col1" >KNN</td>
#       <td id="T_37228_row8_col2" class="data row8 col2" >0.5257</td>
#       <td id="T_37228_row8_col3" class="data row8 col3" >0.4646</td>
#       <td id="T_37228_row8_col4" class="data row8 col4" >0.4979</td>
#     </tr>
#     <tr>
#       <th id="T_37228_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_37228_row9_col0" class="data row9 col0" >remove_other</td>
#       <td id="T_37228_row9_col1" class="data row9 col1" >Random Forest</td>
#       <td id="T_37228_row9_col2" class="data row9 col2" >0.6008</td>
#       <td id="T_37228_row9_col3" class="data row9 col3" >0.5146</td>
#       <td id="T_37228_row9_col4" class="data row9 col4" >0.5626</td>
#     </tr>
#     <tr>
#       <th id="T_37228_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_37228_row10_col0" class="data row10 col0" >oversample</td>
#       <td id="T_37228_row10_col1" class="data row10 col1" >XGBoost</td>
#       <td id="T_37228_row10_col2" class="data row10 col2" >0.4410</td>
#       <td id="T_37228_row10_col3" class="data row10 col3" >0.4300</td>
#       <td id="T_37228_row10_col4" class="data row10 col4" >0.4395</td>
#     </tr>
#     <tr>
#       <th id="T_37228_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_37228_row11_col0" class="data row11 col0" >oversample</td>
#       <td id="T_37228_row11_col1" class="data row11 col1" >SVM</td>
#       <td id="T_37228_row11_col2" class="data row11 col2" >0.4317</td>
#       <td id="T_37228_row11_col3" class="data row11 col3" >0.4234</td>
#       <td id="T_37228_row11_col4" class="data row11 col4" >0.4300</td>
#     </tr>
#     <tr>
#       <th id="T_37228_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_37228_row12_col0" class="data row12 col0" >oversample</td>
#       <td id="T_37228_row12_col1" class="data row12 col1" >Logistic Regression</td>
#       <td id="T_37228_row12_col2" class="data row12 col2" >0.4441</td>
#       <td id="T_37228_row12_col3" class="data row12 col3" >0.4365</td>
#       <td id="T_37228_row12_col4" class="data row12 col4" >0.4424</td>
#     </tr>
#     <tr>
#       <th id="T_37228_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_37228_row13_col0" class="data row13 col0" >oversample</td>
#       <td id="T_37228_row13_col1" class="data row13 col1" >KNN</td>
#       <td id="T_37228_row13_col2" class="data row13 col2" >0.3354</td>
#       <td id="T_37228_row13_col3" class="data row13 col3" >0.3324</td>
#       <td id="T_37228_row13_col4" class="data row13 col4" >0.3358</td>
#     </tr>
#     <tr>
#       <th id="T_37228_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_37228_row14_col0" class="data row14 col0" >oversample</td>
#       <td id="T_37228_row14_col1" class="data row14 col1" >Random Forest</td>
#       <td id="T_37228_row14_col2" class="data row14 col2" >0.4596</td>
#       <td id="T_37228_row14_col3" class="data row14 col3" >0.4486</td>
#       <td id="T_37228_row14_col4" class="data row14 col4" >0.4522</td>
#     </tr>
#     <tr>
#       <th id="T_37228_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_37228_row15_col0" class="data row15 col0" >undersample</td>
#       <td id="T_37228_row15_col1" class="data row15 col1" >XGBoost</td>
#       <td id="T_37228_row15_col2" class="data row15 col2" >0.4068</td>
#       <td id="T_37228_row15_col3" class="data row15 col3" >0.4079</td>
#       <td id="T_37228_row15_col4" class="data row15 col4" >0.4122</td>
#     </tr>
#     <tr>
#       <th id="T_37228_level0_row16" class="row_heading level0 row16" >16

# %%
# ── Best model per strategy ───────────────────────────────────────────────
best_per_strategy = (
    summary.sort_values("F1-macro", ascending=False)
           .groupby("Strategy").first()
           .reset_index()
           [["Strategy", "Model", "Accuracy", "F1-macro", "F1-weighted"]]
           .sort_values("F1-macro", ascending=False)
)

print("Best model per strategy (sorted by F1-macro):")
display(best_per_strategy.style.format({
    "Accuracy": "{:.4f}", "F1-macro": "{:.4f}", "F1-weighted": "{:.4f}"}))
# Out:
# Best model per strategy (sorted by F1-macro):
# <style type="text/css">
# </style>
# <table id="T_7111c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7111c_level0_col0" class="col_heading level0 col0" >Strategy</th>
#       <th id="T_7111c_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_7111c_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#       <th id="T_7111c_level0_col3" class="col_heading level0 col3" >F1-macro</th>
#       <th id="T_7111c_level0_col4" class="col_heading level0 col4" >F1-weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7111c_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_7111c_row0_col0" class="data row0 col0" >remove_other+undersample</td>
#       <td id="T_7111c_row0_col1" class="data row0 col1" >Random Forest</td>
#       <td id="T_7111c_row0_col2" class="data row0 col2" >0.5929</td>
#       <td id="T_7111c_row0_col3" class="data row0 col3" >0.5658</td>
#       <td id="T_7111c_row0_col4" class="data row0 col4" >0.5840</td>
#     </tr>
#     <tr>
#       <th id="T_7111c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_7111c_row1_col0" class="data row1 col0" >remove_other</td>
#       <td id="T_7111c_row1_col1" class="data row1 col1" >XGBoost</td>
#       <td id="T_7111c_row1_col2" class="data row1 col2" >0.5929</td>
#       <td id="T_7111c_row1_col3" class="data row1 col3" >0.5484</td>
#       <td id="T_7111c_row1_col4" class="data row1 col4" >0.5779</td>
#     </tr>
#     <tr>
#       <th id="T_7111c_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_7111c_row2_col0" class="data row2 col0" >remove_other+oversample</td>
#       <td id="T_7111c_row2_col1" class="data row2 col1" >Random Forest</td>
#       <td id="T_7111c_row2_col2" class="data row2 col2" >0.5810</td>
#       <td id="T_7111c_row2_col3" class="data row2 col3" >0.5453</td>
#       <td id="T_7111c_row2_col4" class="data row2 col4" >0.5726</td>
#     </tr>
#     <tr>
#       <th id="T_7111c_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_7111c_row3_col0" class="data row3 col0" >undersample</td>
#       <td id="T_7111c_row3_col1" class="data row3 col1" >Random Forest</td>
#       <td id="T_7111c_row3_col2" class="data row3 col2" >0.4627</td>
#       <td id="T_7111c_row3_col3" class="data row3 col3" >0.4608</td>
#       <td id="T_7111c_row3_col4" class="data row3 col4" >0.4597</td>
#     </tr>
#     <tr>
#       <th id="T_7111c_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_7111c_row4_col0" class="data row4 col0" >baseline</td>
#       <td id="T_7111c_row4_col1" class="data row4 col1" >XGBoost</td>
#       <td id="T_7111c_row4_col2" class="data row4 col2" >0.4752</td>
#       <td id="T_7111c_row4_col3" class="data row4 col3" >0.4500</td>
#       <td id="T_7111c_row4_col4" class="data row4 col4" >0.4662</td>
#     </tr>
#     <tr>
#       <th id="T_7111c_level0_row5" class="row_heading level0 row5" >1</th>
#       <td id="T_7111c_row5_col0" class="data row5 col0" >oversample</td>
#       <td id="T_7111c_row5_col1" class="data row5 col1" >Random Forest</td>
#       <td id="T_7111c_row5_col2" class="data row5 col2" >0.4596</td>
#       <td id="T_7111c_row5_col3" class="data row5 col3" >0.4486</td>
#       <td id="T_7111c_row5_col4" class="data row5 col4" >0.4522</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ── Heatmap: F1-macro for all model × strategy combinations ───────────────
pivot = summary.pivot(index="Model", columns="Strategy", values="F1-macro")
# Order strategies sensibly
col_order = [c for c in STRATEGIES if c in pivot.columns]
pivot = pivot[col_order]

fig, ax = plt.subplots(figsize=(14, 5))
sns.heatmap(pivot, annot=True, fmt=".3f", cmap="YlGn",
            linewidths=0.5, linecolor="white",
            annot_kws={"size": 11}, ax=ax,
            vmin=pivot.values.min() - 0.02,
            vmax=pivot.values.max() + 0.01)
ax.set_title("F1-macro Heatmap: Model × Sampling Strategy", fontsize=14, pad=12)
ax.set_xlabel("Strategy", fontsize=11)
ax.set_ylabel("Model", fontsize=11)
plt.xticks(rotation=25, ha="right")
plt.tight_layout()
plt.show()

# %%
# ── Heatmap: Accuracy ─────────────────────────────────────────────────────
pivot_acc = summary.pivot(index="Model", columns="Strategy", values="Accuracy")[col_order]

fig, ax = plt.subplots(figsize=(14, 5))
sns.heatmap(pivot_acc, annot=True, fmt=".3f", cmap="Blues",
            linewidths=0.5, linecolor="white",
            annot_kws={"size": 11}, ax=ax)
ax.set_title("Accuracy Heatmap: Model × Sampling Strategy", fontsize=14, pad=12)
ax.set_xlabel("Strategy", fontsize=11)
ax.set_ylabel("Model", fontsize=11)
plt.xticks(rotation=25, ha="right")
plt.tight_layout()
plt.show()

# %%
# ── Grouped bar: F1-macro per model across strategies ─────────────────────
fig, ax = plt.subplots(figsize=(15, 6))
model_names = list(MODELS.keys())
x = np.arange(len(model_names))
n_strat = len(STRATEGIES)
width = 0.13
colors_strat = plt.cm.Set2(np.linspace(0, 1, n_strat))

for i, strat in enumerate(STRATEGIES):
    vals = [summary.loc[(summary.Model == m) & (summary.Strategy == strat),
                        "F1-macro"].values[0] for m in model_names]
    offset = (i - n_strat / 2) * width + width / 2
    bars = ax.bar(x + offset, vals, width, label=strat, color=colors_strat[i])

ax.set_xlabel("Model", fontsize=12)
ax.set_ylabel("F1-macro", fontsize=12)
ax.set_title("F1-macro by Model and Sampling Strategy", fontsize=14)
ax.set_xticks(x); ax.set_xticklabels(model_names, fontsize=11)
ax.set_ylim(0, 1)
ax.legend(title="Strategy", bbox_to_anchor=(1.01, 1), loc="upper left", fontsize=9)
ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# ── Per-class F1 breakdown for best experiment per strategy ───────────────
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

for ax_idx, strat in enumerate(STRATEGIES):
    # Find best model for this strategy
    strat_results = [r for r in results if r["strategy"] == strat]
    best = max(strat_results, key=lambda r: r["f1_macro"])
    classes = best["classes"]
    report  = best["report"]

    class_f1 = {cls: report[cls]["f1-score"] for cls in classes}
    mood_colors = {
        "happy":    "#2ecc71",
        "sad":      "#3498db",
        "romantic": "#e74c3c",
        "excited":  "#e67e22",
        "other":    "#95a5a6",
    }
    bar_colors = [mood_colors.get(c, "#7f8c8d") for c in class_f1]

    bars = axes[ax_idx].bar(class_f1.keys(), class_f1.values(), color=bar_colors)
    axes[ax_idx].set_title(
        f"{strat}\nBest: {best['model']}  (F1-macro={best['f1_macro']:.3f})",
        fontsize=10, fontweight="bold")
    axes[ax_idx].set_ylim(0, 1)
    axes[ax_idx].set_ylabel("F1-score")
    axes[ax_idx].axhline(best["f1_macro"], color="black",
                          linestyle="--", linewidth=1, alpha=0.5, label="macro avg")
    axes[ax_idx].legend(fontsize=8)
    for bar, (cls, val) in zip(bars, class_f1.items()):
        axes[ax_idx].text(bar.get_x() + bar.get_width()/2,
                           val + 0.01, f"{val:.2f}",
                           ha="center", va="bottom", fontsize=9)

plt.suptitle("Per-class F1 for Best Model per Strategy", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Confusion matrices for best model per strategy ────────────────────────
fig, axes = plt.subplots(2, 3, figsize=(18, 11))
axes = axes.flatten()

for ax_idx, strat in enumerate(STRATEGIES):
    strat_results = [r for r in results if r["strategy"] == strat]
    best = max(strat_results, key=lambda r: r["f1_macro"])

    cm   = confusion_matrix(best["y_te"], best["y_pred"])
    cm_n = cm.astype(float) / cm.sum(axis=1, keepdims=True)

    sns.heatmap(cm_n, annot=True, fmt=".2f", cmap="Blues",
                xticklabels=best["classes"], yticklabels=best["classes"],
                ax=axes[ax_idx], linewidths=0.3)
    axes[ax_idx].set_title(
        f"{strat}\n{best['model']}  Acc={best['accuracy']:.3f}",
        fontsize=10, fontweight="bold")
    axes[ax_idx].set_xlabel("Predicted"); axes[ax_idx].set_ylabel("Actual")

plt.suptitle("Confusion Matrices — Best Model per Strategy (normalised)",
             fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Full classification reports for every experiment ─────────────────────
for strat in STRATEGIES:
    print("\n" + "="*70)
    print(f"  STRATEGY: {strat.upper()}")
    print("="*70)
    for r in [x for x in results if x["strategy"] == strat]:
        print(f"\n--- {r['model']} ---")
        print(f"  Accuracy   : {r['accuracy']:.4f}")
        print(f"  F1-macro   : {r['f1_macro']:.4f}")
        print(f"  F1-weighted: {r['f1_weighted']:.4f}")
        rpt = r["report"]
        header = f"{'Class':<14} {'Precision':>10} {'Recall':>10} {'F1':>10} {'Support':>10}"
        print("  " + header)
        print("  " + "-"*len(header))
        for cls in r["classes"]:
            row = rpt[cls]
            print(f"  {cls:<14} {row['precision']:>10.4f} {row['recall']:>10.4f} "
                  f"{row['f1-score']:>10.4f} {int(row['support']):>10}")
        print(f"  {'macro avg':<14} {rpt['macro avg']['precision']:>10.4f} "
              f"{rpt['macro avg']['recall']:>10.4f} "
              f"{rpt['macro avg']['f1-score']:>10.4f} "
              f"{int(rpt['macro avg']['support']):>10}")
# Out:
# ======================================================================
#   STRATEGY: BASELINE
# ======================================================================
#
# --- XGBoost ---
#   Accuracy   : 0.4752
#   F1-macro   : 0.4500
#   F1-weighted: 0.4662
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7000     0.7538     0.7259         65
#   happy              0.3500     0.1750     0.2333         40
#   other              0.4762     0.4348     0.4545         69
#   romantic           0.3981     0.5125     0.4481         80
#   sad                0.3939     0.3824     0.3881         68
#   macro avg          0.4636     0.4517     0.4500        322
#
# --- SVM ---
#   Accuracy   : 0.4472
#   F1-macro   : 0.4380
#   F1-weighted: 0.4471
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6232     0.6615     0.6418         65
#   happy              0.2826     0.3250     0.3023         40
#   other              0.4921     0.4493     0.4697         69
#   romantic           0.4177     0.4125     0.4151         80
#   sad                0.3692     0.3529     0.3609         68
#   macro avg          0.4370     0.4403     0.4380        322
#
# --- Logistic Regression ---
#   Accuracy   : 0.4472
#   F1-macro   : 0.4360
#   F1-weighted: 0.4436
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6857     0.7385     0.7111         65
#   happy              0.2500     0.3000     0.2727         40
#   other              0.4286     0.4783     0.4521         69
#   romantic           0.3770     0.2875     0.3262         80
#   sad                0.4242     0.4118     0.4179         68
#   macro avg          0.4331     0.4432     0.4360        322
#
# --- KNN ---
#   Accuracy   : 0.4068
#   F1-macro   : 0.3792
#   F1-weighted: 0.3973
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5732     0.7231     0.6395         65
#   happy              0.1515     0.1250     0.1370         40
#   other              0.4426     0.3913     0.4154         69
#   romantic           0.3407     0.3875     0.3626         80
#   sad                0.3818     0.3088     0.3415         68
#   macro avg          0.3780     0.3871     0.3792        322
#
# --- Random Forest ---
#   Accuracy   : 0.4752
#   F1-macro   : 0.4375
#   F1-weighted: 0.4562
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6582     0.8000     0.7222         65
#   happy              1.0000     0.1000     0.1818         40
#   other              0.5000     0.4203     0.4567         69
#   romantic           0.3737     0.4625     0.4134         80
#   sad                0.3780     0.4559     0.4133         68
#   macro avg          0.5820     0.4477     0.4375        322
#
# ======================================================================
#   STRATEGY: REMOVE_OTHER
# ======================================================================
#
# --- XGBoost ---
#   Accuracy   : 0.5929
#   F1-macro   : 0.5484
#   F1-weighted: 0.5779
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7324     0.8000     0.7647         65
#   happy              0.4211     0.2000     0.2712         40
#   romantic           0.5376     0.6250     0.5780         80
#   sad                0.5714     0.5882     0.5797         68
#   macro avg          0.5656     0.5533     0.5484        253
#
# --- SVM ---
#   Accuracy   : 0.5217
#   F1-macro   : 0.5152
#   F1-weighted: 0.5212
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6818     0.6923     0.6870         65
#   happy              0.3953     0.4250     0.4096         40
#   romantic           0.4533     0.4250     0.4387         80
#   sad                0.5217     0.5294     0.5255         68
#   macro avg          0.5131     0.5179     0.5152        253
#
# --- Logistic Regression ---
#   Accuracy   : 0.5613
#   F1-macro   : 0.5359
#   F1-weighted: 0.5604
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7429     0.8000     0.7704         65
#   happy              0.2400     0.3000     0.2667         40
#   romantic           0.5789     0.4125     0.4818         80
#   sad                0.5921     0.6618     0.6250         68
#   macro avg          0.5385     0.5436     0.5359        253
#
# --- KNN ---
#   Accuracy   : 0.5257
#   F1-macro   : 0.4646
#   F1-weighted: 0.4979
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6067     0.8308     0.7013         65
#   happy              0.3077     0.1000     0.1509         40
#   romantic           0.4574     0.5375     0.4943         80
#   sad                0.5614     0.4706     0.5120         68
#   macro avg          0.4833     0.4847     0.4646        253
#
# --- Random Forest ---
#   Accuracy   : 0.6008
#   F1-macro   : 0.5146
#   F1-weighted: 0.5626
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7067     0.8154     0.7571         65
#   happy              0.4000     0.0500     0.0889         40
#   romantic           0.5238     0.6875     0.5946         80
#   sad                0.6176     0.6176     0.6176         68
#   macro avg          0.5620     0.5426     0.5146        253
#
# ======================================================================
#   STRATEGY: OVERSAMPLE
# ======================================================================
#
# --- XGBoost ---
#   Accuracy   : 0.4410
#   F1-macro   : 0.4300
#   F1-weighted: 0.4395
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7059     0.7385     0.7218         65
#   happy              0.2703     0.2500     0.2597         40
#   other              0.4531     0.4203     0.4361         69
#   romantic           0.3448     0.3750     0.3593         80
#   sad                0.3788     0.3676     0.3731         68
#   macro avg          0.4306     0.4303     0.4300        322
#
# --- SVM ---
#   Accuracy   : 0.4317
#   F1-macro   : 0.4234
#   F1-weighted: 0.4300
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6269     0.6462     0.6364         65
#   happy              0.2857     0.3500     0.3146         40
#   other              0.4521     0.4783     0.4648         69
#   romantic           0.4026     0.3875     0.3949         80
#   sad                0.3393     0.2794     0.3065         68
#   macro avg          0.4213     0.4283     0.4234        322
#
# --- Logistic Regression ---
#   Accuracy   : 0.4441
#   F1-macro   : 0.4365
#   F1-weighted: 0.4424
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6857     0.7385     0.7111         65
#   happy              0.2500     0.3500     0.2917         40
#   other              0.4412     0.4348     0.4380         69
#   romantic           0.3710     0.2875     0.3239         80
#   sad                0.4242     0.4118     0.4179         68
#   macro avg          0.4344     0.4445     0.4365        322
#
# --- KNN ---
#   Accuracy   : 0.3354
#   F1-macro   : 0.3324
#   F1-weighted: 0.3358
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5753     0.6462     0.6087         65
#   happy              0.1509     0.4000     0.2192         40
#   other              0.4800     0.3478     0.4034         69
#   romantic           0.2979     0.1750     0.2205         80
#   sad                0.2609     0.1765     0.2105         68
#   macro avg          0.3530     0.3491     0.3324        322
#
# --- Random Forest ---
#   Accuracy   : 0.4596
#   F1-macro   : 0.4486
#   F1-weighted: 0.4522
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6533     0.7538     0.7000         65
#   happy              0.3929     0.2750     0.3235         40
#   other              0.4848     0.4638     0.4741         69
#   romantic           0.3333     0.3000     0.3158         80
#   sad                0.3951     0.4706     0.4295         68
#   macro avg          0.4519     0.4526     0.4486        322
#
# ======================================================================
#   STRATEGY: UNDERSAMPLE
# ======================================================================
#
# --- XGBoost ---
#   Accuracy   : 0.4068
#   F1-macro   : 0.4079
#   F1-weighted: 0.4122
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6552     0.5846     0.6179         65
#   happy              0.2540     0.4000     0.3107         40
#   other              0.4590     0.4058     0.4308         69
#   romantic           0.3768     0.3250     0.3490         80
#   sad                0.3239     0.3382     0.3309         68
#   macro avg          0.4138     0.4107     0.4079        322
#
# --- SVM ---
#   Accuracy   : 0.4130
#   F1-macro   : 0.4145
#   F1-weighted: 0.4225
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6129     0.5846     0.5984         65
#   happy              0.2105     0.4000     0.2759         40
#   other              0.5625     0.3913     0.4615         69
#   romantic           0.3553     0.3375     0.3462         80
#   sad                0.4167     0.3676     0.3906         68
#   macro avg          0.4316     0.4162     0.4145        322
#
# --- Logistic Regression ---
#   Accuracy   : 0.4130
#   F1-macro   : 0.4043
#   F1-weighted: 0.4139
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7031     0.6923     0.6977         65
#   happy              0.2000     0.2500     0.2222         40
#   other              0.4110     0.4348     0.4225         69
#   romantic           0.3492     0.2750     0.3077         80
#   sad                0.3611     0.3824     0.3714         68
#   macro avg          0.4049     0.4069     0.4043        322
#
# --- KNN ---
#   Accuracy   : 0.3820
#   F1-macro   : 0.3729
#   F1-weighted: 0.3750
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6203     0.7538     0.6806         65
#   happy              0.2097     0.3250     0.2549         40
#   other              0.4082     0.2899     0.3390         69
#   romantic           0.2615     0.2125     0.2345         80
#   sad                0.3582     0.3529     0.3556         68
#   macro avg          0.3716     0.3868     0.3729        322
#
# --- Random Forest ---
#   Accuracy   : 0.4627
#   F1-macro   : 0.4608
#   F1-weighted: 0.4597
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7031     0.6923     0.6977         65
#   happy              0.3810     0.4000     0.3902         40
#   other              0.4655     0.3913     0.4252         69
#   romantic           0.3692     0.3000     0.3310         80
#   sad                0.3978     0.5441     0.4596         68
#   macro avg          0.4633     0.4655     0.4608        322
#
# ======================================================================
#   STRATEGY: REMOVE_OTHER+OVERSAMPLE
# ======================================================================
#
# --- XGBoost ---
#   Accuracy   : 0.5573
#   F1-macro   : 0.5281
#   F1-weighted: 0.5509
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7391     0.7846     0.7612         65
#   happy              0.3448     0.2500     0.2899         40
#   romantic           0.4783     0.5500     0.5116         80
#   sad                0.5714     0.5294     0.5496         68
#   macro avg          0.5334     0.5285     0.5281        253
#
# --- SVM ---
#   Accuracy   : 0.5099
#   F1-macro   : 0.4974
#   F1-weighted: 0.5074
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6714     0.7231     0.6963         65
#   happy              0.3409     0.3750     0.3571         40
#   romantic           0.4706     0.4000     0.4324         80
#   sad                0.4930     0.5147     0.5036         68
#   macro avg          0.4940     0.5032     0.4974        253
#
# --- Logistic Regression ---
#   Accuracy   : 0.5494
#   F1-macro   : 0.5292
#   F1-weighted: 0.5522
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7429     0.8000     0.7704         65
#   happy              0.2407     0.3250     0.2766         40
#   romantic           0.5667     0.4250     0.4857         80
#   sad                0.5797     0.5882     0.5839         68
#   macro avg          0.5325     0.5346     0.5292        253
#
# --- KNN ---
#   Accuracy   : 0.4308
#   F1-macro   : 0.4223
#   F1-weighted: 0.4330
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.5897     0.7077     0.6434         65
#   happy              0.2024     0.4250     0.2742         40
#   romantic           0.5116     0.2750     0.3577         80
#   sad                0.5000     0.3529     0.4138         68
#   macro avg          0.4509     0.4402     0.4223        253
#
# --- Random Forest ---
#   Accuracy   : 0.5810
#   F1-macro   : 0.5453
#   F1-weighted: 0.5726
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7222     0.8000     0.7591         65
#   happy              0.3000     0.2250     0.2571         40
#   romantic           0.4940     0.5125     0.5031         80
#   sad                0.6618     0.6618     0.6618         68
#   macro avg          0.5445     0.5498     0.5453        253
#
# ======================================================================
#   STRATEGY: REMOVE_OTHER+UNDERSAMPLE
# ======================================================================
#
# --- XGBoost ---
#   Accuracy   : 0.5731
#   F1-macro   : 0.5528
#   F1-weighted: 0.5718
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7500     0.7385     0.7442         65
#   happy              0.3182     0.3500     0.3333         40
#   romantic           0.5373     0.4500     0.4898         80
#   sad                0.6026     0.6912     0.6438         68
#   macro avg          0.5520     0.5574     0.5528        253
#
# --- SVM ---
#   Accuracy   : 0.5138
#   F1-macro   : 0.5048
#   F1-weighted: 0.5168
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7015     0.7231     0.7121         65
#   happy              0.2833     0.4250     0.3400         40
#   romantic           0.4918     0.3750     0.4255         80
#   sad                0.5538     0.5294     0.5414         68
#   macro avg          0.5076     0.5131     0.5048        253
#
# --- Logistic Regression ---
#   Accuracy   : 0.5534
#   F1-macro   : 0.5301
#   F1-weighted: 0.5557
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7183     0.7846     0.7500         65
#   happy              0.2264     0.3000     0.2581         40
#   romantic           0.5763     0.4250     0.4892         80
#   sad                0.6143     0.6324     0.6232         68
#   macro avg          0.5338     0.5355     0.5301        253
#
# --- KNN ---
#   Accuracy   : 0.5178
#   F1-macro   : 0.5024
#   F1-weighted: 0.5146
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.6282     0.7538     0.6853         65
#   happy              0.3019     0.4000     0.3441         40
#   romantic           0.5172     0.3750     0.4348         80
#   sad                0.5625     0.5294     0.5455         68
#   macro avg          0.5025     0.5146     0.5024        253
#
# --- Random Forest ---
#   Accuracy   : 0.5929
#   F1-macro   : 0.5658
#   F1-weighted: 0.5840
#   Class           Precision     Recall         F1    Support
#   ----------------------------------------------------------
#   excited            0.7286     0.7846     0.7556         65
#   happy              0.3256     0.3500     0.3373         40
#   romantic           0.5517     0.4000     0.4638         80
#   sad                0.6463     0.7794     0.7067         68
#   macro avg          0.5631     0.5785     0.5658        253

# %%
# ── Overall leaderboard: top 10 experiments ──────────────────────────────
leaderboard = summary.sort_values("F1-macro", ascending=False).head(10).reset_index(drop=True)
leaderboard.index += 1
print("Top 10 experiments overall:")
display(leaderboard.style
    .format({"Accuracy": "{:.4f}", "F1-macro": "{:.4f}", "F1-weighted": "{:.4f}"})
    .bar(subset=["F1-macro"], color="#2ecc71", vmin=0, vmax=1)
    .set_caption("Top 10 — sorted by F1-macro"))
# Out:
# Top 10 experiments overall:
# <style type="text/css">
# #T_54853_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 56.6%, transparent 56.6%);
# }
# #T_54853_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 55.3%, transparent 55.3%);
# }
# #T_54853_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 54.8%, transparent 54.8%);
# }
# #T_54853_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 54.5%, transparent 54.5%);
# }
# #T_54853_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 53.6%, transparent 53.6%);
# }
# #T_54853_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 53.0%, transparent 53.0%);
# }
# #T_54853_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 52.9%, transparent 52.9%);
# }
# #T_54853_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 52.8%, transparent 52.8%);
# }
# #T_54853_row8_col3, #T_54853_row9_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #2ecc71 51.5%, transparent 51.5%);
# }
# </style>
# <table id="T_54853">
#   <caption>Top 10 — sorted by F1-macro</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54853_level0_col0" class="col_heading level0 col0" >Strategy</th>
#       <th id="T_54853_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_54853_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#       <th id="T_54853_level0_col3" class="col_heading level0 col3" >F1-macro</th>
#       <th id="T_54853_level0_col4" class="col_heading level0 col4" >F1-weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54853_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_54853_row0_col0" class="data row0 col0" >remove_other+undersample</td>
#       <td id="T_54853_row0_col1" class="data row0 col1" >Random Forest</td>
#       <td id="T_54853_row0_col2" class="data row0 col2" >0.5929</td>
#       <td id="T_54853_row0_col3" class="data row0 col3" >0.5658</td>
#       <td id="T_54853_row0_col4" class="data row0 col4" >0.5840</td>
#     </tr>
#     <tr>
#       <th id="T_54853_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_54853_row1_col0" class="data row1 col0" >remove_other+undersample</td>
#       <td id="T_54853_row1_col1" class="data row1 col1" >XGBoost</td>
#       <td id="T_54853_row1_col2" class="data row1 col2" >0.5731</td>
#       <td id="T_54853_row1_col3" class="data row1 col3" >0.5528</td>
#       <td id="T_54853_row1_col4" class="data row1 col4" >0.5718</td>
#     </tr>
#     <tr>
#       <th id="T_54853_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_54853_row2_col0" class="data row2 col0" >remove_other</td>
#       <td id="T_54853_row2_col1" class="data row2 col1" >XGBoost</td>
#       <td id="T_54853_row2_col2" class="data row2 col2" >0.5929</td>
#       <td id="T_54853_row2_col3" class="data row2 col3" >0.5484</td>
#       <td id="T_54853_row2_col4" class="data row2 col4" >0.5779</td>
#     </tr>
#     <tr>
#       <th id="T_54853_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_54853_row3_col0" class="data row3 col0" >remove_other+oversample</td>
#       <td id="T_54853_row3_col1" class="data row3 col1" >Random Forest</td>
#       <td id="T_54853_row3_col2" class="data row3 col2" >0.5810</td>
#       <td id="T_54853_row3_col3" class="data row3 col3" >0.5453</td>
#       <td id="T_54853_row3_col4" class="data row3 col4" >0.5726</td>
#     </tr>
#     <tr>
#       <th id="T_54853_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_54853_row4_col0" class="data row4 col0" >remove_other</td>
#       <td id="T_54853_row4_col1" class="data row4 col1" >Logistic Regression</td>
#       <td id="T_54853_row4_col2" class="data row4 col2" >0.5613</td>
#       <td id="T_54853_row4_col3" class="data row4 col3" >0.5359</td>
#       <td id="T_54853_row4_col4" class="data row4 col4" >0.5604</td>
#     </tr>
#     <tr>
#       <th id="T_54853_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_54853_row5_col0" class="data row5 col0" >remove_other+undersample</td>
#       <td id="T_54853_row5_col1" class="data row5 col1" >Logistic Regression</td>
#       <td id="T_54853_row5_col2" class="data row5 col2" >0.5534</td>
#       <td id="T_54853_row5_col3" class="data row5 col3" >0.5301</td>
#       <td id="T_54853_row5_col4" class="data row5 col4" >0.5557</td>
#     </tr>
#     <tr>
#       <th id="T_54853_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_54853_row6_col0" class="data row6 col0" >remove_other+oversample</td>
#       <td id="T_54853_row6_col1" class="data row6 col1" >Logistic Regression</td>
#       <td id="T_54853_row6_col2" class="data row6 col2" >0.5494</td>
#       <td id="T_54853_row6_col3" class="data row6 col3" >0.5292</td>
#       <td id="T_54853_row6_col4" class="data row6 col4" >0.5522</td>
#     </tr>
#     <tr>
#       <th id="T_54853_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_54853_row7_col0" class="data row7 col0" >remove_other+oversample</td>
#       <td id="T_54853_row7_col1" class="data row7 col1" >XGBoost</td>
#       <td id="T_54853_row7_col2" class="data row7 col2" >0.5573</td>
#       <td id="T_54853_row7_col3" class="data row7 col3" >0.5281</td>
#       <td id="T_54853_row7_col4" class="data row7 col4" >0.5509</td>
#     </tr>
#     <tr>
#       <th id="T_54853_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_54853_row8_col0" class="data row8 col0" >remove_other</td>
#       <td id="T_54853_row8_col1" class="data row8 col1" >SVM</td>
#       <td id="T_54853_row8_col2" class="data row8 col2" >0.5217</td>
#       <td id="T_54853_row8_col3" class="data row8 col3" >0.5152</td>
#       <td id="T_54853_row8_col4" class="data row8 col4" >0.5212</td>
#     </tr>
#     <tr>
#       <th id="T_54853_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_54853_row9_col0" class="data row9 col0" >remove_other</td>
#       <td id="T_54853_row9_col1" class="data row9 col1" >Random Forest</td>
#       <td id="T_54853_row9_col2" class="data row9 col2" >0.6008</td>
#       <td id="T_54853_row9_col3" class="data row9 col3" >0.5146</td>
#       <td id="T_54853_row9_col4" class="data row9 col4" >0.5626</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ── Impact analysis: removing 'other' class ──────────────────────────────
baseline_f1    = summary[summary.Strategy == "baseline"].set_index("Model")["F1-macro"]
no_other_f1    = summary[summary.Strategy == "remove_other"].set_index("Model")["F1-macro"]
delta = (no_other_f1 - baseline_f1).sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(9, 4))
colors = ["#2ecc71" if v >= 0 else "#e74c3c" for v in delta.values]
ax.barh(delta.index, delta.values, color=colors)
ax.axvline(0, color="black", linewidth=1)
ax.set_xlabel("F1-macro change")
ax.set_title("Impact of Removing 'other' Class on F1-macro\n(green = improvement)")
for i, v in enumerate(delta.values):
    ax.text(v + (0.001 if v >= 0 else -0.001), i,
            f"{v:+.4f}", va="center",
            ha="left" if v >= 0 else "right", fontsize=10)
plt.tight_layout()
plt.show()

print("\nDelta F1-macro (remove_other - baseline):")
print(delta.to_string())
# Out:
# Delta F1-macro (remove_other - baseline):
# Model
# Logistic Regression   0.0999
# XGBoost               0.0984
# KNN                   0.0854
# SVM                   0.0772
# Random Forest         0.0771

# %%
# ── Impact analysis: sampling strategies vs baseline ─────────────────────
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for ax, ref_strat, compare_strat, title in [
    (axes[0], "baseline",     "oversample",  "Oversample vs Baseline"),
    (axes[1], "baseline",     "undersample", "Undersample vs Baseline"),
]:
    ref  = summary[summary.Strategy == ref_strat].set_index("Model")["F1-macro"]
    comp = summary[summary.Strategy == compare_strat].set_index("Model")["F1-macro"]
    delta = (comp - ref).sort_values(ascending=False)
    colors = ["#2ecc71" if v >= 0 else "#e74c3c" for v in delta.values]
    ax.barh(delta.index, delta.values, color=colors)
    ax.axvline(0, color="black", linewidth=1)
    ax.set_xlabel("F1-macro change")
    ax.set_title(title)
    for i, v in enumerate(delta.values):
        ax.text(v + (0.001 if v >= 0 else -0.001), i,
                f"{v:+.4f}", va="center",
                ha="left" if v >= 0 else "right", fontsize=9)

plt.suptitle("Sampling Strategy Impact on F1-macro", fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Save summary to CSV ───────────────────────────────────────────────────
summary.to_csv("experiment_results.csv", index=False)
print("Saved to experiment_results.csv")
print()
print("Final summary:")
display(summary.sort_values(["Strategy", "F1-macro"], ascending=[True, False]))
